# %% [markdown]
# <a href="https://colab.research.google.com/github/Tomo-for-lab/Code-of-automating-DE/blob/main/data%20extraction/data_extraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Preparation

# %%
# !pip install -q openpyxl anthropic weave python-docx
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 877.6/877.6 kB 8.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.2/29.2 MB 20.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.3/244.3 kB 16.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 5.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 327.8/327.8 kB 21.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 320.6/320.6 kB 14.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 31.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 42.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 202.9/202.9 kB 11.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.0/74.0 kB 381.0 kB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.1/65.1 kB 3.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 2.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 7.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 3.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 6.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 289.0/289.0 kB 8.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 3.5 MB/s eta 0:00:00

# %%
import re
import ipykernel
from notebook.notebookapp import list_running_servers
import requests
from urllib.parse import urljoin
import json
import os
from google.colab import auth
from google.colab import userdata
from googleapiclient.discovery import build
import pandas as pd
import openpyxl
import base64
import csv
import numpy as np
import copy
import glob
import time
from docx import Document

from openai import OpenAI
from openai import AzureOpenAI
from tqdm import tqdm

# %% [markdown]
# Change the working directory to the path of the current notebook

# %%
from google.colab import drive
# Mount Google Drive to access files stored in it
drive.mount('/content/drive')


def get_notebook_path():
    # Get the path of the current Jupyter notebook
    kernel_id = re.search('kernel-(.*).json', ipykernel.get_connection_file()).group(1)
    servers = list_running_servers()
    for ss in servers:
        response = requests.get(urljoin(ss['url'], 'api/sessions'), params={'token': ss.get('token', '')})
        for nn in json.loads(response.text):
            if nn['kernel']['id'] == kernel_id:
                relative_path = nn['notebook']['path']
                return os.path.join(ss['notebook_dir'], relative_path)

def get_folder_path(folder_id):
    # Recursively get the full path of a folder given its ID
    if folder_id:
        folder = drive_service.files().get(fileId=folder_id, fields="name, parents").execute()
        folder_name = folder.get('name')
        parents = folder.get('parents')
        if parents:
            parent_path = get_folder_path(parents[0])
            return parent_path + '/' + folder_name
        else:
            return folder_name
    return ''

def get_file_path(file_id):
    # Recursively get the full path of a file given its ID
    file = drive_service.files().get(fileId=file_id, fields="name, parents").execute()
    file_name = file.get('name')
    parents = file.get('parents')
    if parents:
        parent_id = parents[0]
        parent_path = get_folder_path(parent_id)
        return parent_path
    else:
        return file_name

# Get the path of the current notebook
notebook_path = get_notebook_path()


# Authenticate and initialize the Google Drive API
auth.authenticate_user()
drive_service = build('drive', 'v3')

# Extract the file ID from the notebook path (assumes file ID is part of the path)
file_id = re.search(r'fileId=(\w+)', notebook_path).group(1)

# Get the full path of the file using its ID
file_path = get_file_path(file_id)
if 'マイドライブ' in file_path:
    converted_path = re.sub(r'(^|/)マイドライブ($|/)', '/content/drive/MyDrive/', file_path)
elif 'MyDrive' in file_path:
    converted_path = re.sub(r'(^|/)MyDrive($|/)', '/content/drive/MyDrive/', file_path)
else:
    converted_path = '/content/drive/MyDrive/' + file_path

# Change the working directory to the converted path
os.chdir(converted_path)
# Out:
# Mounted at /content/drive

# %%
import weave

weave.init("data_extraction_GPT_demo")

# %% [markdown]
# # Preparation of Azure for GPT

# %%
#deploy names
deployment_ids = ["gpt-4o","gpt-4-turbo","gpt-3.5-turbo","text-embedding-ada-002"]

#If you use Azure
#key
API_KEY = userdata.get('Azure_API_key')
RESOURCE_ENDPOINT = userdata.get('RESOURCE_ENDPOINT')
AZURE_API_version = userdata.get('AZURE_API_version')

#client
client = AzureOpenAI(
    # https://learn.microsoft.com/en-us/azure/ai-services/openai/reference#rest-api-versioning
    api_version=AZURE_API_version,
    # https://learn.microsoft.com/en-us/azure/cognitive-services/openai/how-to/create-resource?pivots=web-portal#create-a-resource
    azure_endpoint=RESOURCE_ENDPOINT,
    api_key=API_KEY
)

# %% [markdown]
# # Define required function

# %% [markdown]
# ## Function to convert text data in JSON and table data into string variable.

# %%
def extract_sentence(pdf_name):
  # Construct the path to the JSON file associated with the given PDF
  json_name=pdf_name+"/structuredData.json"

  a = open(json_name)# Open and load the JSON file
  j = json.load(a)
  method_flag=1
  extracted_sentence=""# Initialize a string to store the extracted sentences
  previous_item_class=0# To track the class of the previous item and determine if a newline is needed

  # Iterate through each element in the JSON file
  for item in j["elements"] :
    # Check if the item is a heading
    if ("//Document/H" in item['Path']) or (re.search(r"//Document/Sect.*/H", item['Path'])):
      if previous_item_class!=1:
        extracted_sentence+="\n"
        previous_item_class=1
      if "Text" in item:
        if ("reference" == item["Text"].strip().lower()) or ("references" == item["Text"].strip().lower()) or ("appendix" == item["Text"].strip().lower()):
          extracted_sentence+="\n"
          break;
        extracted_sentence+=item["Text"]
        extracted_sentence+="\n"

    # Check if the item is a table and convert table data to text
    elif (re.search("//Document/Table.*" ,item['Path'])) or (re.search(r"//Document/Sect.*/Table", item['Path'])):#表データを文章に置き換える
      if previous_item_class!=2:
        extracted_sentence+="\n"
        previous_item_class=2
      if "filePaths" in item:
        for t in item["filePaths"]:
          if ".xlsx" in t:
            extracted_sentence+=t.replace(".xlsx", "").split("/")[-1]
            extracted_sentence+="\n"
            t=pdf_name+"/"+t
            # Load the Excel file
            df_t = pd.read_excel(t)
            # Remove carriage returns from column names and data
            df_t.columns = [col.replace('_x000D_', '') for col in df_t.columns]
            df_t = df_t.replace('_x000D_', '', regex=True)
            # Get column names as a string
            column_names = ' '.join(df_t.columns)

            extracted_sentence+=df_t.to_csv(index=False)
            extracted_sentence+="\n"

    # Check if the item is a footnote
    elif (re.search("//Document/Footnote\.*",item['Path'])) or (re.search(r"//Document/Sect.*/Footnote", item['Path'])):
      if previous_item_class!=5:
        extracted_sentence+="\n"
        previous_item_class=5
      if "Text" in item:
        extracted_sentence+=item["Text"]
        extracted_sentence+="\n"

    # Check if the item is a paragraph
    elif ("//Document/P" in item['Path']) or (re.search(r"//Document/Sect.*/P", item['Path'])):
      if previous_item_class!=3:
        extracted_sentence+="\n"
        previous_item_class=3
      if not("/Figure" in item["Path"]):
        if "Text" in item:
          extracted_sentence+=item["Text"]

    # Check if the item is a list
    elif ("//Document/L" in item['Path']) or (re.search(r"//Document/Sect.*/L", item['Path'])):
      if previous_item_class!=4:
        extracted_sentence+="\n"
        previous_item_class=4
      if "/Lbl" in item["Path"]:
        extracted_sentence+="\n"
      if "Text" in item:
        extracted_sentence+=item["Text"]


  # Close the JSON file
  a.close()
  return extracted_sentence

# %% [markdown]
# ## Function to convert text data in JSON into string variable.

# %%
def extract_sentence_text(pdf_name):
  # Construct the path to the JSON file associated with the given PDF
  json_name=pdf_name+"/structuredData.json"

  a = open(json_name)# Open and load the JSON file
  j = json.load(a)
  method_flag=1
  extracted_sentence=""# Initialize a string to store the extracted sentences
  previous_item_class=0 # To track the class of the previous item and determine if a newline is needed

  # Iterate through each element in the JSON file
  for item in j["elements"] :
    # Check if the item is a heading
    if ("//Document/H" in item['Path']) or (re.search(r"//Document/Sect.*/H", item['Path'])):
      if previous_item_class!=1:
        extracted_sentence+="\n"
        previous_item_class=1
      if "Text" in item:
        # Check for specific keywords to stop extracting sentences
        if ("reference" == item["Text"].strip().lower()) or ("references" == item["Text"].strip().lower()) or ("appendix" == item["Text"].strip().lower()):
          extracted_sentence+="\n"
          break;
        extracted_sentence+=item["Text"]
        extracted_sentence+="\n"

    # Check if the item is a paragraph
    elif ("//Document/P" in item['Path']) or (re.search(r"//Document/Sect.*/P", item['Path'])):
      if previous_item_class!=3:
        extracted_sentence+="\n"
        previous_item_class=3
      if not("/Figure" in item["Path"]):
        if "Text" in item:
          extracted_sentence+=item["Text"]

    # Check if the item is a list
    elif ("//Document/L" in item['Path']) or (re.search(r"//Document/Sect.*/L", item['Path'])):
      if previous_item_class!=4:
        extracted_sentence+="\n"
        previous_item_class=4
      if "/Lbl" in item["Path"]:
        extracted_sentence+="\n"
      if "Text" in item:
        extracted_sentence+=item["Text"]

    # Check if the item is a footnote
    elif (re.search("//Document/Footnote\.*",item['Path'])) or (re.search(r"//Document/Sect.*/Footnote", item['Path'])):
      if previous_item_class != 5:
        extracted_sentence+="\n"
        previous_item_class=5
      if "Text" in item:
        extracted_sentence+=item["Text"]
        extracted_sentence+="\n"

  # Close the JSON file
  a.close()
  return extracted_sentence

# %% [markdown]
# ## Function to encode images into data URL for input to GPT

# %%
import base64
from mimetypes import guess_type

# Function to encode a local image into data URL
def local_image_to_data_url(image_path):
    # Guess the MIME type of the image based on the file extension
    mime_type, _ = guess_type(image_path)
    if mime_type is None:
        mime_type = 'application/octet-stream'  # Default MIME type if none is found

    # Read and encode the image file
    with open(image_path, "rb") as image_file:
        base64_encoded_data = base64.b64encode(image_file.read()).decode('utf-8')

    # Construct the data URL
    return f"data:{mime_type};base64,{base64_encoded_data}"

# %% [markdown]
# ## Function for GPT function calling

# %%
@weave.op() # 🐝
def GPT_function_calling(tools, messages, tools_name):
  response = client.chat.completions.create(
        model=deployment_ids[0],
        messages=messages,
        tools=tools,
        tool_choice =  {"type": "function", "function": {"name": tools_name}},
        temperature=0
    )
  return response

# %% [markdown]
# # To download data

# %%
# Initialize an empty list to store the list of RCTs for evaluation data.
eval_trials = []

with open('eval_trials_list.txt', 'r') as file:
    for line in file:
        eval_trials.append(json.loads(line.strip()))

# Initialize an empty list to store the list of RCTs for training data.
sample_trials = []

with open('sample_trials_list.txt', 'r') as file:
    for line in file:
        sample_trials.append(json.loads(line.strip()))

# %% [markdown]
# # Data extraction

# %% [markdown]
# ## What LLMs should be aware of when extracting data (free text)

# %%
attention_query = """
#####Attention######

# From which paper to extract data
The primary paper is named AuthorYYYY, the registry ULR AuthorYYYY_NCT1234, the protocol AuthorYYYY_pr, the appendix/supplement files AuthorYYY_app or AuthorYYY_supp, and the secondary papers AuthorYYYY_s1,2,…
You can mainly extract data from primary paper.

#Mixed model repeated measures
- When to be careful
"mixed model", "mixed model repeated measures (MMRM)", "linear mixed model", "growth curve analysis ", "hierarchical model", etc.
If SEs are reported instead of SDs, be especially careful, as MMRM is highly likely.
- What to look out for in evaluation and data extraction
MMRM is said to be a method to estimate the effect of missing values of repeatedly measured outcomes without bias by making the assumption of missing at random
So, N (e.g., Severity_ep_n) in the extraction on outcomes should be the N that was analyzed (=in principle, number randomized; number analyzed for statistical analysis excluding early dropouts). Note that this is different from the number of people for whom outcome measures were available. (In the Christensen2016 example, 1149 patients were randomly assigned and 581 were available at 6 weeks for primary outcome measurement. (N should also be number randomized when calculating SD using SD=SE*sqrt(N).


# How to extract data for each arm
First, extract the data for each arm.
If the arm is further divided into several groups, merge these groups and calculate the integrated data.
If you cannot extract data by arm, extract data for all participants.
If you cannot find any data to extract or you do not have to extract data, output "-1".

# Which measure data you will take
You have to extract data (mean, SD, number, etc.) in the measure you previously extracted.

# The measure abbreviations
ISI: Insomnia Severity Index
SCI: Sleep Condition Indicator
FOSQ: Functional Outcomes of Sleep Questionnaire
ESS: Epworth Sleepiness Scale
PSQI: Pittsburgh Sleep Quality Index
AIS: Athens Insomnia Scale
WASO: Wake After Sleep Onset
SOL: Sleep Onset Latency

# How to calculate SD
You have to calculate SD and output as number (do not output as formula).
SD=SE*sqrt(n)
　If mixed model repeated measures were used, n is the number of people randomized or included in the analysis.
SD=(upper limit of [100-x]%CI - mean)*sqrt(n)/ NORM.S.INV([100-x/2]/100)
  If 90%CI, then ((upper limit of 90%CI - mean)*sqrt(n)/ norm.s.inv(0.95))
If 95%CI, then ((upper limit of 95%CI - mean)*sqrt(n)/ norm.s.inv(0.975))
If 99%CI, then ((upper limit of 99%CI - mean)*sqrt(n)/ norm.s.inv(0.995))
SD= (Q3 − Q1)/1.35
"""

# %%
weave.init("data_extraction_integrate")

# %%
@weave.op() # 🐝
def GPT_chat(tools, messages, tools_name):
  response = client.chat.completions.create(
        model=deployment_ids[0],
        messages=messages,
        tools=tools,
        tool_choice =  {"type": "function", "function": {"name": tools_name}},
        temperature=0
    )
  return response

# %%
#Specify developed description obtained by which method is used
shot_name = "chat"
#Specify the path where the results are to be stored
log_dir_name = "extracted_data_log_GPT_v3"

# Iterate over the number of evaluation data and folds
for n_index in range(5,6):
  for fold_index in range(10):
    for eval_index in range(5):
      eval_name=eval_trials[n_index][fold_index][eval_index]
      print("n_index: ", n_index)
      print("fold_index: ", fold_index)
      print("eval_index: ", eval_index)
      extracted_data = {} #For storing extracted data
      output_extracted_data = {} #For storing output data
############################################
      # Define tools for extracting arm information
      tools = [{'type': 'function',
          'function':
              {'name': 'extract_arm',
              'description': 'Extract the number of the arms and each arm name',
              'parameters': {
                  'type': 'object',
                'properties': {
                    "arms_num":
                    {"type": "number",
                    "description": "Answer the number of the arms"
                    },
                    "arm_name_1":
                    {"type": "string",
                    "description": "Answer arm name. If exceed the number of the arms, answer 'nan'."
                    },

                    "arm_name_2":
                    {"type": "string",
                    "description": "Answer arm name. If exceed the number of the arms, answer 'nan'."
                    },

                    "arm_name_3":
                    {"type": "string",
                    "description": "Answer arm name. If exceed the number of the arms, answer 'nan'."
                    },

                    "arm_name_4":
                    {"type": "string",
                    "description": "Answer arm name. If exceed the number of the arms, answer 'nan'."
                    },

                    "arm_name_5":
                    {"type": "string",
                    "description": "Answer arm name. If exceed the number of the arms, answer 'nan'."
                    }
                },
              "required": [
                  "arms_num",
                  "arm_name_1",
                  "arm_name_2",
                  "arm_name_3",
                  "arm_name_4",
                  "arm_name_5"
                  ]
              }
          }
      }
      ]
#######################################################
      # Create messages for extracting arm information
      messages_arm=[]
      system_content = """You are a systematic reviewer.You have to extract arms(i.e., intervenitons and controls) from the inputted paper of a randomized controlled trial.\n
      Use the extract_arm tool in your response.\n\n"""
      user_content = """You have to extract arms(i.e., intervenitons and controls) from the inputted paper of a randomized controlled trial.\n
      Use the extract_arm tool in your response.\n\n"""
      png_files_sum = 0

      # Create input text from the paper
      root_dir = f"IncludedTrials/{eval_name}"# Root directory containing the trial files
      file_to_find = "structuredData.json" # JSON file to find in directories

      user_content += f"paper_name: {eval_name} \n"
      for dirpath, dirnames, filenames in os.walk(root_dir):# Process each document in the directory
        if (dirpath == root_dir) or (dirpath == root_dir+f"/{eval_name}"):# Only main documents
          if file_to_find in filenames:
            main_paper_txt= extract_sentence_text(dirpath)
            user_content += main_paper_txt

      # Check if main_paper_txt is empty
      if main_paper_txt == "":
        # Generate the log file name, including date and time
        log_file_name = f"{log_dir_name}/{shot_name}/{n_index}_paper/{fold_index}_fold/error_log_{eval_index}_no_paper_text.txt"
        # Define the error message
        error_message = f"An error occurred: no_paper_text"
        print(error_message)
        # Write the error message to the log file
        with open(log_file_name, 'w') as file:
            file.write(error_message)
        # Skip to the next evaluation RCT
        continue;

      messages_arm.append({"role": "system", "content": system_content})
      messages_arm.append({"role": "user", "content": user_content})

############################################
      # Get response from GPT model
      try:
        tools_name = "extract_arm"
        response_arm = GPT_function_calling(tools, messages_arm, tools_name)

      except Exception as e:
        log_file_name = f"{log_dir_name}/{shot_name}/{n_index}_paper/{fold_index}_fold/error_log_{eval_index}_response_arm.txt"
        error_message = f"An error occurred: {str(e)}"
        print(error_message)
        with open(log_file_name, 'w') as file:
            file.write(error_message)
        continue;

############################################
      # Parse the response
      try:
        # Load the JSON response from the GPT output
        output_dict_arm = json.loads(response_arm.choices[0].message.tool_calls[0].function.arguments)
        # Extract the number of arms from the JSON dictionary
        arms_num = output_dict_arm["arms_num"]

        arms_list = []
        # Loop through each arm and append its name to the arms_list
        for arm_num in range(arms_num):
          arms_list.append(output_dict_arm[f"arm_name_{arm_num+1}"])
        print("arms_num: ", arms_num)
        print("arms_list: ", arms_list)

      except Exception as e:
        log_file_name = f"{log_dir_name}/{shot_name}/{n_index}_paper/{fold_index}_fold/error_log_{eval_index}_output_dict_arm.txt"
        error_message = f"An error occurred: {str(e)}"
        print(error_message)
        with open(log_file_name, 'w') as file:
            file.write(error_message)
        continue;

############################################
      # Process each arm
      for arm_num in range(arms_num):
        print("arm_num: ", arm_num)
############################################
      # Create a dictionary to store the output
      # Define the path to the JSON file
        json_file_path = 'original_description_insomnia.json'

        # Load the JSON data from the file
        with open(json_file_path, 'r') as file:
            data = json.load(file)
        all_fields = [field for field in data]

        # Initialize the output dictionary with field names as keys and "None" as values
        output = {item['name']: "None" for item in all_fields}

############################################
        # Create tools from optimized description
        try:
          # Determine the log path based on n_index (the number of RCTs for training data)
          if n_index == 0:
            log_path = f'optimized_description_log_v3/{shot_name}/{n_index}_paper/{fold_index}_fold/optimized_all_fields_{n_index}*.json'
          else:
            log_path = f'optimized_description_log_v3/{shot_name}/{n_index}_paper/{fold_index}_fold/optimized_all_fields_{n_index-1}*.json'
          file_paths = glob.glob(log_path)

          for file_path in file_paths:
              with open(file_path, 'r') as file:
                  optimized_all_fields = json.load(file)

          #Add options
          for item in optimized_all_fields:
            if item['name'] == 'ind_clu':
              if not('[individual, cluster]' in item['description']):
                item['description'] += ' You have to choose from the options [individual, cluster].'
            if item['name'] == 'Single_multi':
              if not('[single, multi]' in item['description']):
                item['description'] += ' You have to choose from the options [single, multi].'
            if item['name'] == 'Insomnia_diagnosis':
              if not('[1. formal_DSM, 1. formal_ICSD, 1. formal_ICD, 1. formal_Edinger2004, 2. informal_ISI, 2. informal_SCI, 2. informal_PSQI, 2. informal_AIS, 2. informal_other_self_reported_scales, 3. others]' in item['description']):
                item['description'] += ' You have to choose from the options [1. formal_DSM, 1. formal_ICSD, 1. formal_ICD, 1. formal_Edinger2004, 2. informal_ISI, 2. informal_SCI, 2. informal_PSQI, 2. informal_AIS, 2. informal_other_self_reported_scales, 3. others].'
            if item['name'] == 'Comorbidities':
              if not('[0. primary_insomnia, 1. primary_secondary_mixed, 2. psy_MDD, 2. psy_anxiety, 2. psy_PTSD, 2. psy_schizophrenia_or_psychosis, 2. psy_bipolar, 2. psy_substance_dependence, 2. psy_others, 2. psy_mixed, 3. phy_dialysis, 3. phy_heart_failure, 3. phy_diabetes, 3. phy_fibromyalgia, 3. phy_cancer, 3. phy_steroid, 3. phy_pregnancy_perinatal, 3. phy_menopause, 3. phy_others, 3. phy_mixed, 4. psy_phy_mixed]' in item['description']):
                item['description'] += ' You have to choose from the options [0. primary_insomnia, 1. primary_secondary_mixed, 2. psy_MDD, 2. psy_anxiety, 2. psy_PTSD, 2. psy_schizophrenia_or_psychosis, 2. psy_bipolar, 2. psy_substance_dependence, 2. psy_others, 2. psy_mixed, 3. phy_dialysis, 3. phy_heart_failure, 3. phy_diabetes, 3. phy_fibromyalgia, 3. phy_cancer, 3. phy_steroid, 3. phy_pregnancy_perinatal, 3. phy_menopause, 3. phy_others, 3. phy_mixed, 4. psy_phy_mixed].'
            if item['name'] == 'scale_used':
              if not('[ISI, SCI, FOSQ, ESS, PSQI, AIS, other_self_reported_scales, WASO_SOL, WASO, SOL]' in item['description']):
                item['description'] += ' You have to choose from the options [ISI, SCI, FOSQ, ESS, PSQI, AIS, other_self_reported_scales, WASO_SOL, WASO, SOL].'
            if item['name'] == 'Severity_scale':
              if not('[ISI, SCI, FOSQ, ESS, PSQI, AIS, other_self_reported_scales, WASO_SOL, WASO, SOL]' in item['description']):
                item['description'] += ' You have to choose from the options [ISI, SCI, FOSQ, ESS, PSQI, AIS, other_self_reported_scales, WASO_SOL, WASO, SOL].'
            if item['name'] == 'r_long_scale_used':
              if not('[ISI, SCI, FOSQ, ESS, PSQI, AIS, other_self_reported_scales, WASO_SOL, WASO, SOL]' in item['description']):
                item['description'] += ' You have to choose from the options [ISI, SCI, FOSQ, ESS, PSQI, AIS, other_self_reported_scales, WASO_SOL, WASO, SOL].'

        except Exception as e:
          extracted_data[arms_list[arm_num]] = copy.deepcopy(output)
          log_file_name = f"{log_dir_name}/{shot_name}/{n_index}_paper/{fold_index}_fold/error_log_{eval_index}_data_extraction_armnum_{arm_num}.txt"
          error_message = f"An error occurred: {str(e)}"
          print(error_message)
          with open(log_file_name, 'w') as file:
              file.write(error_message)
          continue;

        #Convert to appropriate structure for incorporation into tools
        properties_dict = {item['name']: {k: v for k, v in item.items() if k != 'name'} for item in optimized_all_fields}
        name_list = [item['name'] for item in optimized_all_fields]

        # Define the initial structure of tools for data extraction
        description_tools = [{'type': 'function',
            'function':
                {'name': 'extract_study_features',
                'description': 'Extracts key features from a user-inputted research article for systematic review purposes.',
                'parameters': {
                    'type': 'object',
                  'properties': {}
                }
            }
        }
        ]
        splitted_name_list = copy.deepcopy(name_list)
        description_tools[0]['function']['parameters']['required'] = splitted_name_list
        description_tools[0]['function']['parameters']['properties'] = {key: properties_dict[key] for key in splitted_name_list if key in properties_dict}

############################################
        # Create messages for data extraction
        system_content_DE = """You are a systematic reviewer.
        Use the extract_study_features tool in your response.
        """

        query_GPT = f"""You have to extract features in the {arms_list[arm_num]} arm from the inputted paper of a randomized controlled trial.
          Use the extract_study_features tool in your response.\n
            """
        query_GPT += attention_query
        query_GPT += f"trial_name: {eval_name} \n \n "

        query_function_calling = copy.deepcopy(query_GPT)

        query_GPT += "The extract_study_features:"
        query_GPT += json.dumps(description_tools)

        last_query = attention_query

        messages_GPT = []
        content_prompt_GPT = [] # List to hold content prompts for GPT

        png_files_sum = 0 # Sum of PNG files processed

        # Create input text from the paper
        root_dir = f"IncludedTrials/{eval_name}" # Root directory containing the trial files
        file_to_find = "structuredData.json" # JSON file to find in directories

        content_prompt_GPT.append({"type": "text", "text": query_GPT})

        # Extract sentences from each document in the directory
        for dirpath, dirnames, filenames in os.walk(root_dir):
          if eval_name in dirnames:# Process the main paper first
            dirnames.remove(eval_name)
            dirnames.insert(0, eval_name)
          if file_to_find in filenames:
            paper_query = dirpath.split("/")[-1]
            paper_query += extract_sentence(dirpath)
            content_prompt_GPT.append({"type": "text", "text":paper_query})

            # Filter and add PNG files to the content prompt
            if os.path.exists(f"{dirpath}/figures"):
              png_files = [file for file in os.listdir(f"{dirpath}/figures") if file.endswith('.png')]

              for i in range(len(png_files)):
                if png_files_sum >= 10:# Limit the number of images to 10
                  break;
                content_prompt_GPT.append({"type": "image_url", "image_url": {"url": local_image_to_data_url(f"{dirpath}/figures/"+png_files[i])}})
                png_files_sum += 1

        # Process txt and docx files in the root directory
        txt_docx_query = "" # String to hold txt and docx file contents
        txt_docx_flag = False # Flag to check if txt or docx files are found

        for file_name in os.listdir(root_dir):
            if file_name.endswith('.txt'):
                txt_docx_flag = True
                txt_docx_query += "txt_name: "
                txt_docx_query += "txt_name: " + file_name + "\n"
                file_path = os.path.join(root_dir, file_name)
                with open(file_path, 'r', encoding='utf-8') as file:
                    txt_docx_query += file.read()
            elif file_name.endswith('.docx'):
                txt_docx_flag = True
                txt_docx_query += "docx_name: "
                txt_docx_query += "docx_name: " + file_name + "\n"
                file_path = os.path.join(root_dir, file_name)
                doc = Document(file_path)
                full_text = []
                for para in doc.paragraphs:
                    full_text.append(para.text)

                for table in doc.tables:
                    for row in table.rows:
                        for cell in row.cells:
                            full_text.append(cell.text)
                txt_docx_query += '\n'.join(full_text)

        if txt_docx_flag:
          content_prompt_GPT.append({"type": "text", "text":txt_docx_query})


        content_prompt_GPT.append({"type": "text", "text": last_query})

        messages_GPT.append({"role": "system", "content": system_content_DE})
        messages_GPT.append({"role": "user", "content": content_prompt_GPT})

############################################
        try:
          # Get response from GPT model
          tools_name = "extract_study_features"
          response_GPT = GPT_chat(description_tools, messages_GPT ,tools_name)

  ############################################
          # Store the results
          output_dict = json.loads(response_GPT.choices[0].message.tool_calls[0].function.arguments)

          # Update the output dictionary with values from output_dict
          for k in output_dict.keys():
            if k in output.keys():
              output[k] = output_dict[k]

          # Store the updated output dictionary in extracted_data with the current arm name
          extracted_data[arms_list[arm_num]] = copy.deepcopy(output)

        except Exception as e:
          extracted_data[arms_list[arm_num]] = copy.deepcopy(output)
          log_file_name = f"{log_dir_name}/{shot_name}/{n_index}_paper/{fold_index}_fold/error_log_{eval_index}_data_extraction_armnum_{arm_num}.txt"
          error_message = f"An error occurred: {str(e)}"
          print(error_message)
          with open(log_file_name, 'w') as file:
              file.write(error_message)
          continue;

############################################
      # Define the file name for storing the extracted data
      file_name = f"{log_dir_name}/{shot_name}/{n_index}_paper/{fold_index}_fold/extracted_data_{eval_index}.json"
      output_extracted_data[eval_name] = copy.deepcopy(extracted_data)
      print("log has been created: ",extracted_data)

      # Write the extracted data to the specified JSON file
      with open(file_name, 'w') as file:
          json.dump(output_extracted_data, file, indent=4)
# Out:
# n_index:  5
# fold_index:  0
# eval_index:  0
# 🍩 https://wandb.ai/srws-psg/data_extraction_integrate/r/call/4d6014e4-996d-4932-9bfb-c2a2a6ee77c3
# arms_num:  2
# arms_list:  ['CBT-I', 'MEC']
# arm_num:  0
# 🍩 https://wandb.ai/srws-psg/data_extraction_integrate/r/call/71fd5132-c314-4e13-9c12-50a593edc65d
# arm_num:  1
# 🍩 https://wandb.ai/srws-psg/data_extraction_integrate/r/call/d0dfc2a9-87e5-41dc-8bf4-603059b63264
# log has been created:  {'CBT-I': {'Year': 2016, 'ind_clu': 'individual', 'ICC_for_cRCT': 0.05, 'Country': 'USA', 'Single_multi': 'single', 'Age_mean': 55, 'Age_sd': 3.5, 'Age_n': 53, 'F_n': 49, 'Hyp_n': -1, 'Insomnia_diagnosis': 'ISI', 'Primary_insomnia_n': -1, 'Comorbidities': '3. phy_menopause', 'se': 1, 'sd': 1, 'cr': 1, 'cw': 1, 'sr': 1, 'sc': 1, 're': 1, 'pi': 0, 'w': 0, 'dt': 0, 'ns': 0, 'he': 1, 'tg': 1, 'ind': 0, 'gp': 0, 'ff': 0, 'ae': 0, 'n': 53, 'remission': 33, 'def_remission_response': 'At 8 weeks, 33 of 47 women (70%) in the CBT-I group had total scores in a range indicating no clinically significant insomnia (score, 0-7) compared with only 10 of 41 women (24%) randomized to receive MEC; at 24 weeks, 37 of 44 women (84%) in the CBT-I group vs 16 of 37 (43%) in the MEC group were in the no insomnia range.', 'scale_used': 'ISI', 'Severity_bl_mean': 15.6, 'Severity_bl_sd': 0.8, 'Severity_bl_n': 53, 'Severity_ch_mean': -9.9, 'Severity_ch_sd': 0.6, 'Severity_ch_n': 47, 'Severity_ep_mean': 5.7, 'Severity_ep_sd': 0.6, 'Severity_ep_n': 47, 'Severity_scale': 'ISI', 'dropout': 2, 'SE_mean': 75.8, 'SE_sd': 1.3, 'SE_n': 51, 'TST_mean': 396, 'TST_sd': 7.1, 'TST_n': 51, 'SOL_mean': 54.4, 'SOL_sd': 5.3, 'SOL_n': 51, 'WASO_mean': 71.7, 'WASO_sd': 5.6, 'WASO_n': 51, 'Sleep_diary_weeks': 8, 'r_long': 37, 'r_long_scale_used': 'ISI', 'Severity_mean_long': 4.9, 'Severity_sd_long': 0.6, 'Severity_n_long': 44, 'Severity_ch_mean_long': -10.7, 'Severity_ch_sd_long': 0.6, 'Severity_ch_n_long': 44, 'r_weeks_long': 24}, 'MEC': {'Year': 2016, 'ind_clu': 'individual', 'ICC_for_cRCT': 0.05, 'Country': 'USA', 'Single_multi': 'single', 'Age_mean': 54.7, 'Age_sd': 4.7, 'Age_n': 53, 'F_n': -1, 'Hyp_n': -1, 'Insomnia_diagnosis': 'ISI', 'Primary_insomnia_n': -1, 'Comorbidities': '3. phy_menopause', 'se': 1, 'sd': 1, 'cr': 0, 'cw': 0, 'sr': 0, 'sc': 0, 're': 0, 'pi': 0, 'w': 0, 'dt': 0, 'ns': 1, 'he': 1, 'tg': 1, 'ind': 0, 'gp': 0, 'ff': 0, 'ae': 0, 'n': 53, 'remission': 16, 'def_remission_response': 'At 8 weeks, 33 of 47 women (70%) in the CBT-I group had total scores in a range indicating no clinically significant insomnia (score, 0-7) compared with only 10 of 41 women (24%) randomized to receive MEC; at 24 weeks, 37 of 44 women (84%) in the CBT-I group vs 16 of 37 (43%) in the MEC group were in the no insomnia range (Figure 2).', 'scale_used': 'ISI', 'Severity_bl_mean': 16.8, 'Severity_bl_sd': -1, 'Severity_bl_n': 53, 'Severity_ch_mean': -1, 'Severity_ch_sd': -1, 'Severity_ch_n': -1, 'Severity_ep_mean': 10.1, 'Severity_ep_sd': -1, 'Severity_ep_n': 53, 'Severity_scale': 'ISI', 'dropout': 11, 'SE_mean': -1, 'SE_sd': -1, 'SE_n': -1, 'TST_mean': -1, 'TST_sd': -1, 'TST_n': -1, 'SOL_mean': -1, 'SOL_sd': -1, 'SOL_n': -1, 'WASO_mean': -1, 'WASO_sd': -1, 'WASO_n': -1, 'Sleep_diary_weeks': -1, 'r_long': 16, 'r_long_scale_used': 'ISI', 'Severity_mean_long': -1, 'Severity_sd_long': -1, 'Severity_n_long': -1, 'Severity_ch_mean_long': -1, 'Severity_ch_sd_long': -1, 'Severity_ch_n_long': -1, 'r_weeks_long': 24}}
# n_index:  5
# fold_index:  0
# eval_index:  1
# 🍩 https://wandb.ai/srws-psg/data_extraction_integrate/r/call/e8ecd978-0c2e-4c81-a1b7-182f0d445b5a
# arms_num:  2
# arms_list:  ['CBT plus standard care', 'standard care alone']
# arm_num:  0
# 🍩 https://wandb.ai/srws-psg/data_extraction_integrate/r/call/ab753918-0a46-4ea7-9366-ab8fbcf69afe
# arm_num:  1
# 🍩 https://wandb.ai/srws-psg/data_extraction_integrate/r/call/71bf5c57-6d12-4c70-bb6c-bdf31a0e1652
# log has been created:  {'CBT plus standard care': {'Year': 2015, 'ind_clu': 'individual', 'ICC_for_cRCT': 0, 'Country': 'UK', 'Single_multi': 'multi', 'Age_mean': 40.4, 'Age_sd': 12.7, 'Age_n': 19, 'F_n': 7, 'Hyp_n': 6, 'Insomnia_diagnosis': '2. informal_ISI', 'Primary_insomnia_n': -1, 'Comorbidities': '2. psy_schizophrenia_or_psychosis', 'se': 1, 'sd': 1, 'cr': 1, 'cw': 0, 'sr': 0, 'sc': 1, 're': 1, 'pi': 0, 'w': 0, 'dt': 1, 'ns': 0, 'he': 0, 'tg': 1, 'ind': 1, 'gp': 0, 'ff': 1, 'ae': 0, 'n': 24, 'remission': 9, 'def_remission_response': 'By week 12, nine (41%) of 22 patients receiving CBT and one (4%) of 25 patients receiving standard care alone no longer had insomnia, with ISI scores lower than the cutoff for insomnia.', 'scale_used': 'ISI', 'Severity_bl_mean': 18.6, 'Severity_bl_sd': 3.2, 'Severity_bl_n': 24, 'Severity_ch_mean': -1, 'Severity_ch_sd': -1, 'Severity_ch_n': -1, 'Severity_ep_mean': 9.3, 'Severity_ep_sd': 5.5, 'Severity_ep_n': 22, 'Severity_scale': 'ISI', 'dropout': 2, 'SE_mean': -1, 'SE_sd': -1, 'SE_n': -1, 'TST_mean': 456.4, 'TST_sd': 107.7, 'TST_n': 17, 'SOL_mean': 34.6, 'SOL_sd': 40.3, 'SOL_n': 22, 'WASO_mean': 19.9, 'WASO_sd': 22.2, 'WASO_n': 18, 'Sleep_diary_weeks': 12, 'r_long': -1, 'r_long_scale_used': '-1', 'Severity_mean_long': 11, 'Severity_sd_long': 5.6, 'Severity_n_long': 23, 'Severity_ch_mean_long': -1, 'Severity_ch_sd_long': -1, 'Severity_ch_n_long': -1, 'r_weeks_long': 24}, 'standard care alone': {'Year': 2015, 'ind_clu': 'individual', 'ICC_for_cRCT': 0.05, 'Country': 'UK', 'Single_multi': 'multi', 'Age_mean': 42.9, 'Age_sd': 13.4, 'Age_n': 24, 'F_n': 8, 'Hyp_n': 5, 'Insomnia_diagnosis': '2. informal_ISI', 'Primary_insomnia_n': -1, 'Comorbidities': '2. psy_schizophrenia_or_psychosis', 'se': 1, 'sd': 1, 'cr': 0, 'cw': 0, 'sr': 0, 'sc': 0, 're': 0, 'pi': 0, 'w': 0, 'dt': 1, 'ns': 0, 'he': 0, 'tg': 0, 'ind': 0, 'gp': 0, 'ff': 0, 'ae': 0, 'n': 26, 'remission': 1, 'def_remission_response': 'By week 12, nine (41%) of 22 patients receiving CBT and one (4%) of 25 patients receiving standard care alone no longer had insomnia, with ISI scores lower than the cutoff for insomnia.', 'scale_used': 'ISI', 'Severity_bl_mean': 18.8, 'Severity_bl_sd': 3.3, 'Severity_bl_n': 26, 'Severity_ch_mean': -1, 'Severity_ch_sd': -1, 'Severity_ch_n': -1, 'Severity_ep_mean': 15.4, 'Severity_ep_sd': 5.4, 'Severity_ep_n': 25, 'Severity_scale': 'ISI', 'dropout': 1, 'SE_mean': -1, 'SE_sd': -1, 'SE_n': -1, 'TST_mean': 437.5, 'TST_sd': 118.1, 'TST_n': 18, 'SOL_mean': 46.6, 'SOL_sd': 37, 'SOL_n': 19, 'WASO_mean': 47.6, 'WASO_sd': 52.1, 'WASO_n': 18, 'Sleep_diary_weeks': 12, 'r_long': -1, 'r_long_scale_used': '-1', 'Severity_mean_long': 15, 'Severity_sd_long': 5.7, 'Severity_n_long': 25, 'Severity_ch_mean_long': -1, 'Severity_ch_sd_long': -1, 'Severity_ch_n_long': -1, 'r_weeks_long': 24}}
# n_index:  5
# fold_index:  0
# eval_index:  2
# 🍩 https://wandb.ai/srws-psg/data_extraction_integrate/r/call/bc4501bc-ce92-428f-9207-90ac8d4fba02
# arms_num:  3
# arms_list:  ['multicomponent cognitive behavioral self-help intervention (MCT)', 'sleep restriction intervention for insomnia (SRT)', 'care as usual (CAU)']
# arm_num:  0
# 🍩 https://wandb.ai/srws-psg/data_extraction_integrate/r/call/bfc02246-bd97-4260-8d74-299a078ce088
# arm_num:  1
# 🍩 https://wandb.ai/srws-psg/data_extraction_integrate/r/call/0bd1852f-7c0a-4bd9-ad4a-e7102e4b1a44
# arm_num:  2
# 🍩 https://wandb.ai/srws-psg/data_extraction_integrate/r/call/bd9e6861-6dad-4ea1-990d-2c4708ed5f53
# log has been created:  {'multicomponent cognitive behavioral self-help intervention (MCT)': {'Year': 2019, 'ind_clu': 'individual', 'ICC_for_cRCT': 0.05, 'Country': 'Switzerland', 'Single_multi': 'multi', 'Age_mean': 42.17, 'Age_sd': 12.4, 'Age_n': 42, 'F_n': 26, 'Hyp_n': 16, 'Insomnia_diagnosis': '1. formal_ICSD', 'Primary_insomnia_n': 42, 'Comorbidities': '0. primary_insomnia', 'se': 1, 'sd': 1, 'cr': 1, 'cw': 0, 'sr': 1, 'sc': 1, 're': 1, 'pi': 0, 'w': 0, 'dt': 0, 'ns': 0, 'he': 1, 'tg': 1, 'ind': 0, 'gp': 0, 'ff': 0, 'ae': 0, 'n': 42, 'remission': 16, 'def_remission_response': 'Participants were considered responders if their ISI change score compared with baseline was greater than seven at post, and treatment remitters if their absolute ISI score at post was less than eight, following previous recommendations.', 'scale_used': 'ISI', 'Severity_bl_mean': 16.2, 'Severity_bl_sd': 3.75, 'Severity_bl_n': 41, 'Severity_ch_mean': -1, 'Severity_ch_sd': -1, 'Severity_ch_n': -1, 'Severity_ep_mean': 9.08, 'Severity_ep_sd': 5.37, 'Severity_ep_n': 42, 'Severity_scale': 'ISI', 'dropout': 5, 'SE_mean': 84.91, 'SE_sd': 14.22, 'SE_n': 40, 'TST_mean': -1, 'TST_sd': -1, 'TST_n': -1, 'SOL_mean': -1, 'SOL_sd': -1, 'SOL_n': -1, 'WASO_mean': -1, 'WASO_sd': -1, 'WASO_n': -1, 'Sleep_diary_weeks': 8, 'r_long': 20, 'r_long_scale_used': 'ISI', 'Severity_mean_long': 8.11, 'Severity_sd_long': -1, 'Severity_n_long': 41, 'Severity_ch_mean_long': -1, 'Severity_ch_sd_long': -1, 'Severity_ch_n_long': -1, 'r_weeks_long': 24}, 'sleep restriction intervention for insomnia (SRT)': {'Year': 2019, 'ind_clu': 'individual', 'ICC_for_cRCT': 0.05, 'Country': 'Switzerland', 'Single_multi': 'multi', 'Age_mean': 46.59, 'Age_sd': 17.52, 'Age_n': 41, 'F_n': 28, 'Hyp_n': 13, 'Insomnia_diagnosis': '1. formal_ICSD', 'Primary_insomnia_n': 41, 'Comorbidities': '0. primary_insomnia', 'se': 1, 'sd': 1, 'cr': 0, 'cw': 0, 'sr': 1, 'sc': 0, 're': 0, 'pi': 0, 'w': 0, 'dt': 0, 'ns': 0, 'he': 1, 'tg': 1, 'ind': 0, 'gp': 0, 'ff': 0, 'ae': 0, 'n': 41, 'remission': 10, 'def_remission_response': 'Participants were considered responders if their ISI change score compared with baseline was greater than seven at post, and treatment remitters if their absolute ISI score at post was less than eight, following previous recommendations.', 'scale_used': 'ISI', 'Severity_bl_mean': 17.37, 'Severity_bl_sd': 3.44, 'Severity_bl_n': 41, 'Severity_ch_mean': -6.03, 'Severity_ch_sd': 4.1, 'Severity_ch_n': 41, 'Severity_ep_mean': 11.34, 'Severity_ep_sd': 5.25, 'Severity_ep_n': 41, 'Severity_scale': 'ISI', 'dropout': 7, 'SE_mean': 81.81, 'SE_sd': 16.76, 'SE_n': 39, 'TST_mean': -1, 'TST_sd': -1, 'TST_n': -1, 'SOL_mean': -1, 'SOL_sd': -1, 'SOL_n': -1, 'WASO_mean': -1, 'WASO_sd': -1, 'WASO_n': -1, 'Sleep_diary_weeks': 8, 'r_long': 16, 'r_long_scale_used': 'ISI', 'Severity_mean_long': 10.2, 'Severity_sd_long': 0.77, 'Severity_n_long': 41, 'Severity_ch_mean_long': -7.17, 'Severity_ch_sd_long': 0.94, 'Severity_ch_n_long': 41, 'r_weeks_long': 24}, 'care as usual (CAU)': {'Year': 2019, 'ind_clu': 'individual', 'ICC_for_cRCT': 0.05, 'Country': 'Switzerland', 'Single_multi': 'multi', 'Age_mean': 45.24, 'Age_sd': 12.4, 'Age_n': 21, 'F_n': 17, 'Hyp_n': 8, 'Insomnia_diagnosis': '1. formal_ICSD', 'Primary_insomnia_n': 21, 'Comorbidities': '0. primary_insomnia', 'se': 0, 'sd': 0, 'cr': 0, 'cw': 0, 'sr': 0, 'sc': 0, 're': 0, 'pi': 0, 'w': 0, 'dt': 0, 'ns': 0, 'he': 0, 'tg': 0, 'ind': 0, 'gp': 0, 'ff': 0, 'ae': 0, 'n': 21, 'remission': 1, 'def_remission_response': 'Regarding remission (ISI post score < 8), 4.8% of the participants in the CAU (n ¼1), 24.4% in the SRT (n ¼10), and 38.1% (n ¼16) in the MCT condition were considered remitted at post-treatment.', 'scale_used': 'ISI', 'Severity_bl_mean': 17.43, 'Severity_bl_sd': 3.83, 'Severity_bl_n': 21, 'Severity_ch_mean': -1, 'Severity_ch_sd': -1, 'Severity_ch_n': -1, 'Severity_ep_mean': 14.67, 'Severity_ep_sd': 4.97, 'Severity_ep_n': 21, 'Severity_scale': 'ISI', 'dropout': 1, ...
# n_index:  5
# fold_index:  0
# eval_index:  3
# 🍩 https://wandb.ai/srws-psg/data_extraction_integrate/r/call/df1f428b-d5c3-4e00-8a8b-83a15fdb715c
# arms_num:  2
# arms_list:  ['CBT-I', 'SET']
# arm_num:  0
# 🍩 https://wandb.ai/srws-psg/data_extraction_integrate/r/call/306e34cc-1284-4b85-b05d-f9f69ecb48c5
# arm_num:  1
# 🍩 https://wandb.ai/srws-psg/data_extraction_integrate/r/call/bde2af14-e084-45c6-b29c-852615d4a272
# log has been created:  {'CBT-I': {'Year': 2021, 'ind_clu': 'individual', 'ICC_for_cRCT': 0.05, 'Country': 'USA', 'Single_multi': 'single', 'Age_mean': 70.2, 'Age_sd': 7, 'Age_n': 156, 'F_n': 86, 'Hyp_n': 33, 'Insomnia_diagnosis': '1. formal_DSM', 'Primary_insomnia_n': -1, 'Comorbidities': '2. psy_mixed', 'se': 1, 'sd': 1, 'cr': 1, 'cw': 0, 'sr': 1, 'sc': 1, 're': 1, 'pi': 0, 'w': 0, 'dt': 0, 'ns': 0, 'he': 0, 'tg': 1, 'ind': 0, 'gp': 1, 'ff': 1, 'ae': 0, 'n': 156, 'remission': 71, 'def_remission_response': 'The proportion of participants who achieved remission of insomnia disorder after treatment was greater in the CBT-I group (71 [50.7%]) compared with the SET group (49 [37.7%]; adjusted β = 0.52; 95% CI, 0.10-0.93; P = .02); similar results were found for sustained remission of insomnia disorder (ie, insomnia remission) in the CBT-I group (41 [26.3%]) compared with the SET group (26 [19.3%]; adjusted β = 0.56; 95% CI, 0.07-1.04; P = .03).', 'scale_used': 'AIS', 'Severity_bl_mean': 9.4, 'Severity_bl_sd': 3.4, 'Severity_bl_n': 156, 'Severity_ch_mean': -1, 'Severity_ch_sd': -1, 'Severity_ch_n': -1, 'Severity_ep_mean': -1, 'Severity_ep_sd': -1, 'Severity_ep_n': -1, 'Severity_scale': 'AIS', 'dropout': 16, 'SE_mean': -1, 'SE_sd': -1, 'SE_n': -1, 'TST_mean': -1, 'TST_sd': -1, 'TST_n': -1, 'SOL_mean': -1, 'SOL_sd': -1, 'SOL_n': -1, 'WASO_mean': -1, 'WASO_sd': -1, 'WASO_n': -1, 'Sleep_diary_weeks': -1, 'r_long': 41, 'r_long_scale_used': 'AIS', 'Severity_mean_long': -1, 'Severity_sd_long': -1, 'Severity_n_long': -1, 'Severity_ch_mean_long': -1, 'Severity_ch_sd_long': -1, 'Severity_ch_n_long': -1, 'r_weeks_long': 36}, 'SET': {'Year': 2021, 'ind_clu': 'individual', 'ICC_for_cRCT': 0.05, 'Country': 'USA', 'Single_multi': 'single', 'Age_mean': 69.9, 'Age_sd': 6.4, 'Age_n': 135, 'F_n': 82, 'Hyp_n': 24, 'Insomnia_diagnosis': '1. formal_DSM', 'Primary_insomnia_n': -1, 'Comorbidities': '1. primary_secondary_mixed', 'se': 1, 'sd': 1, 'cr': 0, 'cw': 0, 'sr': 0, 'sc': 0, 're': 0, 'pi': 0, 'w': 0, 'dt': 0, 'ns': 0, 'he': 0, 'tg': 1, 'ind': 0, 'gp': 1, 'ff': 1, 'ae': 0, 'n': 135, 'remission': 26, 'def_remission_response': 'The secondary outcome was sustained remission of insomnia disorder by DSM-5 criteria, as defined by absence of insomnia disorder at each follow-up assessment before a depression event or throughout follow-up.', 'scale_used': 'ISI', 'Severity_bl_mean': 9.5, 'Severity_bl_sd': 3.6, 'Severity_bl_n': 135, 'Severity_ch_mean': -1, 'Severity_ch_sd': -1, 'Severity_ch_n': -1, 'Severity_ep_mean': -1, 'Severity_ep_sd': -1, 'Severity_ep_n': -1, 'Severity_scale': 'ISI', 'dropout': 5, 'SE_mean': -1, 'SE_sd': -1, 'SE_n': -1, 'TST_mean': -1, 'TST_sd': -1, 'TST_n': -1, 'SOL_mean': -1, 'SOL_sd': -1, 'SOL_n': -1, 'WASO_mean': -1, 'WASO_sd': -1, 'WASO_n': -1, 'Sleep_diary_weeks': -1, 'r_long': 15, 'r_long_scale_used': 'ISI', 'Severity_mean_long': -1, 'Severity_sd_long': -1, 'Severity_n_long': -1, 'Severity_ch_mean_long': -1, 'Severity_ch_sd_long': -1, 'Severity_ch_n_long': -1, 'r_weeks_long': 36}}
# n_index:  5
# fold_index:  0
# eval_index:  4
# 🍩 https://wandb.ai/srws-psg/data_extraction_integrate/r/call/9ef098b0-6326-4edb-8f9b-d6a2178c8092
# arms_num:  2
# arms_list:  ['Mindfulness smartphone application', 'Progressive muscle relaxation (PMR) smartphone application']
# arm_num:  0
# 🍩 https://wandb.ai/srws-psg/data_extraction_integrate/r/call/55373a41-16ad-4375-9f7b-12f3b50b64dd
# arm_num:  1
# 🍩 https://wandb.ai/srws-psg/data_extraction_integrate/r/call/7bd23982-4577-43c5-bc79-4b12b7b2517b
# log has been created:  {'Mindfulness smartphone application': {'Year': 2020, 'ind_clu': 'individual', 'ICC_for_cRCT': 0.05, 'Country': 'Australia', 'Single_multi': 'single', 'Age_mean': 36.39, 'Age_sd': 11.74, 'Age_n': 23, 'F_n': 3, 'Hyp_n': -1, 'Insomnia_diagnosis': '2. informal_ISI', 'Primary_insomnia_n': -1, 'Comorbidities': '0. primary_insomnia', 'se': 0, 'sd': 1, 'cr': 0, 'cw': 0, 'sr': 0, 'sc': 0, 're': 1, 'pi': 0, 'w': 0, 'dt': 0, 'ns': 0, 'he': 0, 'tg': 0, 'ind': 0, 'gp': 0, 'ff': 0, 'ae': 0, 'n': 12, 'remission': -1, 'def_remission_response': '-1', 'scale_used': 'ISI', 'Severity_bl_mean': 13.33, 'Severity_bl_sd': 3.47, 'Severity_bl_n': 12, 'Severity_ch_mean': -1, 'Severity_ch_sd': -1, 'Severity_ch_n': -1, 'Severity_ep_mean': 7.67, 'Severity_ep_sd': 3.28, 'Severity_ep_n': 12, 'Severity_scale': 'ISI', 'dropout': 0, 'SE_mean': 86.2, 'SE_sd': 3.6, 'SE_n': 10, 'TST_mean': 447.3, 'TST_sd': 87.11, 'TST_n': 10, 'SOL_mean': 3, 'SOL_sd': 2.07, 'SOL_n': 10, 'WASO_mean': 64.4, 'WASO_sd': 23.48, 'WASO_n': 10, 'Sleep_diary_weeks': 8, 'r_long': -1, 'r_long_scale_used': '-1', 'Severity_mean_long': -1, 'Severity_sd_long': -1, 'Severity_n_long': -1, 'Severity_ch_mean_long': -1, 'Severity_ch_sd_long': -1, 'Severity_ch_n_long': -1, 'r_weeks_long': -1}, 'Progressive muscle relaxation (PMR) smartphone application': {'Year': 2020, 'ind_clu': 'individual', 'ICC_for_cRCT': 0.05, 'Country': 'Australia', 'Single_multi': 'single', 'Age_mean': 36.39, 'Age_sd': 11.74, 'Age_n': 23, 'F_n': -1, 'Hyp_n': -1, 'Insomnia_diagnosis': '2. informal_ISI', 'Primary_insomnia_n': -1, 'Comorbidities': '0. primary_insomnia', 'se': 0, 'sd': 0, 'cr': 0, 'cw': 0, 'sr': 0, 'sc': 0, 're': 1, 'pi': 0, 'w': 0, 'dt': 0, 'ns': 0, 'he': 0, 'tg': 0, 'ind': 0, 'gp': 0, 'ff': 0, 'ae': 0, 'n': 11, 'remission': -1, 'def_remission_response': '-1', 'scale_used': 'ISI', 'Severity_bl_mean': 13.91, 'Severity_bl_sd': 1.97, 'Severity_bl_n': 11, 'Severity_ch_mean': -1, 'Severity_ch_sd': -1, 'Severity_ch_n': -1, 'Severity_ep_mean': 7.73, 'Severity_ep_sd': 4.03, 'Severity_ep_n': 11, 'Severity_scale': 'ISI', 'dropout': 0, 'SE_mean': 83.8, 'SE_sd': 3.4, 'SE_n': 10, 'TST_mean': 428.4, 'TST_sd': 39.59, 'TST_n': 10, 'SOL_mean': 5.6, 'SOL_sd': 3.83, 'SOL_n': 10, 'WASO_mean': 75.9, 'WASO_sd': 24.64, 'WASO_n': 10, 'Sleep_diary_weeks': -1, 'r_long': -1, 'r_long_scale_used': '-1', 'Severity_mean_long': -1, 'Severity_sd_long': -1, 'Severity_n_long': -1, 'Severity_ch_mean_long': -1, 'Severity_ch_sd_long': -1, 'Severity_ch_n_long': -1, 'r_weeks_long': -1}}
# n_index:  5
# fold_index:  1
# eval_index:  0
# 🍩 https://wandb.ai/srws-psg/data_extraction_integrate/r/call/9a5c209b-9b00-44b3-965d-1d60e30d0802
# arms_num:  2
# arms_list:  ['Brief Behavioral Treatment for Insomnia (BBTI)', 'Waitlist control']
# arm_num:  0
# 🍩 https://wandb.ai/srws-psg/data_extraction_integrate/r/call/0cacfd66-e220-4b5a-b217-8fd41c8d93d5
# arm_num:  1
# 🍩 https://wandb.ai/srws-psg/data_extraction_integrate/r/call/2c3aef0c-f71b-44bd-9be6-12035e6284a8
# log has been created:  {'Brief Behavioral Treatment for Insomnia (BBTI)': {'Year': 2021, 'ind_clu': 'individual', 'ICC_for_cRCT': 0.05, 'Country': 'USA', 'Single_multi': 'single', 'Age_mean': 21, 'Age_sd': 4.85, 'Age_n': 28, 'F_n': 16, 'Hyp_n': 28, 'Insomnia_diagnosis': '2. informal_ISI', 'Primary_insomnia_n': 15, 'Comorbidities': '2. psy_PTSD', 'se': 1, 'sd': 1, 'cr': 0, 'cw': 0, 'sr': 1, 'sc': 1, 're': 0, 'pi': 0, 'w': 0, 'dt': 0, 'ns': 0, 'he': 0, 'tg': 1, 'ind': 1, 'gp': 0, 'ff': 1, 'ae': 0, 'n': 28, 'remission': 13, 'def_remission_response': 'Patients were classified as improved if at posttreatment they showed a mean TST of 6.5 hours or longer, a mean TWT of less than 60 minutes, and a mean SE of 85% or greater; otherwise, patients were labeled unimproved.', 'scale_used': 'ISI', 'Severity_bl_mean': 16.86, 'Severity_bl_sd': 4.04, 'Severity_bl_n': 28, 'Severity_ch_mean': -11.55, 'Severity_ch_sd': 4.7, 'Severity_ch_n': 13, 'Severity_ep_mean': 5.31, 'Severity_ep_sd': 4.7, 'Severity_ep_n': 13, 'Severity_scale': 'ISI', 'dropout': 15, 'SE_mean': 87, 'SE_sd': 19.0, 'SE_n': 5, 'TST_mean': 5.78, 'TST_sd': 2.66, 'TST_n': 5, 'SOL_mean': 17.79, 'SOL_sd': 28.19, 'SOL_n': 5, 'WASO_mean': 4.39, 'WASO_sd': 3.03, 'WASO_n': 5, 'Sleep_diary_weeks': 4, 'r_long': 12, 'r_long_scale_used': 'ISI', 'Severity_mean_long': 5.7, 'Severity_sd_long': 4.19, 'Severity_n_long': 12, 'Severity_ch_mean_long': -11.16, 'Severity_ch_sd_long': 4.19, 'Severity_ch_n_long': 12, 'r_weeks_long': 12}, 'Waitlist control': {'Year': 2021, 'ind_clu': 'individual', 'ICC_for_cRCT': 0.05, 'Country': 'USA', 'Single_multi': 'single', 'Age_mean': 20.39, 'Age_sd': 2.79, 'Age_n': 28, 'F_n': 11, 'Hyp_n': 28, 'Insomnia_diagnosis': 'ISI', 'Primary_insomnia_n': 18, 'Comorbidities': '2. psy_mixed', 'se': 0, 'sd': 0, 'cr': 0, 'cw': 0, 'sr': 0, 'sc': 0, 're': 0, 'pi': 0, 'w': 1, 'dt': 0, 'ns': 0, 'he': 0, 'tg': 0, 'ind': 0, 'gp': 0, 'ff': 0, 'ae': 0, 'n': 28, 'remission': 0, 'def_remission_response': '-1', 'scale_used': 'ISI', 'Severity_bl_mean': 16.07, 'Severity_bl_sd': 4.49, 'Severity_bl_n': 28, 'Severity_ch_mean': -1.34, 'Severity_ch_sd': 0.32, 'Severity_ch_n': 28, 'Severity_ep_mean': 11.31, 'Severity_ep_sd': 6.47, 'Severity_ep_n': 28, 'Severity_scale': 'ISI', 'dropout': 17, 'SE_mean': 0.83, 'SE_sd': 0.03, 'SE_n': 4, 'TST_mean': 6.81, 'TST_sd': 1.03, 'TST_n': 4, 'SOL_mean': 23.31, 'SOL_sd': 13.12, 'SOL_n': 4, 'WASO_mean': 29.57, 'WASO_sd': 26.73, 'WASO_n': 4, 'Sleep_diary_weeks': 4, 'r_long': 0, 'r_long_scale_used': 'ISI', 'Severity_mean_long': 9.73, 'Severity_sd_long': 6.11, 'Severity_n_long': 11, 'Severity_ch_mean_long': -1.34, 'Severity_ch_sd_long': 0.32, 'Severity_ch_n_long': 28, 'r_weeks_long': 12}}
# n_index:  5
# fold_index:  1
# eval_index:  1
# 🍩 https://wandb.ai/srws-psg/data_extraction_integrate/r/call/e1400d85-69d2-40c4-9493-590dc9fc32cc
# arms_num:  2
# arms_list:  ['digital cognitive behavioral therapy (dCBT)', 'wait-list control (WLC)']
# arm_num:  0
# 🍩 https://wandb.ai/srws-psg/data_extraction_integrate/r/call/fd7f3783-0fec-4adf-859f-b40acc21d19f
# arm_num:  1
# 🍩 https://wandb.ai/srws-psg/data_extraction_integrate/r/call/63ab8266-b6e7-4b56-870e-eed5e6ad28fa
# log has been created:  {'digital cognitive behavioral therapy (dCBT)': {'Year': 2020, 'ind_clu': 'individual', 'ICC_for_cRCT': 0, 'Country': 'United Kingdom', 'Single_multi': 'single', 'Age_mean': 52.5, 'Age_sd': 11.2, 'Age_n': 205, 'F_n': 175, 'Hyp_n': 205, 'Insomnia_diagnosis': '1. formal_DSM', 'Primary_insomnia_n': 205, 'Comorbidities': '0. primary_insomnia', 'se': 1, 'sd': 1, 'cr': 1, 'cw': 1, 'sr': 1, 'sc': 1, 're': 1, 'pi': 1, 'w': 0, 'dt': 0, 'ns': 0, 'he': 0, 'tg': 0, 'ind': 0, 'gp': 0, 'ff': 0, 'ae': 1, 'n': 205, 'remission': -1, 'def_remission_response': '-1', 'scale_used': 'ISI', 'Severity_bl_mean': 18.4, 'Severity_bl_sd': 3.7, 'Severity_bl_n': 205, 'Severity_ch_mean': -1, 'Severity_ch_sd': -1, 'Severity_ch_n': -1, 'Severity_ep_mean': 10.65, 'Severity_ep_sd': 5.12, 'Severity_ep_n': 205, 'Severity_scale': 'ISI', 'dropout': 49, 'SE_mean': 78.05, 'SE_sd': 15.12, 'SE_n': 205, 'TST_mean': -1, 'TST_sd': -1, 'TST_n': -1, 'SOL_mean': -1, 'SOL_sd': -1, 'SOL_n': -1, 'WASO_mean': -1, 'WASO_sd': -1, 'WASO_n': -1, 'Sleep_diary_weeks': 10, 'r_long': -1, 'r_long_scale_used': 'ISI', 'Severity_mean_long': 9.82, 'Severity_sd_long': 5.41, 'Severity_n_long': 205, 'Severity_ch_mean_long': -1, 'Severity_ch_sd_long': -1, 'Severity_ch_n_long': -1, 'r_weeks_long': 24}, 'wait-list control (WLC)': {'Year': 2020, 'ind_clu': 'individual', 'ICC_for_cRCT': 0.05, 'Country': 'United Kingdom', 'Single_multi': 'single', 'Age_mean': 52.4, 'Age_sd': 11.7, 'Age_n': 205, 'F_n': 180, 'Hyp_n': 205, 'Insomnia_diagnosis': '1. formal_DSM', 'Primary_insomnia_n': 205, 'Comorbidities': '0. primary_insomnia', 'se': 0, 'sd': 0, 'cr': 0, 'cw': 0, 'sr': 0, 'sc': 0, 're': 0, 'pi': 0, 'w': 1, 'dt': 0, 'ns': 0, 'he': 0, 'tg': 0, 'ind': 0, 'gp': 0, 'ff': 0, 'ae': 0, 'n': 205, 'remission': 0, 'def_remission_response': '-1', 'scale_used': 'ISI', 'Severity_bl_mean': 17.9, 'Severity_bl_sd': 3.6, 'Severity_bl_n': 205, 'Severity_ch_mean': -1, 'Severity_ch_sd': -1, 'Severity_ch_n': -1, 'Severity_ep_mean': 15.49, 'Severity_ep_sd': 4.84, 'Severity_ep_n': 205, 'Severity_scale': 'ISI', 'dropout': 24, 'SE_mean': 64.54, 'SE_sd': 14.19, 'SE_n': 205, 'TST_mean': -1, 'TST_sd': -1, 'TST_n': -1, 'SOL_mean': -1, 'SOL_sd': -1, 'SOL_n': -1, 'WASO_mean': -1, 'WASO_sd': -1, 'WASO_n': -1, 'Sleep_diary_weeks': 10, 'r_long': 0, 'r_long_scale_used': 'ISI', 'Severity_mean_long': -1, 'Severity_sd_long': -1, 'Severity_n_long': -1, 'Severity_ch_mean_long': -1, 'Severity_ch_sd_long': -1, 'Severity_ch_n_long': -1, 'r_weeks_long': 24}}
# n_index:  5
# fold_index:  1
# eval_index:  2
# 🍩 https://wandb.ai/srws-psg/data_extraction_integrate/r/call/d4b219bf-6e0c-47fa-9d00-fd577078ada3
# arms_num:  2
# arms_list:  ['CBT-I', 'Waitlist Control']
# arm_num:  0
# 🍩 https://wandb.ai/srws-psg/data_extraction_integrate/r/call/517cee19-ec12-4e6e-9591-1fe8b46260c0
# arm_num:  1
# 🍩 https://wandb.ai/srws-psg/data_extraction_integrate/r/call/b67f9efa-c1ee-4e80-b979-a5ca6430571a
# log has been created:  {'CBT-I': {'Year': 2012, 'ind_clu': 'individual', 'ICC_for_cRCT': 0.05, 'Country': 'Sweden', 'Single_multi': 'multi', 'Age_mean': 57.8, 'Age_sd': 6.6, 'Age_n': 17, 'F_n': 10, 'Hyp_n': 5, 'Insomnia_diagnosis': '1. formal_DSM', 'Primary_insomnia_n': 0, 'Comorbidities': '2. psy_mixed', 'se': 1, 'sd': 1, 'cr': 1, 'cw': 1, 'sr': 1, 'sc': 1, 're': 1, 'pi': 0, 'w': 0, 'dt': 0, 'ns': 0, 'he': 1, 'tg': 1, 'ind': 1, 'gp': 0, 'ff': 1, 'ae': 0, 'n': 17, 'remission': 4, 'def_remission_response': 'Treatment remission on the ISI was defined as an ISI score less than 8 points at post-treatment or follow-up (Morin et al., 2009).', 'scale_used': 'ISI', 'Severity_bl_mean': 17.6, 'Severity_bl_sd': 4, 'Severity_bl_n': 17, 'Severity_ch_mean': -7.1, 'Severity_ch_sd': 4.4, 'Severity_ch_n': 17, 'Severity_ep_mean': 10.5, 'Severity_ep_sd': 4.4, 'Severity_ep_n': 17, 'Severity_scale': 'ISI', 'dropout': 2, 'SE_mean': -1, 'SE_sd': -1, 'SE_n': -1, 'TST_mean': 385.3, 'TST_sd': 22.7, 'TST_n': 17, 'SOL_mean': -1, 'SOL_sd': -1, 'SOL_n': -1, 'WASO_mean': -1, 'WASO_sd': -1, 'WASO_n': -1, 'Sleep_diary_weeks': 8, 'r_long': 3, 'r_long_scale_used': 'ISI', 'Severity_mean_long': 11.3, 'Severity_sd_long': 6.8, 'Severity_n_long': 17, 'Severity_ch_mean_long': -6.3, 'Severity_ch_sd_long': 6.8, 'Severity_ch_n_long': 17, 'r_weeks_long': 20}, 'Waitlist Control': {'Year': 2012, 'ind_clu': 'individual', 'ICC_for_cRCT': 0.05, 'Country': 'Sweden', 'Single_multi': 'multi', 'Age_mean': 53.6, 'Age_sd': 10.4, 'Age_n': 15, 'F_n': 10, 'Hyp_n': 5, 'Insomnia_diagnosis': '1. formal_DSM', 'Primary_insomnia_n': 0, 'Comorbidities': '2. psy_mixed', 'se': 0, 'sd': 1, 'cr': 0, 'cw': 0, 'sr': 0, 'sc': 0, 're': 0, 'pi': 0, 'w': 1, 'dt': 0, 'ns': 0, 'he': 0, 'tg': 0, 'ind': 0, 'gp': 0, 'ff': 0, 'ae': 0, 'n': 15, 'remission': 0, 'def_remission_response': 'Treatment remission on the ISI was defined as an ISI score less than 8 points at post-treatment or follow-up (Morin et al., 2009).', 'scale_used': 'ISI', 'Severity_bl_mean': 19, 'Severity_bl_sd': 5.7, 'Severity_bl_n': 15, 'Severity_ch_mean': -1.7, 'Severity_ch_sd': 0.4, 'Severity_ch_n': 15, 'Severity_ep_mean': 18.1, 'Severity_ep_sd': 5.3, 'Severity_ep_n': 15, 'Severity_scale': 'ISI', 'dropout': 0, 'SE_mean': -1, 'SE_sd': -1, 'SE_n': -1, 'TST_mean': 383.7, 'TST_sd': 60.7, 'TST_n': 15, 'SOL_mean': -1, 'SOL_sd': -1, 'SOL_n': -1, 'WASO_mean': -1, 'WASO_sd': -1, 'WASO_n': -1, 'Sleep_diary_weeks': 8, 'r_long': 0, 'r_long_scale_used': 'ISI', 'Severity_mean_long': 18.2, 'Severity_sd_long': 4.9, 'Severity_n_long': 15, 'Severity_ch_mean_long': -0.8, 'Severity_ch_sd_long': 0.3, 'Severity_ch_n_long': 15, 'r_weeks_long': 20}}
# n_index:  5
# fold_index:  1
# eval_index:  3
# 🍩 https://wandb.ai/srws-psg/data_extraction_integrate/r/call/cd2a4dfb-8553-407a-a2be-06776cdc5027
# arms_num:  4
# arms_list:  ['intensive sleep retraining (ISR)', 'stimulus control therapy (SCT)', 'ISR plus SCT', 'control (sleep hygiene)']
# arm_num:  0
# 🍩 https://wandb.ai/srws-psg/data_extraction_integrate/r/call/e2837968-aaff-4815-aa11-41c76e05f92d
# arm_num:  1
# 🍩 https://wandb.ai/srws-psg/data_extraction_integrate/r/call/82e0171e-c413-49a7-ae9e-6f3a71abf2c3
# arm_num:  2
# 🍩 https://wandb.ai/srws-psg/data_extraction_integrate/r/call/cc118e8e-0ca2-42db-9d28-a1663b838eeb
# arm_num:  3
# 🍩 https://wandb.ai/srws-psg/data_extraction_integrate/r/call/862e51ab-e496-4017-9a37-10ea9624436f
# log has been created:  {'intensive sleep retraining (ISR)': {'Year': 2012, 'ind_clu': 'individual', 'ICC_for_cRCT': 0.05, 'Country': 'Australia', 'Single_multi': 'single', 'Age_mean': 38.53, 'Age_sd': 13.3, 'Age_n': 19, 'F_n': 11, 'Hyp_n': 19, 'Insomnia_diagnosis': '1. formal_ICSD', 'Primary_insomnia_n': 19, 'Comorbidities': '0. primary_insomnia', 'se': 1, 'sd': 1, 'cr': 0, 'cw': 0, 'sr': 0, 'sc': 0, 're': 0, 'pi': 0, 'w': 0, 'dt': 0, 'ns': 0, 'he': 0, 'tg': 0, 'ind': 0, 'gp': 0, 'ff': 1, 'ae': 0, 'n': 19, 'remission': -1, 'def_remission_response': '-1', 'scale_used': 'PSQI', 'Severity_bl_mean': -1, 'Severity_bl_sd': -1, 'Severity_bl_n': -1, 'Severity_ch_mean': -1, 'Severity_ch_sd': -1, 'Severity_ch_n': -1, 'Severity_ep_mean': -1, 'Severity_ep_sd': -1, 'Severity_ep_n': -1, 'Severity_scale': 'PSQI', 'dropout': 3, 'SE_mean': -1, 'SE_sd': -1, 'SE_n': -1, 'TST_mean': -1, 'TST_sd': -1, 'TST_n': -1, 'SOL_mean': -1, 'SOL_sd': -1, 'SOL_n': -1, 'WASO_mean': -1, 'WASO_sd': -1, 'WASO_n': -1, 'Sleep_diary_weeks': -1, 'r_long': -1, 'r_long_scale_used': 'PSQI', 'Severity_mean_long': -1, 'Severity_sd_long': -1, 'Severity_n_long': -1, 'Severity_ch_mean_long': -1, 'Severity_ch_sd_long': -1, 'Severity_ch_n_long': -1, 'r_weeks_long': -1}, 'stimulus control therapy (SCT)': {'Year': 2012, 'ind_clu': 'individual', 'ICC_for_cRCT': 0.05, 'Country': 'Australia', 'Single_multi': 'single', 'Age_mean': 42.2, 'Age_sd': 13.1, 'Age_n': 20, 'F_n': 15, 'Hyp_n': 20, 'Insomnia_diagnosis': '2. informal_PSQI', 'Primary_insomnia_n': 20, 'Comorbidities': '0. primary_insomnia', 'se': 1, 'sd': 1, 'cr': 0, 'cw': 0, 'sr': 0, 'sc': 1, 're': 0, 'pi': 0, 'w': 0, 'dt': 0, 'ns': 0, 'he': 1, 'tg': 1, 'ind': 1, 'gp': 0, 'ff': 1, 'ae': 0, 'n': 20, 'remission': 6, 'def_remission_response': 'Criteria 1 = (a) reduction of SOL from Pre-treatment to Follow-up 1 to an average of < 30 min, or a reduction of SOL by ≥ 50%, and (b) sleep efficiency increase to ≥ 85%. Criterion 2 = a reduction in SOL by 33% to < 35 minutes.', 'scale_used': 'PSQI', 'Severity_bl_mean': -1, 'Severity_bl_sd': -1, 'Severity_bl_n': -1, 'Severity_ch_mean': -1, 'Severity_ch_sd': -1, 'Severity_ch_n': -1, 'Severity_ep_mean': -1, 'Severity_ep_sd': -1, 'Severity_ep_n': -1, 'Severity_scale': 'PSQI', 'dropout': 3, 'SE_mean': -1, 'SE_sd': -1, 'SE_n': -1, 'TST_mean': -1, 'TST_sd': -1, 'TST_n': -1, 'SOL_mean': -1, 'SOL_sd': -1, 'SOL_n': -1, 'WASO_mean': -1, 'WASO_sd': -1, 'WASO_n': -1, 'Sleep_diary_weeks': -1, 'r_long': 6, 'r_long_scale_used': 'PSQI', 'Severity_mean_long': -1, 'Severity_sd_long': -1, 'Severity_n_long': -1, 'Severity_ch_mean_long': -1, 'Severity_ch_sd_long': -1, 'Severity_ch_n_long': -1, 'r_weeks_long': 24}, 'ISR plus SCT': {'Year': 2012, 'ind_clu': 'individual', 'ICC_for_cRCT': 0.05, 'Country': 'Australia', 'Single_multi': 'multi', 'Age_mean': 36.9, 'Age_sd': 11.5, 'Age_n': 20, 'F_n': 17, 'Hyp_n': 20, 'Insomnia_diagnosis': '1. formal_ICSD', 'Primary_insomnia_n': 20, 'Comorbidities': '0. primary_insomnia', 'se': 1, 'sd': 1, 'cr': 0, 'cw': 0, 'sr': 0, 'sc': 1, 're': 0, 'pi': 0, 'w': 0, 'dt': 0, 'ns': 0, 'he': 1, 'tg': 1, 'ind': 1, 'gp': 0, 'ff': 1, 'ae': 0, 'n': 20, 'remission': 12, 'def_remission_response': '(a) reduction of SOL from Pre-treatment to Follow-up 1 to an average of < 30 min, or a reduction of SOL by ≥ 50%, and (b) sleep efficiency increase to ≥ 85%.', 'scale_used': 'PSQI', 'Severity_bl_mean': -1, 'Severity_bl_sd': -1, 'Severity_bl_n': -1, 'Severity_ch_mean': -1, 'Severity_ch_sd': -1, 'Severity_ch_n': -1, 'Severity_ep_mean': -1, 'Severity_ep_sd': -1, 'Severity_ep_n': -1, 'Severity_scale': 'PSQI', 'dropout': 0, 'SE_mean': -1, 'SE_sd': -1, 'SE_n': -1, 'TST_mean': -1, 'TST_sd': -1, 'TST_n': -1, 'SOL_mean': -1, 'SOL_sd': -1, 'SOL_n': -1, 'WASO_mean': -1, 'WASO_sd': -1, 'WASO_n': -1, 'Sleep_diary_weeks': -1, 'r_long': -1, 'r_long_scale_used': 'PSQI', 'Severity_mean_long': -1, 'Severity_sd_long': -1, 'Severity_n_long': -1, 'Severity_ch_mean_long': -1, 'Severity_ch_sd_long': -1, 'Severity_ch_n_long' ...
# n_index:  5
# fold_index:  1
# eval_index:  4
# 🍩 https://wandb.ai/srws-psg/data_extraction_integrate/r/call/86e0385d-2ee5-40bd-9c3c-acd4cc934512
# arms_num:  2
# arms_list:  ['CBTI-BP with RISE-UP', 'Psychoeducation (PE)']
# arm_num:  0
# 🍩 https://wandb.ai/srws-psg/data_extraction_integrate/r/call/580afdc1-7f3b-4fad-923b-e46c168ef500
# arm_num:  1
# 🍩 https://wandb.ai/srws-psg/data_extraction_integrate/r/call/7f3e9320-52bc-440b-a028-a445145f352e
# log has been created:  {'CBTI-BP with RISE-UP': {'Year': 2018, 'ind_clu': 'individual', 'ICC_for_cRCT': 0.05, 'Country': 'USA', 'Single_multi': 'multi', 'Age_mean': 39.3, 'Age_sd': 14.2, 'Age_n': 20, 'F_n': 14, 'Hyp_n': 8, 'Insomnia_diagnosis': '1. formal_Edinger2004', 'Primary_insomnia_n': 20, 'Comorbidities': '2. psy_bipolar', 'se': 1, 'sd': 1, 'cr': 1, 'cw': 1, 'sr': 1, 'sc': 1, 're': 1, 'pi': 0, 'w': 0, 'dt': 0, 'ns': 0, 'he': 1, 'tg': 1, 'ind': 1, 'gp': 0, 'ff': 1, 'ae': 0, 'n': 20, 'remission': -1, 'def_remission_response': '-1', 'scale_used': 'ISI', 'Severity_bl_mean': 18.4, 'Severity_bl_sd': 4.9, 'Severity_bl_n': 20, 'Severity_ch_mean': -1, 'Severity_ch_sd': -1, 'Severity_ch_n': -1, 'Severity_ep_mean': -1, 'Severity_ep_sd': -1, 'Severity_ep_n': -1, 'Severity_scale': 'ISI', 'dropout': 1, 'SE_mean': -1, 'SE_sd': -1, 'SE_n': -1, 'TST_mean': -1, 'TST_sd': -1, 'TST_n': -1, 'SOL_mean': -1, 'SOL_sd': -1, 'SOL_n': -1, 'WASO_mean': -1, 'WASO_sd': -1, 'WASO_n': -1, 'Sleep_diary_weeks': 1, 'r_long': -1, 'r_long_scale_used': '-1', 'Severity_mean_long': -1, 'Severity_sd_long': -1, 'Severity_n_long': -1, 'Severity_ch_mean_long': -1, 'Severity_ch_sd_long': -1, 'Severity_ch_n_long': -1, 'r_weeks_long': -1}, 'Psychoeducation (PE)': {'Year': 2018, 'ind_clu': 'individual', 'ICC_for_cRCT': 0.05, 'Country': 'USA', 'Single_multi': 'multi', 'Age_mean': 35.4, 'Age_sd': 8.9, 'Age_n': 20, 'F_n': 13, 'Hyp_n': 9, 'Insomnia_diagnosis': '1. formal_Edinger2004', 'Primary_insomnia_n': 20, 'Comorbidities': '2. psy_bipolar', 'se': 1, 'sd': 1, 'cr': 0, 'cw': 0, 'sr': 0, 'sc': 0, 're': 0, 'pi': 0, 'w': 0, 'dt': 0, 'ns': 0, 'he': 0, 'tg': 0, 'ind': 0, 'gp': 0, 'ff': 0, 'ae': 0, 'n': 20, 'remission': -1, 'def_remission_response': '-1', 'scale_used': 'ISI', 'Severity_bl_mean': 18.8, 'Severity_bl_sd': 4.4, 'Severity_bl_n': 20, 'Severity_ch_mean': -1, 'Severity_ch_sd': -1, 'Severity_ch_n': -1, 'Severity_ep_mean': -1, 'Severity_ep_sd': -1, 'Severity_ep_n': -1, 'Severity_scale': 'ISI', 'dropout': 1, 'SE_mean': -1, 'SE_sd': -1, 'SE_n': -1, 'TST_mean': -1, 'TST_sd': -1, 'TST_n': -1, 'SOL_mean': -1, 'SOL_sd': -1, 'SOL_n': -1, 'WASO_mean': -1, 'WASO_sd': -1, 'WASO_n': -1, 'Sleep_diary_weeks': -1, 'r_long': -1, 'r_long_scale_used': '-1', 'Severity_mean_long': -1, 'Severity_sd_long': -1, 'Severity_n_long': -1, 'Severity_ch_mean_long': -1, 'Severity_ch_sd_long': -1, 'Severity_ch_n_long': -1, 'r_weeks_long': -1}}
# n_index:  5
# fold_index:  2
# eval_index:  0
# 🍩 https://wandb.ai/srws-psg/data_extraction_integrate/r/call/26190825-ab42-447d-b61b-7349b4ba9d12
# arms_num:  2
# arms_list:  ['digital Cognitive Behavioral Therapy for Insomnia (dCBT-I)', 'face-to-face Cognitive Behavioral Therapy for Insomnia (FtF CBT-I)']
# arm_num:  0
# 🍩 https://wandb.ai/srws-psg/data_extraction_integrate/r/call/e5745e05-6d75-47f3-9876-3f9b742f8836
# arm_num:  1
# 🍩 https://wandb.ai/srws-psg/data_extraction_integrate/r/call/91f34434-0554-4ddd-8879-a4f75444eeb4
# log has been created:  {'digital Cognitive Behavioral Therapy for Insomnia (dCBT-I)': {'Year': 2021, 'ind_clu': 'individual', 'ICC_for_cRCT': 0, 'Country': 'Norway', 'Single_multi': 'single', 'Age_mean': 41.4, 'Age_sd': 10.5, 'Age_n': 49, 'F_n': 35, 'Hyp_n': 49, 'Insomnia_diagnosis': '1. formal_DSM', 'Primary_insomnia_n': 49, 'Comorbidities': '1. primary_secondary_mixed', 'se': 1, 'sd': 1, 'cr': 1, 'cw': 1, 'sr': 1, 'sc': 1, 're': 1, 'pi': 0, 'w': 0, 'dt': 0, 'ns': 0, 'he': 0, 'tg': 0, 'ind': 0, 'gp': 0, 'ff': 0, 'ae': 0, 'n': 49, 'remission': 10, 'def_remission_response': 'A reduction in ISI scores of 8 or more points from baseline is regarded as a response to treatment, and an absolute score on the ISI of 7 points or less is regarded as remission.', 'scale_used': 'ISI', 'Severity_bl_mean': 19.4, 'Severity_bl_sd': 4.1, 'Severity_bl_n': 49, 'Severity_ch_mean': -7.1, 'Severity_ch_sd': 6.9, 'Severity_ch_n': 49, 'Severity_ep_mean': 12.3, 'Severity_ep_sd': 6.9, 'Severity_ep_n': 49, 'Severity_scale': 'ISI', 'dropout': 8, 'SE_mean': 79.9, 'SE_sd': 14.3, 'SE_n': 30, 'TST_mean': 6.05, 'TST_sd': 1.45, 'TST_n': 30, 'SOL_mean': 28.6, 'SOL_sd': 31.2, 'SOL_n': 30, 'WASO_mean': 34.2, 'WASO_sd': 27.8, 'WASO_n': 30, 'Sleep_diary_weeks': 33, 'r_long': 19, 'r_long_scale_used': 'ISI', 'Severity_mean_long': 12.3, 'Severity_sd_long': 6.9, 'Severity_n_long': 49, 'Severity_ch_mean_long': -7.1, 'Severity_ch_sd_long': 6.9, 'Severity_ch_n_long': 49, 'r_weeks_long': 33}, 'face-to-face Cognitive Behavioral Therapy for Insomnia (FtF CBT-I)': {'Year': 2021, 'ind_clu': 'individual', 'ICC_for_cRCT': 0, 'Country': 'Norway', 'Single_multi': 'single', 'Age_mean': 41.3, 'Age_sd': 12.5, 'Age_n': 52, 'F_n': 41, 'Hyp_n': 33, 'Insomnia_diagnosis': '1. formal_DSM', 'Primary_insomnia_n': 52, 'Comorbidities': '1. primary_secondary_mixed', 'se': 1, 'sd': 1, 'cr': 1, 'cw': 1, 'sr': 1, 'sc': 1, 're': 1, 'pi': 0, 'w': 0, 'dt': 0, 'ns': 0, 'he': 0, 'tg': 1, 'ind': 1, 'gp': 0, 'ff': 1, 'ae': 0, 'n': 52, 'remission': 27, 'def_remission_response': 'A reduction in ISI scores of 8 or more points from baseline is regarded as a response to treatment, and an absolute score on the ISI of 7 points or less is regarded as remission.', 'scale_used': 'ISI', 'Severity_bl_mean': 18.4, 'Severity_bl_sd': 3.7, 'Severity_bl_n': 52, 'Severity_ch_mean': -9.5, 'Severity_ch_sd': 5.1, 'Severity_ch_n': 52, 'Severity_ep_mean': 8.9, 'Severity_ep_sd': 6, 'Severity_ep_n': 52, 'Severity_scale': 'ISI', 'dropout': 1, 'SE_mean': 79.9, 'SE_sd': 14.3, 'SE_n': 30, 'TST_mean': 6.08, 'TST_sd': 1.34, 'TST_n': 40, 'SOL_mean': 27.1, 'SOL_sd': 21.9, 'SOL_n': 40, 'WASO_mean': 39.1, 'WASO_sd': 53.6, 'WASO_n': 40, 'Sleep_diary_weeks': 33, 'r_long': 31, 'r_long_scale_used': 'ISI', 'Severity_mean_long': 8.9, 'Severity_sd_long': 6, 'Severity_n_long': 48, 'Severity_ch_mean_long': -9.5, 'Severity_ch_sd_long': 6, 'Severity_ch_n_long': 48, 'r_weeks_long': 33}}
# n_index:  5
# fold_index:  2
# eval_index:  1
# 🍩 https://wandb.ai/srws-psg/data_extraction_integrate/r/call/135a9a06-e13d-43ec-ae0c-aa64f943427e
# arms_num:  2
# arms_list:  ['psychoeducational intervention (PI+)', 'control (PI-)']
# arm_num:  0
# 🍩 https://wandb.ai/srws-psg/data_extraction_integrate/r/call/b285dbcd-6102-44c1-b9df-c2c1537c5e6f
# arm_num:  1
# 🍩 https://wandb.ai/srws-psg/data_extraction_integrate/r/call/1c591e13-9245-4742-9aa6-6af055d6a46d
# log has been created:  {'psychoeducational intervention (PI+)': {'Year': 2017, 'ind_clu': 'individual', 'ICC_for_cRCT': 0.05, 'Country': 'Italy', 'Single_multi': 'single', 'Age_mean': 64.42, 'Age_sd': 12.94, 'Age_n': 19, 'F_n': 9, 'Hyp_n': 0, 'Insomnia_diagnosis': '1. formal_ICSD', 'Primary_insomnia_n': 19, 'Comorbidities': '0. primary_insomnia', 'se': 1, 'sd': 1, 'cr': 0, 'cw': 0, 'sr': 0, 'sc': 0, 're': 0, 'pi': 0, 'w': 0, 'dt': 0, 'ns': 0, 'he': 0, 'tg': 0, 'ind': 0, 'gp': 0, 'ff': 1, 'ae': 0, 'n': 19, 'remission': -1, 'def_remission_response': '-1', 'scale_used': 'ISI', 'Severity_bl_mean': 15.74, 'Severity_bl_sd': 4.27, 'Severity_bl_n': 19, 'Severity_ch_mean': -3.58, 'Severity_ch_sd': 5.92, 'Severity_ch_n': 19, 'Severity_ep_mean': 12.16, 'Severity_ep_sd': 6.62, 'Severity_ep_n': 19, 'Severity_scale': 'ISI', 'dropout': 1, 'SE_mean': -1, 'SE_sd': -1, 'SE_n': -1, 'TST_mean': -1, 'TST_sd': -1, 'TST_n': -1, 'SOL_mean': -1, 'SOL_sd': -1, 'SOL_n': -1, 'WASO_mean': -1, 'WASO_sd': -1, 'WASO_n': -1, 'Sleep_diary_weeks': 2, 'r_long': -1, 'r_long_scale_used': '-1', 'Severity_mean_long': -1, 'Severity_sd_long': -1, 'Severity_n_long': -1, 'Severity_ch_mean_long': -1, 'Severity_ch_sd_long': -1, 'Severity_ch_n_long': -1, 'r_weeks_long': -1}, 'control (PI-)': {'Year': 2017, 'ind_clu': 'individual', 'ICC_for_cRCT': 0.05, 'Country': 'Italy', 'Single_multi': 'single', 'Age_mean': 59.56, 'Age_sd': 14.41, 'Age_n': 19, 'F_n': 5, 'Hyp_n': 0, 'Insomnia_diagnosis': '1. formal_ICSD', 'Primary_insomnia_n': 19, 'Comorbidities': '0. primary_insomnia', 'se': 0, 'sd': 1, 'cr': 0, 'cw': 0, 'sr': 0, 'sc': 0, 're': 0, 'pi': 0, 'w': 0, 'dt': 0, 'ns': 0, 'he': 0, 'tg': 0, 'ind': 0, 'gp': 0, 'ff': 0, 'ae': 0, 'n': 19, 'remission': -1, 'def_remission_response': '-1', 'scale_used': 'ISI', 'Severity_bl_mean': 17.78, 'Severity_bl_sd': 4.26, 'Severity_bl_n': 19, 'Severity_ch_mean': -1.67, 'Severity_ch_sd': -1, 'Severity_ch_n': 19, 'Severity_ep_mean': 13.11, 'Severity_ep_sd': 5.68, 'Severity_ep_n': 19, 'Severity_scale': 'ISI', 'dropout': 1, 'SE_mean': -1, 'SE_sd': -1, 'SE_n': -1, 'TST_mean': -1, 'TST_sd': -1, 'TST_n': -1, 'SOL_mean': -1, 'SOL_sd': -1, 'SOL_n': -1, 'WASO_mean': -1, 'WASO_sd': -1, 'WASO_n': -1, 'Sleep_diary_weeks': 2, 'r_long': -1, 'r_long_scale_used': '-1', 'Severity_mean_long': -1, 'Severity_sd_long': -1, 'Severity_n_long': -1, 'Severity_ch_mean_long': -1, 'Severity_ch_sd_long': -1, 'Severity_ch_n_long': -1, 'r_weeks_long': -1}}
# n_index:  5
# fold_index:  2
# eval_index:  2
# 🍩 https://wandb.ai/srws-psg/data_extraction_integrate/r/call/d876d487-3b96-453f-9ef2-2e349d4215a9
# arms_num:  2
# arms_list:  ['Brief Behavioral Treatment for Insomnia (BBTI)', 'Sleep Hygiene (SH) Education']
# arm_num:  0
# 🍩 https://wandb.ai/srws-psg/data_extraction_integrate/r/call/78fd356a-a1ae-46c6-af57-93e01dd7ea98
# arm_num:  1
# 🍩 https://wandb.ai/srws-psg/data_extraction_integrate/r/call/50a0e9c0-d4cc-4f67-a33f-e5cbe304ec21
# log has been created:  {'Brief Behavioral Treatment for Insomnia (BBTI)': {'Year': 2016, 'ind_clu': 'individual', 'ICC_for_cRCT': 0.05, 'Country': 'China', 'Single_multi': 'single', 'Age_mean': 42.7, 'Age_sd': 8.83, 'Age_n': 40, 'F_n': 22, 'Hyp_n': 40, 'Insomnia_diagnosis': '1. formal_ICSD', 'Primary_insomnia_n': 40, 'Comorbidities': '1. primary_secondary_mixed', 'se': 1, 'sd': 1, 'cr': 0, 'cw': 0, 'sr': 1, 'sc': 1, 're': 0, 'pi': 0, 'w': 0, 'dt': 0, 'ns': 0, 'he': 1, 'tg': 1, 'ind': 1, 'gp': 0, 'ff': 1, 'ae': 0, 'n': 40, 'remission': -1, 'def_remission_response': '-1', 'scale_used': 'ISI', 'Severity_bl_mean': 12.93, 'Severity_bl_sd': 2.89, 'Severity_bl_n': 40, 'Severity_ch_mean': -1, 'Severity_ch_sd': -1, 'Severity_ch_n': -1, 'Severity_ep_mean': 7.96, 'Severity_ep_sd': 1.99, 'Severity_ep_n': 40, 'Severity_scale': 'ISI', 'dropout': 1, 'SE_mean': 81, 'SE_sd': 10, 'SE_n': 40, 'TST_mean': 356.97, 'TST_sd': 38.84, 'TST_n': 40, 'SOL_mean': 18.1, 'SOL_sd': 8.46, 'SOL_n': 40, 'WASO_mean': 68.96, 'WASO_sd': 55.12, 'WASO_n': 40, 'Sleep_diary_weeks': 4, 'r_long': -1, 'r_long_scale_used': '-1', 'Severity_mean_long': -1, 'Severity_sd_long': -1, 'Severity_n_long': -1, 'Severity_ch_mean_long': -1, 'Severity_ch_sd_long': -1, 'Severity_ch_n_long': -1, 'r_weeks_long': -1}, 'Sleep Hygiene (SH) Education': {'Year': 2016, 'ind_clu': 'individual', 'ICC_for_cRCT': 0, 'Country': 'China', 'Single_multi': 'single', 'Age_mean': 39.63, 'Age_sd': 7.84, 'Age_n': 39, 'F_n': 21, 'Hyp_n': 39, 'Insomnia_diagnosis': '1. formal_ICSD', 'Primary_insomnia_n': 39, 'Comorbidities': '1. primary_secondary_mixed', 'se': 1, 'sd': 0, 'cr': 0, 'cw': 0, 'sr': 0, 'sc': 0, 're': 0, 'pi': 0, 'w': 0, 'dt': 0, 'ns': 0, 'he': 0, 'tg': 1, 'ind': 0, 'gp': 1, 'ff': 1, 'ae': 0, 'n': 39, 'remission': -1, 'def_remission_response': '-1', 'scale_used': 'ISI', 'Severity_bl_mean': 12, 'Severity_bl_sd': 3.12, 'Severity_bl_n': 39, 'Severity_ch_mean': -1, 'Severity_ch_sd': -1, 'Severity_ch_n': -1, 'Severity_ep_mean': 11.36, 'Severity_ep_sd': 2.52, 'Severity_ep_n': 39, 'Severity_scale': 'ISI', 'dropout': 2, 'SE_mean': 72, 'SE_sd': 14, 'SE_n': 39, 'TST_mean': 361.1, 'TST_sd': 61.49, 'TST_n': 39, 'SOL_mean': 29.7, 'SOL_sd': 13.04, 'SOL_n': 39, 'WASO_mean': 120.74, 'WASO_sd': 99.11, 'WASO_n': 39, 'Sleep_diary_weeks': 4, 'r_long': -1, 'r_long_scale_used': '-1', 'Severity_mean_long': -1, 'Severity_sd_long': -1, 'Severity_n_long': -1, 'Severity_ch_mean_long': -1, 'Severity_ch_sd_long': -1, 'Severity_ch_n_long': -1, 'r_weeks_long': -1}}
# n_index:  5
# fold_index:  2
# eval_index:  3
# 🍩 https://wandb.ai/srws-psg/data_extraction_integrate/r/call/3d0a5846-dc78-4c58-a7ae-469ed08108bd
# arms_num:  2
# arms_list:  ['intervention', 'control']
# arm_num:  0
# Exception in thread Thread-15 (_process_batches):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/weave/trace_server/async_batch_processor.py", line 61, in _process_batches
#     self.processor_fn(current_batch)
#   File "/usr/local/lib/python3.10/dist-packages/tenacity/__init__.py", line 330, in wrapped_f
#     return self(f, *args, **kw)
#   File "/usr/local/lib/python3.10/dist-packages/tenacity/__init__.py", line 467, in __call__
#     do = self.iter(retry_state=retry_state)
#   File "/usr/local/lib/python3.10/dist-packages/tenacity/__init__.py", line 368, in iter
#     result = action(retry_state)
#   File "/usr/local/lib/python3.10/dist-packages/tenacity/__init__.py", line 390, in <lambda>
#     self._add_action_func(lambda rs: rs.outcome.result())
#   File "/usr/lib/python3.10/concurrent/futures/_base.py", line 451, in result
#     return self.__get_result()
#   File "/usr/lib/python3.10/concurrent/futures/_base.py", line 403, in __get_result
#     raise self._exception
#   File "/usr/local/lib/python3.10/dist-packages/tenacity/__init__.py", line 470, in __call__
#     result = fn(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/weave/trace_server/remote_http_trace_server.py", line 140, in _flush_calls
#     self._flush_calls(batch[:split_idx], _should_update_batch_size=False)
#   File "/usr/local/lib/python3.10/dist-packages/tenacity/__init__.py", line 330, in wrapped_f
#     return self(f, *args, **kw)
#   File "/usr/local/lib/python3.10/dist-packages/tenacity/__init__.py", line 467, in __call__
#     do = self.iter(retry_state=retry_state)
#   File "/usr/local/lib/python3.10/dist-packages/tenacity/__init__.py", line 368, in iter
#     result = action(retry_state)
#   File "/usr/local/lib/python3.10/dist-packages/tenacity/__init__.py", line 390, in <lambda>
#     self._add_action_func(lambda rs: rs.outcome.result())
#   File "/usr/lib/python3.10/concurrent/futures/_base.py", line 451, in result
#     return self.__get_result()
#   File "/usr/lib/python3.10/concurrent/futures/_base.py", line 403, in __get_result
#     raise self._exception
#   File "/usr/local/lib/python3.10/dist-packages/tenacity/__init__.py", line 470, in __call__
#     result = fn(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/weave/trace_server/remote_http_trace_server.py", line 149, in _flush_calls
#     r.raise_for_status()
#   File "/usr/local/lib/python3.10/dist-packages/requests/models.py", line 1021, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 413 Client Error: Request Entity Too Large for url: https://trace.wandb.ai/call/upsert_batch
# 🍩 https://wandb.ai/srws-psg/data_extraction_integrate/r/call/5c2540bf-782d-427f-88ef-483c97f58fb3
# arm_num:  1
# 🍩 https://wandb.ai/srws-psg/data_extraction_integrate/r/call/007ce155-a6b8-4082-9e28-fc56e570eaf8
# ...
# n_index:  5
# fold_index:  9
# eval_index:  1
# 🍩 https://wandb.ai/srws-psg/data_extraction_integrate/r/call/d0b13199-d228-4df4-823c-e0541a0612d5
# arms_num:  3
# arms_list:  ['individual therapy', 'self-help with telephone support', 'waiting-list control']
# arm_num:  0
# 🍩 https://wandb.ai/srws-psg/data_extraction_integrate/r/call/5a3810d6-f97a-4920-85ae-b1ee6d448ee3
# arm_num:  1
# 🍩 https://wandb.ai/srws-psg/data_extraction_integrate/r/call/08661afd-a604-4353-97f0-6dde61e9aad6
# arm_num:  2
# 🍩 https://wandb.ai/srws-psg/data_extraction_integrate/r/call/61f73acd-f7d7-4373-a846-805e722710aa
# log has been created:  {'individual therapy': {'Year': 2004, 'ind_clu': 'individual', 'ICC_for_cRCT': 0.05, 'Country': 'Canada', 'Single_multi': 'single', 'Age_mean': 43.3, 'Age_sd': 10.9, 'Age_n': 60, 'F_n': 18, 'Hyp_n': 20, 'Insomnia_diagnosis': '1. formal_DSM', 'Primary_insomnia_n': 20, 'Comorbidities': '2. psy_mixed', 'se': 1, 'sd': 1, 'cr': 1, 'cw': 0, 'sr': 1, 'sc': 1, 're': 1, 'pi': 0, 'w': 0, 'dt': 0, 'ns': 0, 'he': 1, 'tg': 1, 'ind': 1, 'gp': 0, 'ff': 1, 'ae': 0, 'n': 20, 'remission': 12, 'def_remission_response': 'The proportion of participants who had a SOL less than 30 minutes for at least 4 nights during a week was calculated at post-treatment and the follow-up intervals. This is the conventional criterion for defining insomnia (Morin, Colecchi et al. 1999; Lichstein et al. 2003). Because the PSQI assesses sleep in a global fashion and has an evidence-based cut-off score for distinguishing clinically impaired from normal sleep (< 6; Buysse et al. 1989), it was also used in the determination of clinical significance.', 'scale_used': 'PSQI', 'Severity_bl_mean': 13.3, 'Severity_bl_sd': 3.4, 'Severity_bl_n': 20, 'Severity_ch_mean': -6.6, 'Severity_ch_sd': 3.4, 'Severity_ch_n': 20, 'Severity_ep_mean': 6.7, 'Severity_ep_sd': 3.4, 'Severity_ep_n': 20, 'Severity_scale': 'PSQI', 'dropout': 4, 'SE_mean': 87.3, 'SE_sd': 8.8, 'SE_n': 20, 'TST_mean': 6.7, 'TST_sd': 1.2, 'TST_n': 20, 'SOL_mean': 22.3, 'SOL_sd': 13.7, 'SOL_n': 20, 'WASO_mean': 36.9, 'WASO_sd': 31.7, 'WASO_n': 20, 'Sleep_diary_weeks': 7, 'r_long': 9, 'r_long_scale_used': 'PSQI', 'Severity_mean_long': 6.7, 'Severity_sd_long': 4.6, 'Severity_n_long': 18, 'Severity_ch_mean_long': -6.6, 'Severity_ch_sd_long': 4.6, 'Severity_ch_n_long': 18, 'r_weeks_long': 30}, 'self-help with telephone support': {'Year': 2004, 'ind_clu': 'individual', 'ICC_for_cRCT': 0.05, 'Country': 'Canada', 'Single_multi': 'single', 'Age_mean': 43.3, 'Age_sd': 10.9, 'Age_n': 60, 'F_n': 18, 'Hyp_n': 20, 'Insomnia_diagnosis': '1. formal_DSM', 'Primary_insomnia_n': 20, 'Comorbidities': '2. psy_substance_dependence', 'se': 1, 'sd': 1, 'cr': 1, 'cw': 0, 'sr': 1, 'sc': 1, 're': 1, 'pi': 0, 'w': 0, 'dt': 0, 'ns': 0, 'he': 1, 'tg': 1, 'ind': 0, 'gp': 0, 'ff': 0, 'ae': 0, 'n': 20, 'remission': 3, 'def_remission_response': 'A total of eight participants (five IT and three SHTS participants, 25% of treated sample) met both criteria at post-treatment.', 'scale_used': 'PSQI', 'Severity_bl_mean': 12.4, 'Severity_bl_sd': 3.7, 'Severity_bl_n': 20, 'Severity_ch_mean': -1.7, 'Severity_ch_sd': 1.7, 'Severity_ch_n': 20, 'Severity_ep_mean': 9.1, 'Severity_ep_sd': 4.2, 'Severity_ep_n': 20, 'Severity_scale': 'PSQI', 'dropout': 5, 'SE_mean': 87.1, 'SE_sd': 9.3, 'SE_n': 20, 'TST_mean': 6.5, 'TST_sd': 1.6, 'TST_n': 20, 'SOL_mean': 25, 'SOL_sd': 19.8, 'SOL_n': 20, 'WASO_mean': 40.9, 'WASO_sd': 40.5, 'WASO_n': 20, 'Sleep_diary_weeks': 7, 'r_long': 2, 'r_long_scale_used': 'PSQI', 'Severity_mean_long': 8.5, 'Severity_sd_long': 2.7, 'Severity_n_long': 20, 'Severity_ch_mean_long': -0.6, 'Severity_ch_sd_long': 0.6, 'Severity_ch_n_long': 20, 'r_weeks_long': 30}, 'waiting-list control': {'Year': 2004, 'ind_clu': 'individual', 'ICC_for_cRCT': 0.05, 'Country': 'Canada', 'Single_multi': 'single', 'Age_mean': 43.3, 'Age_sd': 10.9, 'Age_n': 60, 'F_n': 18, 'Hyp_n': 20, 'Insomnia_diagnosis': '1. formal_DSM', 'Primary_insomnia_n': 20, 'Comorbidities': '2. psy_mixed', 'se': 0, 'sd': 1, 'cr': 1, 'cw': 0, 'sr': 1, 'sc': 1, 're': 1, 'pi': 0, 'w': 1, 'dt': 0, 'ns': 0, 'he': 0, 'tg': 0, 'ind': 0, 'gp': 0, 'ff': 0, 'ae': 0, 'n': 20, 'remission': 0, 'def_remission_response': '-1', 'scale_used': 'PSQI', 'Severity_bl_mean': 13.4, 'Severity_bl_sd': 3.4, 'Severity_bl_n': 20, 'Severity_ch_mean': -1, 'Severity_ch_sd': -1, 'Severity_ch_n': -1, 'Severity_ep_mean': 11.1, 'Severity_ep_sd': 4.2, 'Severity_ep_n': 20, 'Severity_scale': 'PSQI', 'dropout': 3, 'SE_mean': 78.3, 'SE_sd': 13.4, 'SE_n': 20, 'TST_mean': 5.7, 'TST_sd': 1.2, 'TST_n': 20, 'SOL_mean': 64. ...
# n_index:  5
# fold_index:  9
# eval_index:  2
# 🍩 https://wandb.ai/srws-psg/data_extraction_integrate/r/call/a8ae3cee-9111-4165-b3f1-9c53f2ac6797
# arms_num:  2
# arms_list:  ['acceptance and commitment therapy (ACT)', 'active control condition']
# arm_num:  0
# 🍩 https://wandb.ai/srws-psg/data_extraction_integrate/r/call/18a7869c-9488-460f-9570-0718cb2f7856
# arm_num:  1
# 🍩 https://wandb.ai/srws-psg/data_extraction_integrate/r/call/abeb6ef8-4905-49b4-8e2e-f92563d92ecd
# log has been created:  {'acceptance and commitment therapy (ACT)': {'Year': 2021, 'ind_clu': 'individual', 'ICC_for_cRCT': 0.05, 'Country': 'Iran', 'Single_multi': 'single', 'Age_mean': 41.45, 'Age_sd': 8.66, 'Age_n': 17, 'F_n': 10, 'Hyp_n': 17, 'Insomnia_diagnosis': '1. formal_DSM', 'Primary_insomnia_n': 17, 'Comorbidities': '0. primary_insomnia', 'se': 1, 'sd': 1, 'cr': 1, 'cw': 1, 'sr': 0, 'sc': 0, 're': 1, 'pi': 0, 'w': 0, 'dt': 0, 'ns': 0, 'he': 1, 'tg': 1, 'ind': 0, 'gp': 1, 'ff': 1, 'ae': 0, 'n': 17, 'remission': -1, 'def_remission_response': '-1', 'scale_used': 'PSQI', 'Severity_bl_mean': 15.76, 'Severity_bl_sd': 2.13, 'Severity_bl_n': 17, 'Severity_ch_mean': -1, 'Severity_ch_sd': -1, 'Severity_ch_n': -1, 'Severity_ep_mean': 4.77, 'Severity_ep_sd': 2.54, 'Severity_ep_n': 17, 'Severity_scale': 'PSQI', 'dropout': 3, 'SE_mean': -1, 'SE_sd': -1, 'SE_n': -1, 'TST_mean': -1, 'TST_sd': -1, 'TST_n': -1, 'SOL_mean': -1, 'SOL_sd': -1, 'SOL_n': -1, 'WASO_mean': -1, 'WASO_sd': -1, 'WASO_n': -1, 'Sleep_diary_weeks': 8, 'r_long': -1, 'r_long_scale_used': '-1', 'Severity_mean_long': 4.06, 'Severity_sd_long': 1.75, 'Severity_n_long': 17, 'Severity_ch_mean_long': -1, 'Severity_ch_sd_long': -1, 'Severity_ch_n_long': -1, 'r_weeks_long': 20}, 'active control condition': {'Year': 2021, 'ind_clu': 'individual', 'ICC_for_cRCT': 0.05, 'Country': 'Iran', 'Single_multi': 'single', 'Age_mean': 41.47, 'Age_sd': 7.48, 'Age_n': 18, 'F_n': 12, 'Hyp_n': 18, 'Insomnia_diagnosis': '1. formal_DSM', 'Primary_insomnia_n': 18, 'Comorbidities': '0. primary_insomnia', 'se': 0, 'sd': 0, 'cr': 0, 'cw': 0, 'sr': 0, 'sc': 0, 're': 0, 'pi': 0, 'w': 0, 'dt': 0, 'ns': 1, 'he': 1, 'tg': 1, 'ind': 0, 'gp': 1, 'ff': 1, 'ae': 0, 'n': 18, 'remission': 0, 'def_remission_response': 'Not reported', 'scale_used': 'PSQI', 'Severity_bl_mean': 18, 'Severity_bl_sd': 3.14, 'Severity_bl_n': 18, 'Severity_ch_mean': 0, 'Severity_ch_sd': 0, 'Severity_ch_n': 0, 'Severity_ep_mean': 12.89, 'Severity_ep_sd': 5.26, 'Severity_ep_n': 18, 'Severity_scale': 'PSQI', 'dropout': 2, 'SE_mean': 0, 'SE_sd': 0, 'SE_n': 0, 'TST_mean': 0, 'TST_sd': 0, 'TST_n': 0, 'SOL_mean': 0, 'SOL_sd': 0, 'SOL_n': 0, 'WASO_mean': 0, 'WASO_sd': 0, 'WASO_n': 0, 'Sleep_diary_weeks': 0, 'r_long': 0, 'r_long_scale_used': 'PSQI', 'Severity_mean_long': 12.5, 'Severity_sd_long': 4.58, 'Severity_n_long': 18, 'Severity_ch_mean_long': 0, 'Severity_ch_sd_long': 0, 'Severity_ch_n_long': 0, 'r_weeks_long': 20}}
# n_index:  5
# fold_index:  9
# eval_index:  3
# 🍩 https://wandb.ai/srws-psg/data_extraction_integrate/r/call/1eb151cb-5510-4096-8010-f4a759743f49
# arms_num:  3
# arms_list:  ['CBT-PI', 'CBT-P', 'EOC']
# arm_num:  0
# 🍩 https://wandb.ai/srws-psg/data_extraction_integrate/r/call/5121c32b-6ee8-4567-a722-17b708bfdb72
# arm_num:  1
# 🍩 https://wandb.ai/srws-psg/data_extraction_integrate/r/call/fd43aa1a-8918-46f2-85b2-c727ba3fe1ca
# arm_num:  2
# 🍩 https://wandb.ai/srws-psg/data_extraction_integrate/r/call/b2606b9a-ad47-46db-857a-58da388c4961
# log has been created:  {'CBT-PI': {'Year': 2013, 'ind_clu': 'cluster', 'ICC_for_cRCT': 0.1, 'Country': 'United States', 'Single_multi': 'multi', 'Age_mean': 73.2, 'Age_sd': 8.1, 'Age_n': 122, 'F_n': 97, 'Hyp_n': 122, 'Insomnia_diagnosis': '2. informal_PSQI', 'Primary_insomnia_n': 0, 'Comorbidities': '3. phy_mixed', 'se': 1, 'sd': 1, 'cr': 1, 'cw': 0, 'sr': 1, 'sc': 1, 're': 1, 'pi': 0, 'w': 0, 'dt': 0, 'ns': 0, 'he': 1, 'tg': 1, 'ind': 0, 'gp': 1, 'ff': 1, 'ae': 0, 'n': 122, 'remission': 62, 'def_remission_response': 'A 30% or greater baseline to 2-month (post-treatment) reduction on the Insomnia Severity Index (ISI)', 'scale_used': 'ISI', 'Severity_bl_mean': 11.2, 'Severity_bl_sd': 5.2, 'Severity_bl_n': 122, 'Severity_ch_mean': -1.89, 'Severity_ch_sd': 1.89, 'Severity_ch_n': 122, 'Severity_ep_mean': 8.5, 'Severity_ep_sd': 1.89, 'Severity_ep_n': 113, 'Severity_scale': 'ISI', 'dropout': 13, 'SE_mean': 83.66, 'SE_sd': 3.61, 'SE_n': 96, 'TST_mean': -1, 'TST_sd': -1, 'TST_n': -1, 'SOL_mean': -1, 'SOL_sd': -1, 'SOL_n': -1, 'WASO_mean': -1, 'WASO_sd': -1, 'WASO_n': -1, 'Sleep_diary_weeks': 8, 'r_long': 55, 'r_long_scale_used': 'ISI', 'Severity_mean_long': 9.43, 'Severity_sd_long': 2.01, 'Severity_n_long': 44, 'Severity_ch_mean_long': -1.77, 'Severity_ch_sd_long': 1.77, 'Severity_ch_n_long': 44, 'r_weeks_long': 30}, 'CBT-P': {'Year': 2013, 'ind_clu': 'cluster', 'ICC_for_cRCT': 0.1, 'Country': 'United States', 'Single_multi': 'multi', 'Age_mean': 73, 'Age_sd': 8.4, 'Age_n': 122, 'F_n': 98, 'Hyp_n': 25, 'Insomnia_diagnosis': '1. formal_ICSD', 'Primary_insomnia_n': 122, 'Comorbidities': '1. primary_secondary_mixed', 'se': 1, 'sd': 1, 'cr': 1, 'cw': 0, 'sr': 1, 'sc': 1, 're': 1, 'pi': 0, 'w': 0, 'dt': 0, 'ns': 0, 'he': 0, 'tg': 1, 'ind': 0, 'gp': 1, 'ff': 1, 'ae': 0, 'n': 122, 'remission': 40, 'def_remission_response': 'A 30% or greater baseline to 2-month (post-treatment) reduction on the Insomnia Severity Index (ISI)', 'scale_used': 'ISI', 'Severity_bl_mean': 11.8, 'Severity_bl_sd': 4.7, 'Severity_bl_n': 122, 'Severity_ch_mean': -1.32, 'Severity_ch_sd': 1.32, 'Severity_ch_n': 122, 'Severity_ep_mean': 10.53, 'Severity_ep_sd': 1.32, 'Severity_ep_n': 122, 'Severity_scale': 'ISI', 'dropout': 10, 'SE_mean': 83.93, 'SE_sd': 1.32, 'SE_n': 122, 'TST_mean': 430.2, 'TST_sd': 63.9, 'TST_n': 122, 'SOL_mean': -1, 'SOL_sd': -1, 'SOL_n': -1, 'WASO_mean': -1, 'WASO_sd': -1, 'WASO_n': -1, 'Sleep_diary_weeks': 8, 'r_long': 23, 'r_long_scale_used': 'ISI', 'Severity_mean_long': 11.96, 'Severity_sd_long': 1.32, 'Severity_n_long': 122, 'Severity_ch_mean_long': -0.71, 'Severity_ch_sd_long': 1.32, 'Severity_ch_n_long': 122, 'r_weeks_long': 40}, 'EOC': {'Year': 2013, 'ind_clu': 'cluster', 'ICC_for_cRCT': 0.022, 'Country': 'United States', 'Single_multi': 'multi', 'Age_mean': 73.1, 'Age_sd': 8, 'Age_n': 123, 'F_n': 93, 'Hyp_n': 13, 'Insomnia_diagnosis': '1. formal_Edinger2004', 'Primary_insomnia_n': 123, 'Comorbidities': '1. primary_secondary_mixed', 'se': 1, 'sd': 0, 'cr': 0, 'cw': 0, 'sr': 0, 'sc': 0, 're': 0, 'pi': 0, 'w': 0, 'dt': 0, 'ns': 1, 'he': 1, 'tg': 1, 'ind': 0, 'gp': 1, 'ff': 1, 'ae': 0, 'n': 123, 'remission': 49, 'def_remission_response': 'A 30% or greater baseline to 2-month (post-treatment) reduction on the Insomnia Severity Index (ISI)', 'scale_used': 'ISI', 'Severity_bl_mean': 11.5, 'Severity_bl_sd': 5.1, 'Severity_bl_n': 123, 'Severity_ch_mean': -1.12, 'Severity_ch_sd': 2.83, 'Severity_ch_n': 123, 'Severity_ep_mean': 10.18, 'Severity_ep_sd': 4.97, 'Severity_ep_n': 123, 'Severity_scale': 'ISI', 'dropout': 3, 'SE_mean': 81.02, 'SE_sd': 8.7, 'SE_n': 115, 'TST_mean': 413.8, 'TST_sd': 66.6, 'TST_n': 118, 'SOL_mean': -1, 'SOL_sd': -1, 'SOL_n': -1, 'WASO_mean': -1, 'WASO_sd': -1, 'WASO_n': -1, 'Sleep_diary_weeks': 8, 'r_long': 49, 'r_long_scale_used': 'ISI', 'Severity_mean_long': 10.18, 'Severity_sd_long': 4.97, 'Severity_n_long': 120, 'Severity_ch_mean_long': -1.32, 'Severity_ch_sd_long': 2.57, 'Severity_ch_n_long': 120, 'r_weeks_long': 39}}
# n_index:  5
# fold_index:  9
# eval_index:  4
# 🍩 https://wandb.ai/srws-psg/data_extraction_integrate/r/call/82e1ffaf-615c-495f-9dc3-80a0e99c9cc4
# arms_num:  2
# arms_list:  ['self-help cognitive behavioral intervention', 'treatment as usual (TAU)']
# arm_num:  0
# 🍩 https://wandb.ai/srws-psg/data_extraction_integrate/r/call/c06d2959-40bd-4b5d-b128-8a72a81e3d7a
# arm_num:  1
# 🍩 https://wandb.ai/srws-psg/data_extraction_integrate/r/call/fd020f57-6934-4c49-aa6e-763ec7716b47
# log has been created:  {'self-help cognitive behavioral intervention': {'Year': 2012, 'ind_clu': 'individual', 'ICC_for_cRCT': 0.05, 'Country': 'UK', 'Single_multi': 'multi', 'Age_mean': 67.0, 'Age_sd': 7.9, 'Age_n': 98, 'F_n': 68, 'Hyp_n': 50, 'Insomnia_diagnosis': '1. formal_DSM', 'Primary_insomnia_n': 0, 'Comorbidities': '3. phy_mixed', 'se': 1, 'sd': 1, 'cr': 1, 'cw': 0, 'sr': 1, 'sc': 1, 're': 0, 'pi': 0, 'w': 0, 'dt': 0, 'ns': 0, 'he': 1, 'tg': 1, 'ind': 0, 'gp': 0, 'ff': 0, 'ae': 0, 'n': 98, 'remission': -1, 'def_remission_response': '-1', 'scale_used': 'ISI', 'Severity_bl_mean': 17.7, 'Severity_bl_sd': 4.6, 'Severity_bl_n': 98, 'Severity_ch_mean': -1, 'Severity_ch_sd': -1, 'Severity_ch_n': -1, 'Severity_ep_mean': 12.59, 'Severity_ep_sd': 4.57, 'Severity_ep_n': 62, 'Severity_scale': 'ISI', 'dropout': 34, 'SE_mean': -1, 'SE_sd': -1, 'SE_n': -1, 'TST_mean': -1, 'TST_sd': -1, 'TST_n': -1, 'SOL_mean': -1, 'SOL_sd': -1, 'SOL_n': -1, 'WASO_mean': -1, 'WASO_sd': -1, 'WASO_n': -1, 'Sleep_diary_weeks': 7, 'r_long': -1, 'r_long_scale_used': 'ISI', 'Severity_mean_long': -1, 'Severity_sd_long': -1, 'Severity_n_long': -1, 'Severity_ch_mean_long': -1, 'Severity_ch_sd_long': -1, 'Severity_ch_n_long': -1, 'r_weeks_long': 26}, 'treatment as usual (TAU)': {'Year': 2012, 'ind_clu': 'individual', 'ICC_for_cRCT': 0, 'Country': 'UK', 'Single_multi': 'multi', 'Age_mean': 66.3, 'Age_sd': 6.9, 'Age_n': 95, 'F_n': 60, 'Hyp_n': 50, 'Insomnia_diagnosis': '1. formal_DSM', 'Primary_insomnia_n': 95, 'Comorbidities': '4. psy_phy_mixed', 'se': 1, 'sd': 0, 'cr': 0, 'cw': 0, 'sr': 0, 'sc': 0, 're': 0, 'pi': 0, 'w': 0, 'dt': 1, 'ns': 0, 'he': 0, 'tg': 0, 'ind': 0, 'gp': 0, 'ff': 0, 'ae': 0, 'n': 95, 'remission': -1, 'def_remission_response': '-1', 'scale_used': 'PSQI', 'Severity_bl_mean': 11.9, 'Severity_bl_sd': 3.4, 'Severity_bl_n': 95, 'Severity_ch_mean': -1, 'Severity_ch_sd': -1, 'Severity_ch_n': -1, 'Severity_ep_mean': 1.3, 'Severity_ep_sd': 2.52, 'Severity_ep_n': 95, 'Severity_scale': 'PSQI', 'dropout': 28, 'SE_mean': 65.8, 'SE_sd': 15.49, 'SE_n': 95, 'TST_mean': -1, 'TST_sd': -1, 'TST_n': -1, 'SOL_mean': -1, 'SOL_sd': -1, 'SOL_n': -1, 'WASO_mean': -1, 'WASO_sd': -1, 'WASO_n': -1, 'Sleep_diary_weeks': 7, 'r_long': -1, 'r_long_scale_used': '-1', 'Severity_mean_long': 1.73, 'Severity_sd_long': 2.69, 'Severity_n_long': 95, 'Severity_ch_mean_long': -1, 'Severity_ch_sd_long': -1, 'Severity_ch_n_long': -1, 'r_weeks_long': 30}}
