# %% [markdown]
# <a href="https://colab.research.google.com/github/Tomo-for-lab/Code-of-automating-DE/blob/main/development%20of%20metaprompt/development_of_metaprompt_with_conventional_n_shots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Preparation

# %%
# !pip install -q openpyxl anthropic weave python-docx
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 877.6/877.6 kB 9.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.2/29.2 MB 36.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.3/244.3 kB 13.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 3.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 327.8/327.8 kB 16.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 320.6/320.6 kB 9.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 10.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 27.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 202.9/202.9 kB 9.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.0/74.0 kB 4.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.1/65.1 kB 1.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 3.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 4.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 3.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 6.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 289.0/289.0 kB 8.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 2.2 MB/s eta 0:00:00

# %%
import re
import ipykernel
from notebook.notebookapp import list_running_servers
import requests
from urllib.parse import urljoin
import json
import os
from google.colab import auth
from googleapiclient.discovery import build
import pandas as pd
import anthropic
import re
import openpyxl
import base64
import csv
import numpy as np
import datetime
import copy
import logging
import glob
import time
from docx import Document

from openai import OpenAI
from openai import AzureOpenAI
import json
import pandas as pd
import os
import glob
import numpy as np
from tqdm import tqdm
from google.colab import userdata

# %% [markdown]
# Change the working directory to the path of the current notebook

# %%
from google.colab import drive
# Mount Google Drive to access files stored in it
drive.mount('/content/drive')


def get_notebook_path():
    # Get the path of the current Jupyter notebook
    kernel_id = re.search('kernel-(.*).json', ipykernel.get_connection_file()).group(1)
    servers = list_running_servers()
    for ss in servers:
        response = requests.get(urljoin(ss['url'], 'api/sessions'), params={'token': ss.get('token', '')})
        for nn in json.loads(response.text):
            if nn['kernel']['id'] == kernel_id:
                relative_path = nn['notebook']['path']
                return os.path.join(ss['notebook_dir'], relative_path)

def get_folder_path(folder_id):
    # Recursively get the full path of a folder given its ID
    if folder_id:
        folder = drive_service.files().get(fileId=folder_id, fields="name, parents").execute()
        folder_name = folder.get('name')
        parents = folder.get('parents')
        if parents:
            parent_path = get_folder_path(parents[0])
            return parent_path + '/' + folder_name
        else:
            return folder_name
    return ''

def get_file_path(file_id):
    # Recursively get the full path of a file given its ID
    file = drive_service.files().get(fileId=file_id, fields="name, parents").execute()
    file_name = file.get('name')
    parents = file.get('parents')
    if parents:
        parent_id = parents[0]
        parent_path = get_folder_path(parent_id)
        return parent_path
    else:
        return file_name

# Get the path of the current notebook
notebook_path = get_notebook_path()


# Authenticate and initialize the Google Drive API
auth.authenticate_user()
drive_service = build('drive', 'v3')

# Extract the file ID from the notebook path (assumes file ID is part of the path)
file_id = re.search(r'fileId=(\w+)', notebook_path).group(1)

# Get the full path of the file using its ID
file_path = get_file_path(file_id)
if 'マイドライブ' in file_path:
    converted_path = re.sub(r'(^|/)マイドライブ($|/)', '/content/drive/MyDrive/', file_path)
elif 'MyDrive' in file_path:
    converted_path = re.sub(r'(^|/)MyDrive($|/)', '/content/drive/MyDrive/', file_path)
else:
    converted_path = '/content/drive/MyDrive/' + file_path

# Change the working directory to the converted path
os.chdir(converted_path)
# Out:
# Mounted at /content/drive

# %% [markdown]
#  # To download original description

# %%
# Path to the JSON file of original descriptions
json_file_path = 'original_description_insomnia.json'

# Load JSON data from the file
with open(json_file_path, 'r') as file:
    data = json.load(file)

# Extract all fields from the JSON data
all_fields = [field for field in data]

# Change type 'integer' to 'number' for tools
for item in all_fields:
    if item['type'] == 'integer':
        item['type'] = 'number'

# %%
print(all_fields)
# Out:
# [{'name': 'Year', 'type': 'number', 'description': 'Publication year of the primary report. If only the results from registry are available, use the date when the results are posted instead.'}, {'name': 'ind_clu', 'type': 'string', 'description': "Study design: Choose 'individual' if individually randomized, choose 'cluster' if it is a cluster RCT. You have to choose from the options [individual, cluster]."}, {'name': 'ICC_for_cRCT', 'type': 'number', 'description': "Intra-cluster Correlation Coefficient for cluster RCTs. If it is not clearly stated, use '0.05'."}, {'name': 'Country', 'type': 'string', 'description': 'Countries where the trial took place.'}, {'name': 'Single_multi', 'type': 'string', 'description': 'Whether the recruitment took place at a single or multi centers. You have to choose from the options [single, multi].'}, {'name': 'Age_mean', 'type': 'number', 'description': 'Mean age of the patients in the arm.'}, {'name': 'Age_sd', 'type': 'number', 'description': 'Standard deviation of the mean age. SD can be calculated using SE or CI if not directly provided.'}, {'name': 'Age_n', 'type': 'number', 'description': 'The number of patients used for calculating Age_mean.'}, {'name': 'F_n', 'type': 'number', 'description': 'Number of female patients in the arm.'}, {'name': 'Hyp_n', 'type': 'number', 'description': "Number of patients using hypnotics. If the drug treatment is part of the protocol treatment, 'Hyp_n' should be equal to 'n'. If not, use the number at baseline."}, {'name': 'Insomnia_diagnosis', 'type': 'string', 'description': 'Formal or informal diagnostic criteria used for insomnia. Prioritize DSM, ICSD, ICD, and other formal criteria over informal scales. You have to choose from the options [1. formal_DSM, 1. formal_ICSD, 1. formal_ICD, 1. formal_Edinger2004, 2. informal_ISI, 2. informal_SCI, 2. informal_PSQI, 2. informal_AIS, 2. informal_other_self_reported_scales, 3. others].'}, {'name': 'Primary_insomnia_n', 'type': 'number', 'description': "The number of primary insomnia patients (insomnia without comorbidities) in the arm. If focused on primary insomnia, it should be same as 'n'."}, {'name': 'Comorbidities', 'type': 'string', 'description': 'Comorbid conditions present in the study population. Use predefined categories such as primary_insomnia, psy_MDD, phy_heart_failure, etc. You have to choose from the options [0. primary_insomnia, 1. primary_secondary_mixed, 2. psy_MDD, 2. psy_anxiety, 2. psy_PTSD, 2. psy_schizophrenia_or_psychosis, 2. psy_bipolar, 2. psy_substance_dependence, 2. psy_others, 2. psy_mixed, 3. phy_dialysis, 3. phy_heart_failure, 3. phy_diabetes, 3. phy_fibromyalgia, 3. phy_cancer, 3. phy_steroid, 3. phy_pregnancy_perinatal, 3. phy_menopause, 3. phy_others, 3. phy_mixed, 4. psy_phy_mixed]'}, {'name': 'se', 'type': 'number', 'description': 'Sleep hygiene education component: 1 if included, 0 if not.'}, {'name': 'sd', 'type': 'number', 'description': 'Sleep diary component: 1 if included, 0 if not.'}, {'name': 'cr', 'type': 'number', 'description': 'Cognitive restructuring component: 1 if included, 0 if not.'}, {'name': 'cw', 'type': 'number', 'description': 'Constructive worry component: 1 if included, 0 if not.'}, {'name': 'sr', 'type': 'number', 'description': 'Sleep restriction component: 1 if included, 0 if not.'}, {'name': 'sc', 'type': 'number', 'description': 'Stimulus control component: 1 if included, 0 if not.'}, {'name': 're', 'type': 'number', 'description': 'Relaxation component: 1 if included, 0 if not.'}, {'name': 'pi', 'type': 'number', 'description': 'Paradoxical intention component: 1 if included, 0 if not.'}, {'name': 'w', 'type': 'number', 'description': 'Waiting component: 1 if included, 0 if not.'}, {'name': 'dt', 'type': 'number', 'description': 'Conventional drug treatment component: 1 if included, 0 if not.'}, {'name': 'ns', 'type': 'number', 'description': 'Non-specific treatment effect component: 1 if included, 0 if not.'}, {'name': 'he', 'type': 'number' ...

# %% [markdown]
# # To download training data

# %%
# Initialize an empty list to store the list of RCTs for training data.
sample_trials = []

# Open the file containing the list
with open('sample_trials_list.txt', 'r') as file:
    # Read each line in the file
    for line in file:
        # Parse the JSON string on the current line and add it to the list
        sample_trials.append(json.loads(line.strip()))

# %% [markdown]
# # Preparation of Azure for GPT

# %%
#deploy names
deployment_ids = ["gpt-4o","gpt-4-turbo","gpt-3.5-turbo","text-embedding-ada-002"]

#If you use Azure
#key
API_KEY = userdata.get('Azure_API_key')
RESOURCE_ENDPOINT = userdata.get('RESOURCE_ENDPOINT')
AZURE_API_version = userdata.get('AZURE_API_version')

#client
client = AzureOpenAI(
    # https://learn.microsoft.com/en-us/azure/ai-services/openai/reference#rest-api-versioning
    api_version=AZURE_API_version,
    # https://learn.microsoft.com/en-us/azure/cognitive-services/openai/how-to/create-resource?pivots=web-portal#create-a-resource
    azure_endpoint=RESOURCE_ENDPOINT,
    api_key=API_KEY
)

# %% [markdown]
# # Preparation of weave
#
# Weave is the application to store interactions with LLMs as logs.

# %%
import weave

# Initialize weave with a specific identifier
weave.init("hello-weave")

# %% [markdown]
# # Define required function

# %% [markdown]
# ## Function to convert text data in JSON and table data into string variable.

# %%
def extract_sentence(pdf_name):
  # Construct the path to the JSON file associated with the given PDF
  json_name=pdf_name+"/structuredData.json"

  a = open(json_name)# Open and load the JSON file
  j = json.load(a)
  method_flag=1
  extracted_sentence=""# Initialize a string to store the extracted sentences
  previous_item_class=0# To track the class of the previous item and determine if a newline is needed

  # Iterate through each element in the JSON file
  for item in j["elements"] :
    # Check if the item is a heading
    if ("//Document/H" in item['Path']) or (re.search(r"//Document/Sect.*/H", item['Path'])):
      if previous_item_class!=1:
        extracted_sentence+="\n"
        previous_item_class=1
      if "Text" in item:
        if ("reference" == item["Text"].strip().lower()) or ("references" == item["Text"].strip().lower()) or ("appendix" == item["Text"].strip().lower()):
          extracted_sentence+="\n"
          break;
        extracted_sentence+=item["Text"]
        extracted_sentence+="\n"

    # Check if the item is a table and convert table data to text
    elif (re.search("//Document/Table.*" ,item['Path'])) or (re.search(r"//Document/Sect.*/Table", item['Path'])):#表データを文章に置き換える
      if previous_item_class!=2:
        extracted_sentence+="\n"
        previous_item_class=2
      if "filePaths" in item:
        for t in item["filePaths"]:
          if ".xlsx" in t:
            extracted_sentence+=t.replace(".xlsx", "").split("/")[-1]
            extracted_sentence+="\n"
            t=pdf_name+"/"+t
            # Load the Excel file
            df_t = pd.read_excel(t)
            # Remove carriage returns from column names and data
            df_t.columns = [col.replace('_x000D_', '') for col in df_t.columns]
            df_t = df_t.replace('_x000D_', '', regex=True)
            # Get column names as a string
            column_names = ' '.join(df_t.columns)

            extracted_sentence+=df_t.to_csv(index=False)
            extracted_sentence+="\n"

    # Check if the item is a footnote
    elif (re.search("//Document/Footnote\.*",item['Path'])) or (re.search(r"//Document/Sect.*/Footnote", item['Path'])):
      if previous_item_class!=5:
        extracted_sentence+="\n"
        previous_item_class=5
      if "Text" in item:
        extracted_sentence+=item["Text"]
        extracted_sentence+="\n"

    # Check if the item is a paragraph
    elif ("//Document/P" in item['Path']) or (re.search(r"//Document/Sect.*/P", item['Path'])):
      if previous_item_class!=3:
        extracted_sentence+="\n"
        previous_item_class=3
      if not("/Figure" in item["Path"]):
        if "Text" in item:
          extracted_sentence+=item["Text"]

    # Check if the item is a list
    elif ("//Document/L" in item['Path']) or (re.search(r"//Document/Sect.*/L", item['Path'])):
      if previous_item_class!=4:
        extracted_sentence+="\n"
        previous_item_class=4
      if "/Lbl" in item["Path"]:
        extracted_sentence+="\n"
      if "Text" in item:
        extracted_sentence+=item["Text"]


  # Close the JSON file
  a.close()
  return extracted_sentence

# %% [markdown]
# ## Function to convert text data in JSON into string variable.

# %%
def extract_sentence_text(pdf_name):
  # Construct the path to the JSON file associated with the given PDF
  json_name=pdf_name+"/structuredData.json"

  a = open(json_name)# Open and load the JSON file
  j = json.load(a)
  method_flag=1
  extracted_sentence=""# Initialize a string to store the extracted sentences
  previous_item_class=0 # To track the class of the previous item and determine if a newline is needed

  # Iterate through each element in the JSON file
  for item in j["elements"] :
    # Check if the item is a heading
    if ("//Document/H" in item['Path']) or (re.search(r"//Document/Sect.*/H", item['Path'])):
      if previous_item_class!=1:
        extracted_sentence+="\n"
        previous_item_class=1
      if "Text" in item:
        # Check for specific keywords to stop extracting sentences
        if ("reference" == item["Text"].strip().lower()) or ("references" == item["Text"].strip().lower()) or ("appendix" == item["Text"].strip().lower()):
          extracted_sentence+="\n"
          break;
        extracted_sentence+=item["Text"]
        extracted_sentence+="\n"

    # Check if the item is a paragraph
    elif ("//Document/P" in item['Path']) or (re.search(r"//Document/Sect.*/P", item['Path'])):
      if previous_item_class!=3:
        extracted_sentence+="\n"
        previous_item_class=3
      if not("/Figure" in item["Path"]):
        if "Text" in item:
          extracted_sentence+=item["Text"]

    # Check if the item is a list
    elif ("//Document/L" in item['Path']) or (re.search(r"//Document/Sect.*/L", item['Path'])):
      if previous_item_class!=4:
        extracted_sentence+="\n"
        previous_item_class=4
      if "/Lbl" in item["Path"]:
        extracted_sentence+="\n"
      if "Text" in item:
        extracted_sentence+=item["Text"]

    # Check if the item is a footnote
    elif (re.search("//Document/Footnote\.*",item['Path'])) or (re.search(r"//Document/Sect.*/Footnote", item['Path'])):
      if previous_item_class != 5:
        extracted_sentence+="\n"
        previous_item_class=5
      if "Text" in item:
        extracted_sentence+=item["Text"]
        extracted_sentence+="\n"

  # Close the JSON file
  a.close()
  return extracted_sentence

# %% [markdown]
# ## Function to create tools for development of metaprompt

# %%
def make_tools_optimization(optimized_all_fields):
  # Create a dictionary with item names as keys and the rest of the item attributes as values
  properties_dict = {item['name']: {k: v for k, v in item.items() if k != 'name'} for item in optimized_all_fields}

  # Create a list of names from the optimized fields
  name_list = [item['name'] for item in optimized_all_fields]


  # Define the base structure for the description tools
  description_tools = [{'type': 'function',
      'function':{
          'name': 'optimize_descriptions_of_study_features',
          'description': """      Follow the instructions below to optimize the descriptions in 'optimize_descriptions_of_study_features' tools.
      # Tool Updates
      When updating the description of tools, use the data extracted by you and correct answer data to be extracted. Provide as much detail as possible and include few-shot examples.
      # Tool Update Instructions:
      1. **Updating Tool Descriptions**:
      - Use data from papers, the data extracted by you and correct answer data to be extracted to update the tool descriptions.
        - When new tools are added, provide detailed explanations of their use and purpose.
        - Offer clear and detailed descriptions of each tool's functionality and how to use them.
      2. **Providing Few-Shot Examples**:
        - Offer concrete few-shot examples to demonstrate the use of new or existing tools.
        - Use examples to show the precise usage of the tools, making it easy for you to understand.
        """,
          'parameters': {
              'type': 'object',
            'properties': {}
          }
      }
  }
  ]

  # Copy the name list to a new list for use in the tool description
  splitted_name_list = copy.deepcopy(name_list)

  # Add the required names to the function parameters
  description_tools[0]['function']['parameters']['required'] = splitted_name_list

  # Add the properties for each name to the function parameters
  description_tools[0]['function']['parameters']['properties'] = {key: properties_dict[key] for key in splitted_name_list if key in properties_dict}

  return description_tools

# %% [markdown]
# ## Function to encode images into data URL for input to GPT

# %%
import base64
from mimetypes import guess_type

# Function to encode a local image into data URL
def local_image_to_data_url(image_path):
    # Guess the MIME type of the image based on the file extension
    mime_type, _ = guess_type(image_path)
    if mime_type is None:
        mime_type = 'application/octet-stream'  # Default MIME type if none is found

    # Read and encode the image file
    with open(image_path, "rb") as image_file:
        base64_encoded_data = base64.b64encode(image_file.read()).decode('utf-8')

    # Construct the data URL
    return f"data:{mime_type};base64,{base64_encoded_data}"

# %% [markdown]
# ## Function for GPT function calling

# %%
@weave.op() # 🐝
def GPT_function_calling(tools, messages, tools_name):
  response = client.chat.completions.create(
        model=deployment_ids[0],
        messages=messages,
        tools=tools,
        tool_choice =  {"type": "function", "function": {"name": tools_name}},
        temperature=0
    )
  return response

# %% [markdown]
# ## Function to update descripions for each variable.

# %%
def optimizing_all_fields(optimized_all_fields, response, splitter):
  # Parse the response to get the output dictionary from the tool's function call
  output_dict = json.loads(response.choices[0].message.tool_calls[0].function.arguments)

  # Iterate over the key-value pairs in the output dictionary
  for key, value in output_dict.items():

    # Find the matching item in the optimized_all_fields list
    for i in range(len(optimized_all_fields)):
      if optimized_all_fields[i]["name"] == key:
        # Check if the value is not an integer or float
        if not isinstance(value, (int, float)):
          # Update the description if the value is not "Not specified" or "*"
          if (str(value) != "Not specified") and (str(value) != "*"):
            optimized_all_fields[i]["description"] = value

  return optimized_all_fields

# %% [markdown]
# ## Function to log the developed metaprompt.

# %%
def optimized_description_log(shot_name, fold_index, n, n_index, f_index, log_file_name, optimized_all_fields):

  # Construct the file path using the provided parameters
  file_name = f"{log_file_name}/{shot_name}/{n[n_index]}_paper/{fold_index}_fold/optimized_all_fields_{f_index}.json"

  # Write the optimized_all_fields data to a JSON file
  with open(file_name, 'w') as file:
      json.dump(optimized_all_fields, file, indent=4)

  # Print a completion message
  print("Log has been successfully written to 'log_description'")

# %% [markdown]
# ##Function to log error

# %%
def error_log(shot_name, fold_index, n, n_index,f_index,log_file_name,e):
  # Construct the file path for the error log
  error_log_file_name = f"{log_file_name}/error_log"

  # Append error details to the log file
  with open(error_log_file_name, 'a') as file:
    file.write(f"shot_name: {shot_name} \n")
    file.write(f"fold_index: {fold_index} \n")
    file.write(f"n: {n[n_index]} \n")
    file.write(f"f_index: {f_index} \n")
    file.write(str(e)+"\n")
    file.write("\n")

# %% [markdown]
# # Development of metaprompt

# %% [markdown]
# ## What LLMs should be aware of when extracting data (free text)

# %%
attention_query = """
#####Attention######

# From which paper to extract data
The primary paper is named AuthorYYYY, the registry ULR AuthorYYYY_NCT1234, the protocol AuthorYYYY_pr, the appendix/supplement files AuthorYYY_app or AuthorYYY_supp, and the secondary papers AuthorYYYY_s1,2,…
You can mainly extract data from primary paper.

#Mixed model repeated measures
- When to be careful
"mixed model", "mixed model repeated measures (MMRM)", "linear mixed model", "growth curve analysis ", "hierarchical model", etc.
If SEs are reported instead of SDs, be especially careful, as MMRM is highly likely.
- What to look out for in evaluation and data extraction
MMRM is said to be a method to estimate the effect of missing values of repeatedly measured outcomes without bias by making the assumption of missing at random
So, N (e.g., Severity_ep_n) in the extraction on outcomes should be the N that was analyzed (=in principle, number randomized; number analyzed for statistical analysis excluding early dropouts). Note that this is different from the number of people for whom outcome measures were available. (In the Christensen2016 example, 1149 patients were randomly assigned and 581 were available at 6 weeks for primary outcome measurement. (N should also be number randomized when calculating SD using SD=SE*sqrt(N).


# How to extract data for each arm
First, extract the data for each arm.
If the arm is further divided into several groups, merge these groups and calculate the integrated data.
If you cannot extract data by arm, extract data for all participants.
If you cannot find any data to extract or you do not have to extract data, output "-1".

# Which measure data you will take
You have to extract data (mean, SD, number, etc.) in the measure you previously extracted.

# The measure abbreviations
ISI: Insomnia Severity Index
SCI: Sleep Condition Indicator
FOSQ: Functional Outcomes of Sleep Questionnaire
ESS: Epworth Sleepiness Scale
PSQI: Pittsburgh Sleep Quality Index
AIS: Athens Insomnia Scale
WASO: Wake After Sleep Onset
SOL: Sleep Onset Latency

# How to calculate SD
You have to calculate SD and output as number (do not output as formula).
SD=SE*sqrt(n)
　If mixed model repeated measures were used, n is the number of people randomized or included in the analysis.
SD=(upper limit of [100-x]%CI - mean)*sqrt(n)/ NORM.S.INV([100-x/2]/100)
  If 90%CI, then ((upper limit of 90%CI - mean)*sqrt(n)/ norm.s.inv(0.95))
If 95%CI, then ((upper limit of 95%CI - mean)*sqrt(n)/ norm.s.inv(0.975))
If 99%CI, then ((upper limit of 99%CI - mean)*sqrt(n)/ norm.s.inv(0.995))
SD= (Q3 − Q1)/1.35
"""

# %% [markdown]
# ## Optimize

# %%
# Load the Excel file for original extracted data
file_path = 'DE.xlsx'
df = pd.read_excel(file_path,skiprows=1)

n=[1,2,3,4,5]

# %%
shot_name = "few_shots"

weave.init('optimizing_description_integrate') # 🐝

# %%
# Initialize variables
log_file_name = "optimized_description_log"

# Iterate over the number of training data and folds
for n_index in range(5):
  for fold_index in range(10):
    num_done_correctly = list(range(n[n_index])) #List of trials from which data could be extracted
    print("data extraction")
    all_extracted_data = []
    for f_index in range(n[n_index]):
      f_name=sample_trials[n_index][fold_index][f_index]
      print("n_index: ", n_index)
      print("fold_index: ", fold_index)
      print("f_index: ", f_index)

      ############################################
      # Data extraction
      ############################################
      extracted_data = {}# For storing extracted data
      output_extracted_data = {} # For storing output data
      ############################################
      # Define tools for extracting arm information
      tools = [{'type': 'function',
          'function':
              {'name': 'extract_arm',
              'description': 'Extract the number of the arms and each arm name',
              'parameters': {
                  'type': 'object',
                'properties': {
                    "arms_num":
                    {"type": "number",
                    "description": "Answer the number of the arms"
                    },
                    "arm_name_1":
                    {"type": "string",
                    "description": "Answer arm name. If exceed the number of the arms, answer 'nan'."
                    },

                    "arm_name_2":
                    {"type": "string",
                    "description": "Answer arm name. If exceed the number of the arms, answer 'nan'."
                    },

                    "arm_name_3":
                    {"type": "string",
                    "description": "Answer arm name. If exceed the number of the arms, answer 'nan'."
                    },

                    "arm_name_4":
                    {"type": "string",
                    "description": "Answer arm name. If exceed the number of the arms, answer 'nan'."
                    },

                    "arm_name_5":
                    {"type": "string",
                    "description": "Answer arm name. If exceed the number of the arms, answer 'nan'."
                    }
                },
              "required": [
                  "arms_num",
                  "arm_name_1",
                  "arm_name_2",
                  "arm_name_3",
                  "arm_name_4",
                  "arm_name_5"
                  ]
              }
          }
      }
      ]
      #######################################################
      # Create messages for extracting arm information
      messages_arm=[]
      system_content = """You are a systematic reviewer.You have to extract arms(i.e., intervenitons and controls) from the inputted paper of a randomized controlled trial.\n
      Use the extract_arm tool in your response.\n\n"""
      user_content = """You have to extract arms(i.e., intervenitons and controls) from the inputted paper of a randomized controlled trial.\n
      Use the extract_arm tool in your response.\n\n"""
      png_files_sum = 0

      # Create input text from the paper
      root_dir = f"IncludedTrials/{f_name}"
      file_to_find = "structuredData.json"

      user_content += f"paper_name: {f_name} \n"
      for dirpath, dirnames, filenames in os.walk(root_dir):# Root directory containing the trial files
        if (dirpath == root_dir) or (dirpath == root_dir+f"/{f_name}"):# JSON file to find in directories
          if file_to_find in filenames:
            main_paper_txt= extract_sentence_text(dirpath)
            user_content += main_paper_txt

      if main_paper_txt == "":
        num_done_correctly.remove(f_index) #Exclude trials from which data could not be extracted
        error_message = f"An error occurred: no_paper_text"
        print(error_message)
        continue;

      messages_arm.append({"role": "system", "content": system_content})
      messages_arm.append({"role": "user", "content": user_content})

############################################
      # Get response from GPT model
      try:
        tools_name = "extract_arm"
        response_arm = GPT_function_calling(tools, messages_arm, tools_name)
      except Exception as e:
        num_done_correctly.remove(f_index)
        error_log(shot_name, fold_index, n, n_index,f_index,log_file_name,e)
        error_message = f"An error occurred response arm: {str(e)}"
        print(error_message)
        continue;

############################################
      # Parse the response
      try:
        output_dict_arm = json.loads(response_arm.choices[0].message.tool_calls[0].function.arguments)
      except Exception as e:
        num_done_correctly.remove(f_index)
        error_log(shot_name, fold_index, n, n_index,f_index,log_file_name,e)
        error_message = f"An error occurred output_dict_arm : {str(e)}"
        print(error_message)
        continue;

      arms_num = output_dict_arm["arms_num"]# Number of arms
      arms_list = []# List of arm names
      for arm_num in range(arms_num):
        arms_list.append(output_dict_arm[f"arm_name_{arm_num+1}"])
      print("arms_num: ", arms_num)
      print("arms_list: ", arms_list)

############################################
      # Process each arm
      for arm_num in range(arms_num):
        print("arm_num: ", arm_num)
############################################
        #Create output storage dict
        # Path to the JSON file
        json_file_path = '../original_description/original_description_insomnia.json'

        # Load JSON data from the file
        with open(json_file_path, 'r') as file:
            data = json.load(file)

        # Extract all fields from the JSON data
        all_fields = [field for field in data]

        output = {item['name']: "None" for item in all_fields}

        for i in range(2):
  ############################################
          # Create tools for optimized description
          properties_dict = {item['name']: {k: v for k, v in item.items() if k != 'name'} for item in all_fields}
          name_list = [item['name'] for item in all_fields]

          description_tools = [{'type': 'function',
              'function':
                  {'name': 'extract_study_features',
                  'description': 'Extracts key features from a user-inputted research article for systematic review purposes.',
                  'parameters': {
                      'type': 'object',
                    'properties': {}
                  }
              }
          }
          ]

          # Split the name list for processing
          if i==0:
            splitted_name_list = copy.deepcopy(name_list[:30])
          else:
            splitted_name_list = copy.deepcopy(name_list[30:len(name_list)])

          description_tools[0]['function']['parameters']['required'] = splitted_name_list
          description_tools[0]['function']['parameters']['properties'] = {key: properties_dict[key] for key in splitted_name_list if key in properties_dict}

  ############################################
          # Create messages for data extraction
          system_content_DE = """You are a systematic reviewer.
          Use the extract_study_features tool in your response.
          """

          query_GPT = f"""You have to extract features in the {arms_list[arm_num]} arm from the inputted paper of a randomized controlled trial.
            Use the extract_study_features tool in your response.\n
              """
          query_GPT += attention_query
          query_GPT += f"trial_name: {f_name} \n \n "

          query_function_calling = copy.deepcopy(query_GPT)

          query_GPT += "The extract_study_features:"
          query_GPT += json.dumps(description_tools)

          last_query = attention_query

          messages_GPT = []
          messages_function_calling = []
          content_prompt_GPT = [] # List to hold content prompts for GPT

          png_files_sum = 0 # Sum of PNG files processed

          # Create input text from the paper
          root_dir = f"IncludedTrials/{f_name}" # Root directory containing the trial files
          file_to_find = "structuredData.json" # JSON file to find in directories

          content_prompt_GPT.append({"type": "text", "text": query_GPT})

          # Extract sentences from each document in the directory
          for dirpath, dirnames, filenames in os.walk(root_dir):
            if f_name in dirnames:# Process the main paper first
              dirnames.remove(f_name)
              dirnames.insert(0, f_name)
            if file_to_find in filenames:
              paper_query = dirpath.split("/")[-1]
              paper_query += extract_sentence(dirpath)
              content_prompt_GPT.append({"type": "text", "text":paper_query})

              # Filter and add PNG files to the content prompt
              if os.path.exists(f"{dirpath}/figures"):
                png_files = [file for file in os.listdir(f"{dirpath}/figures") if file.endswith('.png')]

                for i in range(len(png_files)):
                  if png_files_sum >= 10:# Limit the number of images to 10
                    break;
                  content_prompt_GPT.append({"type": "image_url", "image_url": {"url": local_image_to_data_url(f"{dirpath}/figures/"+png_files[i])}})
                  png_files_sum += 1

          # Process txt and docx files in the root directory
          txt_docx_query = "" # String to hold txt and docx file contents
          txt_docx_flag = False # Flag to check if txt or docx files are found

          for file_name in os.listdir(root_dir):
              if file_name.endswith('.txt'):
                  txt_docx_flag = True
                  txt_docx_query += "txt_name: "
                  txt_docx_query += "txt_name: " + file_name + "\n"
                  file_path = os.path.join(root_dir, file_name)
                  with open(file_path, 'r', encoding='utf-8') as file:
                      txt_docx_query += file.read()
              elif file_name.endswith('.docx'):
                  txt_docx_flag = True
                  txt_docx_query += "docx_name: "
                  txt_docx_query += "docx_name: " + file_name + "\n"
                  file_path = os.path.join(root_dir, file_name)
                  doc = Document(file_path)
                  full_text = []
                  for para in doc.paragraphs:
                      full_text.append(para.text)

                  for table in doc.tables: # Read tables in the document
                      for row in table.rows:
                          for cell in row.cells:
                              full_text.append(cell.text)
                  txt_docx_query += '\n'.join(full_text)

          if txt_docx_flag:
            content_prompt_GPT.append({"type": "text", "text":txt_docx_query}) # Add txt/docx content if found


          content_prompt_GPT.append({"type": "text", "text": last_query}) # Add the last query to the content prompt

          messages_GPT.append({"role": "system", "content": system_content_DE})
          messages_GPT.append({"role": "user", "content": content_prompt_GPT})

  ############################################
          try:
            # Get response from GPT model
            tools_name = "extract_study_features" # Name of the tool being used
            response_GPT = GPT_function_calling(description_tools, messages_GPT ,tools_name) # Call GPT function for study features extraction
          except Exception as e:
            error_log(shot_name, fold_index, n, n_index,f_index,log_file_name,e)
            error_message = f"An error occurred data extraction: {str(e)}"
            print(error_message)
            continue;
  ############################################
          # Store the results
          output_dict_GPT = json.loads(response_GPT.choices[0].message.tool_calls[0].function.arguments)
          print(output_dict_GPT)
          for k in output_dict_GPT.keys():
            if k in output.keys():
              output[k] = output_dict_GPT[k] # Update output with GPT response
          extracted_data[arms_list[arm_num]] = copy.deepcopy(output) # Store the extracted data for the current arm
          print(extracted_data[arms_list[arm_num]])
############################################
      #Write the extracted results of the trials into JSON.
      output_extracted_data[f_name] = copy.deepcopy(extracted_data)
      all_extracted_data.append(output_extracted_data)

############################################
#Optimization
############################################
    #List to store optimized description
    _optimized_all_fields = copy.deepcopy(all_fields)
    for i in range(2):
        # Split the fields for processing: first 30 and the rest
        # Create messages for optimization
      if i == 0:
        optimized_all_fields = copy.deepcopy(all_fields[:30])
      else:
        optimized_all_fields = copy.deepcopy(all_fields[30:len(all_fields)])

      png_files_sum = 0

      # System content for GPT model
      system_content = """
      You are a systematic reviewer and you have to complete the data extraction protocol.
      Now, I will present a research paper, the data extracted by you and correct answer data to be extracted so that you can optimize the value of “description” of each item to improve your future extractions.
      Please optimize the value of “description” of each item in the tool.\n
      Output only each "description" of each item in tools.
      Do not extract data from the paper.
      """

      # Query for GPT model
      query_GPT = """
      Follow the instructions below to optimize the descriptions in 'optimize_descriptions_of_study_features' tools.

      ## Tool Updates
      When updating the description of tools, use detailed information from papers, the data extracted by you and correct answer data to be extracted. Provide as much detail as possible and include few-shot examples when necessary.

      ### Tool Update Instructions:
      1. **Updating Tool Descriptions**:
        - Use data from papers, the data extracted by you and correct answer data to be extracted to update the tool descriptions.
        - When new tools are added, provide detailed explanations of their use and purpose.
        - Offer clear and detailed descriptions of each tool's functionality and how to use them.

      2. **Providing Few-Shot Examples**:
        - Offer concrete few-shot examples to demonstrate the use of new or existing tools.
        - Use examples to show the precise usage of the tools, making it easy for users to understand.
      """

      tools = make_tools_optimization(optimized_all_fields)#Re-define tools
      for name in tools[0]['function']['parameters']['properties']:
        tools[0]['function']['parameters']['properties'][name]['description'] = ' You have to optimize the description below: ' + tools[0]['function']['parameters']['properties'][name]['description']

      messages_GPT = []
      content_prompt_GPT = [] # List to hold prompts for GPT model

      messages_GPT.append({"role": "system", "content": system_content})

      query_GPT += "The 'optimize_descriptions_of_study_features' tools:"
      query_GPT += json.dumps(tools)

      content_prompt_GPT.append({"type": "text", "text": query_GPT})

      #Store extracted data in prompt for each trial
      for _f_index in range(len(num_done_correctly)):
        f_index = num_done_correctly[_f_index]
        print(fold_index, f_index)
        f_name=sample_trials[n_index][fold_index][f_index]

        # Create input text from the paper
        root_dir = f"IncludedTrials/{f_name}" # Root directory containing the trial files
        file_to_find = "structuredData.json" # JSON file to find in directories

        query_function_calling += f"<example {f_index+1}> \n"
        query_function_calling += f"trial_name: {f_name} \n"

        first_flag = True

        # Extract sentences from each document in the directory
        for dirpath, dirnames, filenames in os.walk(root_dir):
          if f_name in dirnames:# Process the main paper first
            dirnames.remove(f_name)
            dirnames.insert(0, f_name)
          if file_to_find in filenames:
            if first_flag:
              paper_query = f"<example {f_index+1}> \n"
              paper_query += f"trial_name: {f_name} \n"
              paper_query += dirpath.split("/")[-1]
              first_flag = False
            else:
              paper_query = dirpath.split("/")[-1]
            paper_query += extract_sentence(dirpath)
            content_prompt_GPT.append({"type": "text", "text":paper_query})

            # Filter and add PNG files to the content prompt
            if os.path.exists(f"{dirpath}/figures"):
              png_files = [file for file in os.listdir(f"{dirpath}/figures") if file.endswith('.png')]

              for i in range(len(png_files)):
                if png_files_sum >= 9:# Limit the number of images to 10
                  break;
                content_prompt_GPT.append({"type": "image_url", "image_url": {"url": local_image_to_data_url(f"{dirpath}/figures/"+png_files[i])}})
                png_files_sum += 1

        # Process txt and docx files in the root directory
        txt_docx_query = ""
        for file_name in os.listdir(root_dir):
            if file_name.endswith('.txt'):
                txt_docx_query += "txt_name: "
                txt_docx_query += "txt_name: " + file_name + "\n"
                file_path = os.path.join(root_dir, file_name)
                with open(file_path, 'r', encoding='utf-8') as file:
                    txt_docx_query += file.read()
            elif file_name.endswith('.docx'):
                txt_docx_query += "docx_name: "
                txt_docx_query += "docx_name: " + file_name + "\n"
                file_path = os.path.join(root_dir, file_name)
                doc = Document(file_path)
                full_text = []
                for para in doc.paragraphs:
                    full_text.append(para.text)
                for table in doc.tables:
                    for row in table.rows:
                        for cell in row.cells:
                            full_text.append(cell.text)
                txt_docx_query += '\n'.join(full_text)
        content_prompt_GPT.append({"type": "text", "text":txt_docx_query})

        # Create query for extracted and correct data
        answer_query = f"\n <The extracted data for example {f_index+1}> \n"
        answer_query += "The data extracted by you are following: \n"
        arm_num=0
        for extracted_arm_name in all_extracted_data[_f_index][f_name]:
          answer_query += f"arm_{arm_num}: "
          answer_query += extracted_arm_name
          answer_query += "\n"
          for key, value in all_extracted_data[_f_index][f_name][extracted_arm_name].items():
            answer_query += key
            answer_query += ": "
            answer_query += str(value)
            answer_query += "\n"
          answer_query += "\n"
          arm_num+=1
        answer_query += "\n"

        answer_query += "Correct answer data to be extracted are following: \n"
        pdf_df = df[df["study"]==f_name] # DataFrame for the study

        for arm_num in range(len(pdf_df)):
          answer_query += f"arm_{arm_num}: "
          answer_query += pdf_df.iloc[arm_num]["Arm"]
          answer_query += "\n"
          for field_num in range(len(all_fields)):
            answer_query += all_fields[field_num]["name"]
            answer_query += ": "
            answer_query += str(pdf_df.iloc[arm_num][all_fields[field_num]["name"]])
            answer_query += "\n"
          answer_query += "\n"
        answer_query += "\n"

        content_prompt_GPT.append({"type": "text", "text": answer_query})

      messages_GPT.append({"role": "user", "content": content_prompt_GPT})

  ############################################
      # Optimize descriptions
      try:
        tools_name = "optimize_descriptions_of_study_features"  # Tool name for GPT
        response_GPT = GPT_function_calling(tools, messages_GPT, tools_name) # Get response from GPT
      except Exception as e:
        error_log(shot_name, fold_index, n, n_index,f_index,log_file_name,e)
        print("error occured: ", str(e))
        continue;
      try:
        _optimized_all_fields = optimizing_all_fields(_optimized_all_fields, response_GPT, "\n") # Optimize descriptions for all variables
        print(response_GPT)
      except Exception as e:
        error_log(shot_name, fold_index, n, n_index,f_index,log_file_name,e)
        print("error occured", str(e))
        continue;
    print(f_name+":"+json.dumps(_optimized_all_fields))
    optimized_description_log(shot_name, fold_index, n, n_index,f_index,log_file_name,_optimized_all_fields) # Log the optimized descriptions
# Out:
# data extraction
# n_index:  0
# fold_index:  0
# f_index:  0
# 🍩 https://wandb.ai/srws-psg/optimizing_description_integrate/r/call/2cf9153e-d7fe-4fd4-9b7f-65d558db54ea
# arms_num:  2
# arms_list:  ['psychoeducational intervention (PI+)', 'control (PI-)']
# arm_num:  0
# 🍩 https://wandb.ai/srws-psg/optimizing_description_integrate/r/call/83904e57-c12e-4477-95cb-3a9db73bc243
# {'Year': 2017, 'ind_clu': 'individual', 'ICC_for_cRCT': 0.05, 'Country': 'Italy', 'Single_multi': 'single', 'Age_mean': 64.42, 'Age_sd': 12.94, 'Age_n': 19, 'F_n': 10, 'Hyp_n': 19, 'Insomnia_diagnosis': '1. formal_ICSD', 'Primary_insomnia_n': 19, 'Comorbidities': '0. primary_insomnia', 'se': 1, 'sd': 1, 'cr': 0, 'cw': 0, 'sr': 0, 'sc': 0, 're': 0, 'pi': 0, 'w': 0, 'dt': 0, 'ns': 0, 'he': 0, 'tg': 0, 'ind': 0, 'gp': 0, 'ff': 1, 'ae': 0}
# {'Year': 2017, 'ind_clu': 'individual', 'ICC_for_cRCT': 0.05, 'Country': 'Italy', 'Single_multi': 'single', 'Age_mean': 64.42, 'Age_sd': 12.94, 'Age_n': 19, 'F_n': 10, 'Hyp_n': 19, 'Insomnia_diagnosis': '1. formal_ICSD', 'Primary_insomnia_n': 19, 'Comorbidities': '0. primary_insomnia', 'se': 1, 'sd': 1, 'cr': 0, 'cw': 0, 'sr': 0, 'sc': 0, 're': 0, 'pi': 0, 'w': 0, 'dt': 0, 'ns': 0, 'he': 0, 'tg': 0, 'ind': 0, 'gp': 0, 'ff': 1, 'ae': 0, 'n': 'None', 'remission': 'None', 'def_remission_response': 'None', 'scale_used': 'None', 'Severity_bl_mean': 'None', 'Severity_bl_sd': 'None', 'Severity_bl_n': 'None', 'Severity_ch_mean': 'None', 'Severity_ch_sd': 'None', 'Severity_ch_n': 'None', 'Severity_ep_mean': 'None', 'Severity_ep_sd': 'None', 'Severity_ep_n': 'None', 'Severity_scale': 'None', 'dropout': 'None', 'SE_mean': 'None', 'SE_sd': 'None', 'SE_n': 'None', 'TST_mean': 'None', 'TST_sd': 'None', 'TST_n': 'None', 'SOL_mean': 'None', 'SOL_sd': 'None', 'SOL_n': 'None', 'WASO_mean': 'None', 'WASO_sd': 'None', 'WASO_n': 'None', 'Sleep_diary_weeks': 'None', 'r_long': 'None', 'r_long_scale_used': 'None', 'Severity_mean_long': 'None', 'Severity_sd_long': 'None', 'Severity_n_long': 'None', 'Severity_ch_mean_long': 'None', 'Severity_ch_sd_long': 'None', 'Severity_ch_n_long': 'None', 'r_weeks_long': 'None'}
# 🍩 https://wandb.ai/srws-psg/optimizing_description_integrate/r/call/f5db04d2-24e0-4090-9aa0-681204279ee6
# {'n': 19, 'remission': -1, 'def_remission_response': '-1', 'scale_used': 'ISI', 'Severity_bl_mean': 15.74, 'Severity_bl_sd': 4.27, 'Severity_bl_n': 19, 'Severity_ch_mean': -1, 'Severity_ch_sd': -1, 'Severity_ch_n': -1, 'Severity_ep_mean': 12.16, 'Severity_ep_sd': 6.62, 'Severity_ep_n': 19, 'Severity_scale': 'ISI', 'dropout': 1, 'SE_mean': -1, 'SE_sd': -1, 'SE_n': -1, 'TST_mean': -1, 'TST_sd': -1, 'TST_n': -1, 'SOL_mean': -1, 'SOL_sd': -1, 'SOL_n': -1, 'WASO_mean': -1, 'WASO_sd': -1, 'WASO_n': -1, 'Sleep_diary_weeks': 1, 'r_long': -1, 'r_long_scale_used': '-1', 'Severity_mean_long': -1, 'Severity_sd_long': -1, 'Severity_n_long': -1, 'Severity_ch_mean_long': -1, 'Severity_ch_sd_long': -1, 'Severity_ch_n_long': -1, 'r_weeks_long': -1}
# {'Year': 2017, 'ind_clu': 'individual', 'ICC_for_cRCT': 0.05, 'Country': 'Italy', 'Single_multi': 'single', 'Age_mean': 64.42, 'Age_sd': 12.94, 'Age_n': 19, 'F_n': 10, 'Hyp_n': 19, 'Insomnia_diagnosis': '1. formal_ICSD', 'Primary_insomnia_n': 19, 'Comorbidities': '0. primary_insomnia', 'se': 1, 'sd': 1, 'cr': 0, 'cw': 0, 'sr': 0, 'sc': 0, 're': 0, 'pi': 0, 'w': 0, 'dt': 0, 'ns': 0, 'he': 0, 'tg': 0, 'ind': 0, 'gp': 0, 'ff': 1, 'ae': 0, 'n': 19, 'remission': -1, 'def_remission_response': '-1', 'scale_used': 'ISI', 'Severity_bl_mean': 15.74, 'Severity_bl_sd': 4.27, 'Severity_bl_n': 19, 'Severity_ch_mean': -1, 'Severity_ch_sd': -1, 'Severity_ch_n': -1, 'Severity_ep_mean': 12.16, 'Severity_ep_sd': 6.62, 'Severity_ep_n': 19, 'Severity_scale': 'ISI', 'dropout': 1, 'SE_mean': -1, 'SE_sd': -1, 'SE_n': -1, 'TST_mean': -1, 'TST_sd': -1, 'TST_n': -1, 'SOL_mean': -1, 'SOL_sd': -1, 'SOL_n': -1, 'WASO_mean': -1, 'WASO_sd': -1, 'WASO_n': -1, 'Sleep_diary_weeks': 1, 'r_long': -1, 'r_long_scale_used': '-1', 'Severity_mean_long': -1, 'Severity_sd_long': -1, 'Severity_n_long': -1, 'Severity_ch_mean_long': -1, 'Severity_ch_sd_long': -1, 'Severity_ch_n_long': -1, 'r_weeks_long': -1}
# arm_num:  1
# 🍩 https://wandb.ai/srws-psg/optimizing_description_integrate/r/call/07cd5690-eb55-4906-b7a2-148969b42025
# {'Year': 2017, 'ind_clu': 'individual', 'ICC_for_cRCT': 0.05, 'Country': 'Italy', 'Single_multi': 'single', 'Age_mean': 59.56, 'Age_sd': 14.41, 'Age_n': 19, 'F_n': 11, 'Hyp_n': 0, 'Insomnia_diagnosis': '1. formal_ICSD', 'Primary_insomnia_n': 19, 'Comorbidities': '0. primary_insomnia', 'se': 0, 'sd': 1, 'cr': 0, 'cw': 0, 'sr': 0, 'sc': 0, 're': 0, 'pi': 0, 'w': 0, 'dt': 0, 'ns': 0, 'he': 0, 'tg': 0, 'ind': 0, 'gp': 0, 'ff': 0, 'ae': 0}
# {'Year': 2017, 'ind_clu': 'individual', 'ICC_for_cRCT': 0.05, 'Country': 'Italy', 'Single_multi': 'single', 'Age_mean': 59.56, 'Age_sd': 14.41, 'Age_n': 19, 'F_n': 11, 'Hyp_n': 0, 'Insomnia_diagnosis': '1. formal_ICSD', 'Primary_insomnia_n': 19, 'Comorbidities': '0. primary_insomnia', 'se': 0, 'sd': 1, 'cr': 0, 'cw': 0, 'sr': 0, 'sc': 0, 're': 0, 'pi': 0, 'w': 0, 'dt': 0, 'ns': 0, 'he': 0, 'tg': 0, 'ind': 0, 'gp': 0, 'ff': 0, 'ae': 0, 'n': 'None', 'remission': 'None', 'def_remission_response': 'None', 'scale_used': 'None', 'Severity_bl_mean': 'None', 'Severity_bl_sd': 'None', 'Severity_bl_n': 'None', 'Severity_ch_mean': 'None', 'Severity_ch_sd': 'None', 'Severity_ch_n': 'None', 'Severity_ep_mean': 'None', 'Severity_ep_sd': 'None', 'Severity_ep_n': 'None', 'Severity_scale': 'None', 'dropout': 'None', 'SE_mean': 'None', 'SE_sd': 'None', 'SE_n': 'None', 'TST_mean': 'None', 'TST_sd': 'None', 'TST_n': 'None', 'SOL_mean': 'None', 'SOL_sd': 'None', 'SOL_n': 'None', 'WASO_mean': 'None', 'WASO_sd': 'None', 'WASO_n': 'None', 'Sleep_diary_weeks': 'None', 'r_long': 'None', 'r_long_scale_used': 'None', 'Severity_mean_long': 'None', 'Severity_sd_long': 'None', 'Severity_n_long': 'None', 'Severity_ch_mean_long': 'None', 'Severity_ch_sd_long': 'None', 'Severity_ch_n_long': 'None', 'r_weeks_long': 'None'}
# 🍩 https://wandb.ai/srws-psg/optimizing_description_integrate/r/call/656ced38-432e-4d22-92da-5b24cc18c9ff
# {'n': 19, 'remission': -1, 'def_remission_response': '-1', 'scale_used': 'ISI', 'Severity_bl_mean': 17.78, 'Severity_bl_sd': 4.26, 'Severity_bl_n': 19, 'Severity_ch_mean': -1, 'Severity_ch_sd': -1, 'Severity_ch_n': -1, 'Severity_ep_mean': 13.11, 'Severity_ep_sd': 5.68, 'Severity_ep_n': 19, 'Severity_scale': 'ISI', 'dropout': 1, 'SE_mean': -1, 'SE_sd': -1, 'SE_n': -1, 'TST_mean': -1, 'TST_sd': -1, 'TST_n': -1, 'SOL_mean': -1, 'SOL_sd': -1, 'SOL_n': -1, 'WASO_mean': -1, 'WASO_sd': -1, 'WASO_n': -1, 'Sleep_diary_weeks': -1, 'r_long': -1, 'r_long_scale_used': '-1', 'Severity_mean_long': -1, 'Severity_sd_long': -1, 'Severity_n_long': -1, 'Severity_ch_mean_long': -1, 'Severity_ch_sd_long': -1, 'Severity_ch_n_long': -1, 'r_weeks_long': -1}
# {'Year': 2017, 'ind_clu': 'individual', 'ICC_for_cRCT': 0.05, 'Country': 'Italy', 'Single_multi': 'single', 'Age_mean': 59.56, 'Age_sd': 14.41, 'Age_n': 19, 'F_n': 11, 'Hyp_n': 0, 'Insomnia_diagnosis': '1. formal_ICSD', 'Primary_insomnia_n': 19, 'Comorbidities': '0. primary_insomnia', 'se': 0, 'sd': 1, 'cr': 0, 'cw': 0, 'sr': 0, 'sc': 0, 're': 0, 'pi': 0, 'w': 0, 'dt': 0, 'ns': 0, 'he': 0, 'tg': 0, 'ind': 0, 'gp': 0, 'ff': 0, 'ae': 0, 'n': 19, 'remission': -1, 'def_remission_response': '-1', 'scale_used': 'ISI', 'Severity_bl_mean': 17.78, 'Severity_bl_sd': 4.26, 'Severity_bl_n': 19, 'Severity_ch_mean': -1, 'Severity_ch_sd': -1, 'Severity_ch_n': -1, 'Severity_ep_mean': 13.11, 'Severity_ep_sd': 5.68, 'Severity_ep_n': 19, 'Severity_scale': 'ISI', 'dropout': 1, 'SE_mean': -1, 'SE_sd': -1, 'SE_n': -1, 'TST_mean': -1, 'TST_sd': -1, 'TST_n': -1, 'SOL_mean': -1, 'SOL_sd': -1, 'SOL_n': -1, 'WASO_mean': -1, 'WASO_sd': -1, 'WASO_n': -1, 'Sleep_diary_weeks': -1, 'r_long': -1, 'r_long_scale_used': '-1', 'Severity_mean_long': -1, 'Severity_sd_long': -1, 'Severity_n_long': -1, 'Severity_ch_mean_long': -1, 'Severity_ch_sd_long': -1, 'Severity_ch_n_long': -1, 'r_weeks_long': -1}
# 0 0
# 🍩 https://wandb.ai/srws-psg/optimizing_description_integrate/r/call/46a04c72-6a25-4d6e-93c6-770f6c2b365f
# ChatCompletion(id='chatcmpl-9TBk0a6JKnRzFZp9KPoAtnz9bCfTq', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='', role='assistant', function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_A3uBquq5pn2FyAZMB7UEsUD0', function=Function(arguments='{"Year":2017,"ind_clu":"individual","ICC_for_cRCT":0.05,"Country":"Italy","Single_multi":"single","Age_mean":64.42,"Age_sd":12.94,"Age_n":19,"F_n":10,"Hyp_n":19,"Insomnia_diagnosis":"1. formal_ICSD","Primary_insomnia_n":19,"Comorbidities":"0. primary_insomnia","se":1,"sd":1,"cr":0,"cw":0,"sr":0,"sc":0,"re":0,"pi":0,"w":0,"dt":0,"ns":0,"he":0,"tg":0,"ind":0,"gp":0,"ff":1,"ae":0}', name='optimize_descriptions_of_study_features'), type='function')]), content_filter_results={})], created=1716743672, model='gpt-4o-2024-05-13', object='chat.completion', system_fingerprint='fp_5f4bad809a', usage=CompletionUsage(completion_tokens=157, prompt_tokens=15155, total_tokens=15312), prompt_filter_results=[{'prompt_index': 0, 'content_filter_result': {'jailbreak': {'filtered': False, 'detected': False}, 'custom_blocklists': {'filtered': False, 'details': []}}}, {'prompt_index': 8, 'content_filter_result': {'custom_blocklists': {'filtered': False, 'details': []}}}, {'prompt_index': 5, 'content_filter_result': {'custom_blocklists': {'filtered': False, 'details': []}}}, {'prompt_index': 7, 'content_filter_result': {'custom_blocklists': {'filtered': False, 'details': []}}}, {'prompt_index': 3, 'content_filter_result': {'custom_blocklists': {'filtered': False, 'details': []}}}, {'prompt_index': 4, 'content_filter_result': {'custom_blocklists': {'filtered': False, 'details': []}}}, {'prompt_index': 6, 'content_filter_result': {'custom_blocklists': {'filtered': False, 'details': []}}}, {'prompt_index': 2, 'content_filter_result': {'custom_blocklists': {'filtered': False, 'details': []}}}])
# 0 0
# 🍩 https://wandb.ai/srws-psg/optimizing_description_integrate/r/call/bbb882e6-0eb4-4cd6-a0f3-a927e0763f29
# ChatCompletion(id='chatcmpl-9TBk98esrtqJYmtlQKlKvKWSncha0', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='', role='assistant', function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_DqdRbn7zeLwO4jXgIEkXH4SY', function=Function(arguments='{"n":19,"remission":-1,"def_remission_response":"-1","scale_used":"ISI","Severity_bl_mean":15.74,"Severity_bl_sd":4.27,"Severity_bl_n":19,"Severity_ch_mean":-1,"Severity_ch_sd":-1,"Severity_ch_n":-1,"Severity_ep_mean":12.16,"Severity_ep_sd":6.62,"Severity_ep_n":19,"Severity_scale":"ISI","dropout":1,"SE_mean":-1,"SE_sd":-1,"SE_n":-1,"TST_mean":-1,"TST_sd":-1,"TST_n":-1,"SOL_mean":-1,"SOL_sd":-1,"SOL_n":-1,"WASO_mean":-1,"WASO_sd":-1,"WASO_n":-1,"Sleep_diary_weeks":1,"r_long":-1,"r_long_scale_used":"-1","Severity_mean_long":-1,"Severity_sd_long":-1,"Severity_n_long":-1,"Severity_ch_mean_long":-1,"Severity_ch_sd_long":-1,"Severity_ch_n_long":-1,"r_weeks_long":-1}', name='optimize_descriptions_of_study_features'), type='function')]), content_filter_results={})], created=1716743681, model='gpt-4o-2024-05-13', object='chat.completion', system_fingerprint='fp_5f4bad809a', usage=CompletionUsage(completion_tokens=255, prompt_tokens=16134, total_tokens=16389), prompt_filter_results=[{'prompt_index': 0, 'content_filter_result': {'jailbreak': {'filtered': False, 'detected': False}, 'custom_blocklists': {'filtered': False, 'details': []}}}, {'prompt_index': 5, 'content_filter_result': {'custom_blocklists': {'filtered': False, 'details': []}}}, {'prompt_index': 8, 'content_filter_result': {'custom_blocklists': {'filtered': False, 'details': []}}}, {'prompt_index': 3, 'content_filter_result': {'custom_blocklists': {'filtered': False, 'details': []}}}, {'prompt_index': 7, 'content_filter_result': {'custom_blocklists': {'filtered': False, 'details': []}}}, {'prompt_index': 6, 'content_filter_result': {'custom_blocklists': {'filtered': False, 'details': []}}}, {'prompt_index': 4, 'content_filter_result': {'custom_blocklists': {'filtered': False, 'details': []}}}, {'prompt_index': 2, 'content_filter_result': {'custom_blocklists': {'filtered': False, 'details': []}}}])
# Quintiliani2020:[{"name": "Year", "type": "number", "description": "Publication year of the primary report. If only the results from registry are available, use the date when the results are posted instead."}, {"name": "ind_clu", "type": "string", "description": "individual"}, {"name": "ICC_for_cRCT", "type": "number", "description": "Intra-cluster Correlation Coefficient for cluster RCTs. If it is not clearly stated, use '0.05'."}, {"name": "Country", "type": "string", "description": "Italy"}, {"name": "Single_multi", "type": "string", "description": "single"}, {"name": "Age_mean", "type": "number", "description": "Mean age of the patients in the arm."}, {"name": "Age_sd", "type": "number", "description": "Standard deviation of the mean age. SD can be calculated using SE or CI if not directly provided."}, {"name": "Age_n", "type": "number", "description": "The number of patients used for calculating Age_mean."}, {"name": "F_n", "type": "number", "description": "Number of female patients in the arm."}, {"name": "Hyp_n", "type": "number", "description": "Number of patients using hypnotics. If the drug treatment is part of the protocol treatment, 'Hyp_n' should be equal to 'n'. If not, use the number at baseline."}, {"name": "Insomnia_diagnosis", "type": "string", "description": "1. formal_ICSD"}, {"name": "Primary_insomnia_n", "type": "number", "description": "The number of primary insomnia patients (insomnia without comorbidities) in the arm. If focused on primary insomnia, it should be same as 'n'."}, {"name": "Comorbidities", "type": "string", "description": "0. primary_insomnia"}, {"name": "se", "type": "number", "description": "Sleep hygiene education component: 1 if included, 0 if not."}, {"name": "sd", "type": "number", "description": "Sleep diary component: 1 if included, 0 if not."}, {"name": "cr", "type": "number", "description": "Cognitive restructuring component: 1 if included, 0 if not."}, {"name": "cw", "type": "number", "description": "Constructive worry component: 1 if included, 0 if not."}, {"name": "sr", "type": "number", "description": "Sleep restriction component: 1 if included, 0 if not."}, {"name": "sc", "type": "number", "description": "Stimulus control component: 1 if included, 0 if not."}, {"name": "re", "type": "number", "description": "Relaxation component: 1 if included, 0 if not."}, {"name": "pi", "type": "number", "description": "Paradoxical intention component: 1 if included, 0 if not."}, {"name": "w", "type": "number", "description": "Waiting component: 1 if included, 0 if not."}, {"name": "dt", "type": "number", "description": "Conventional drug treatment component: 1 if included, 0 if not."}, {"name": "ns", "type": "number", "description": "Non-specific treatment effect component: 1 if included, 0 if not."}, {"name": "he", "type": "number", "description": "Human encouragement component: 1 if included, 0 if not."}, {"name": "tg", "type": "number", "description": "Therapeutic guidance component: 1 if included, 0 if not."}, {"name": "ind", "type": "number", "description": "Individual interaction with therapists: 1 if included, 0 if not."}, {"name": "gp", "type": "number", "description": "Group interaction with therapists: 1 if included, 0 if not."}, {"name": "ff", "type": "number", "description": "Face-to-face interaction with therapists: 1 if included, 0 if not."}, {"name": "ae", "type": "number", "description": "Automatic encouragement component: 1 if included, 0 if not."}, {"name": "n", "type": "number", "description": "The number of patients randomized to the arm."}, {"name": "remission", "type": "number", "description": "The number of patients achieving remission at post-treatment or at its closest time point. If equidistant, use the longer timeframe."}, {"name": "def_remission_response", "type": "string", "description": "-1"}, {"name": "scale_used", "type": "string", "description": "ISI"}, {"name": "Severity_bl_mean", "type": "number", "description": "Mean severity measured at baseline."}, { ...
# Log has been successfully written to 'log_description'
# data extraction
# n_index:  0
# fold_index:  1
# f_index:  0
# 🍩 https://wandb.ai/srws-psg/optimizing_description_integrate/r/call/cd09f296-116b-46d6-adad-a10efe0d1aab
# arms_num:  2
# arms_list:  ['computerized cognitive behavioral therapy for insomnia (CCBT-I)', 'standard sleep hygiene education']
# arm_num:  0
# 🍩 https://wandb.ai/srws-psg/optimizing_description_integrate/r/call/9a54bfda-7474-45c2-9b8f-b3c545af0ad1
# {'Year': 2017, 'ind_clu': 'individual', 'ICC_for_cRCT': 0.05, 'Country': 'USA', 'Single_multi': 'single', 'Age_mean': 63.1, 'Age_sd': 6.8, 'Age_n': 14, 'F_n': 3, 'Hyp_n': 14, 'Insomnia_diagnosis': '2. informal_ISI', 'Primary_insomnia_n': 0, 'Comorbidities': '2. psy_mixed', 'se': 1, 'sd': 1, 'cr': 1, 'cw': 0, 'sr': 1, 'sc': 1, 're': 1, 'pi': 0, 'w': 0, 'dt': 0, 'ns': 0, 'he': 1, 'tg': 1, 'ind': 0, 'gp': 0, 'ff': 0, 'ae': 1}
# {'Year': 2017, 'ind_clu': 'individual', 'ICC_for_cRCT': 0.05, 'Country': 'USA', 'Single_multi': 'single', 'Age_mean': 63.1, 'Age_sd': 6.8, 'Age_n': 14, 'F_n': 3, 'Hyp_n': 14, 'Insomnia_diagnosis': '2. informal_ISI', 'Primary_insomnia_n': 0, 'Comorbidities': '2. psy_mixed', 'se': 1, 'sd': 1, 'cr': 1, 'cw': 0, 'sr': 1, 'sc': 1, 're': 1, 'pi': 0, 'w': 0, 'dt': 0, 'ns': 0, 'he': 1, 'tg': 1, 'ind': 0, 'gp': 0, 'ff': 0, 'ae': 1, 'n': 'None', 'remission': 'None', 'def_remission_response': 'None', 'scale_used': 'None', 'Severity_bl_mean': 'None', 'Severity_bl_sd': 'None', 'Severity_bl_n': 'None', 'Severity_ch_mean': 'None', 'Severity_ch_sd': 'None', 'Severity_ch_n': 'None', 'Severity_ep_mean': 'None', 'Severity_ep_sd': 'None', 'Severity_ep_n': 'None', 'Severity_scale': 'None', 'dropout': 'None', 'SE_mean': 'None', 'SE_sd': 'None', 'SE_n': 'None', 'TST_mean': 'None', 'TST_sd': 'None', 'TST_n': 'None', 'SOL_mean': 'None', 'SOL_sd': 'None', 'SOL_n': 'None', 'WASO_mean': 'None', 'WASO_sd': 'None', 'WASO_n': 'None', 'Sleep_diary_weeks': 'None', 'r_long': 'None', 'r_long_scale_used': 'None', 'Severity_mean_long': 'None', 'Severity_sd_long': 'None', 'Severity_n_long': 'None', 'Severity_ch_mean_long': 'None', 'Severity_ch_sd_long': 'None', 'Severity_ch_n_long': 'None', 'r_weeks_long': 'None'}
# 🍩 https://wandb.ai/srws-psg/optimizing_description_integrate/r/call/a83c802c-385e-4017-8508-4e258507a12a
# {'n': 14, 'remission': -1, 'def_remission_response': '-1', 'scale_used': 'ISI', 'Severity_bl_mean': 15.7, 'Severity_bl_sd': 3, 'Severity_bl_n': 14, 'Severity_ch_mean': -1, 'Severity_ch_sd': -1, 'Severity_ch_n': -1, 'Severity_ep_mean': 11.2, 'Severity_ep_sd': 5.6, 'Severity_ep_n': 14, 'Severity_scale': 'ISI', 'dropout': 6, 'SE_mean': -1, 'SE_sd': -1, 'SE_n': -1, 'TST_mean': -1, 'TST_sd': -1, 'TST_n': -1, 'SOL_mean': -1, 'SOL_sd': -1, 'SOL_n': -1, 'WASO_mean': -1, 'WASO_sd': -1, 'WASO_n': -1, 'Sleep_diary_weeks': -1, 'r_long': -1, 'r_long_scale_used': '-1', 'Severity_mean_long': -1, 'Severity_sd_long': -1, 'Severity_n_long': -1, 'Severity_ch_mean_long': -1, 'Severity_ch_sd_long': -1, 'Severity_ch_n_long': -1, 'r_weeks_long': -1}
# {'Year': 2017, 'ind_clu': 'individual', 'ICC_for_cRCT': 0.05, 'Country': 'USA', 'Single_multi': 'single', 'Age_mean': 63.1, 'Age_sd': 6.8, 'Age_n': 14, 'F_n': 3, 'Hyp_n': 14, 'Insomnia_diagnosis': '2. informal_ISI', 'Primary_insomnia_n': 0, 'Comorbidities': '2. psy_mixed', 'se': 1, 'sd': 1, 'cr': 1, 'cw': 0, 'sr': 1, 'sc': 1, 're': 1, 'pi': 0, 'w': 0, 'dt': 0, 'ns': 0, 'he': 1, 'tg': 1, 'ind': 0, 'gp': 0, 'ff': 0, 'ae': 1, 'n': 14, 'remission': -1, 'def_remission_response': '-1', 'scale_used': 'ISI', 'Severity_bl_mean': 15.7, 'Severity_bl_sd': 3, 'Severity_bl_n': 14, 'Severity_ch_mean': -1, 'Severity_ch_sd': -1, 'Severity_ch_n': -1, 'Severity_ep_mean': 11.2, 'Severity_ep_sd': 5.6, 'Severity_ep_n': 14, 'Severity_scale': 'ISI', 'dropout': 6, 'SE_mean': -1, 'SE_sd': -1, 'SE_n': -1, 'TST_mean': -1, 'TST_sd': -1, 'TST_n': -1, 'SOL_mean': -1, 'SOL_sd': -1, 'SOL_n': -1, 'WASO_mean': -1, 'WASO_sd': -1, 'WASO_n': -1, 'Sleep_diary_weeks': -1, 'r_long': -1, 'r_long_scale_used': '-1', 'Severity_mean_long': -1, 'Severity_sd_long': -1, 'Severity_n_long': -1, 'Severity_ch_mean_long': -1, 'Severity_ch_sd_long': -1, 'Severity_ch_n_long': -1, 'r_weeks_long': -1}
# arm_num:  1
# 🍩 https://wandb.ai/srws-psg/optimizing_description_integrate/r/call/aeaa05d7-5f34-4032-8e4a-da5eea54a979
# {'Year': 2017, 'ind_clu': 'individual', 'ICC_for_cRCT': 0.05, 'Country': 'USA', 'Single_multi': 'single', 'Age_mean': 64.7, 'Age_sd': 9.5, 'Age_n': 14, 'F_n': 9, 'Hyp_n': 14, 'Insomnia_diagnosis': '2. informal_ISI', 'Primary_insomnia_n': 0, 'Comorbidities': '2. psy_mixed', 'se': 1, 'sd': 0, 'cr': 0, 'cw': 0, 'sr': 0, 'sc': 0, 're': 0, 'pi': 0, 'w': 0, 'dt': 0, 'ns': 0, 'he': 1, 'tg': 0, 'ind': 0, 'gp': 0, 'ff': 0, 'ae': 0}
# {'Year': 2017, 'ind_clu': 'individual', 'ICC_for_cRCT': 0.05, 'Country': 'USA', 'Single_multi': 'single', 'Age_mean': 64.7, 'Age_sd': 9.5, 'Age_n': 14, 'F_n': 9, 'Hyp_n': 14, 'Insomnia_diagnosis': '2. informal_ISI', 'Primary_insomnia_n': 0, 'Comorbidities': '2. psy_mixed', 'se': 1, 'sd': 0, 'cr': 0, 'cw': 0, 'sr': 0, 'sc': 0, 're': 0, 'pi': 0, 'w': 0, 'dt': 0, 'ns': 0, 'he': 1, 'tg': 0, 'ind': 0, 'gp': 0, 'ff': 0, 'ae': 0, 'n': 'None', 'remission': 'None', 'def_remission_response': 'None', 'scale_used': 'None', 'Severity_bl_mean': 'None', 'Severity_bl_sd': 'None', 'Severity_bl_n': 'None', 'Severity_ch_mean': 'None', 'Severity_ch_sd': 'None', 'Severity_ch_n': 'None', 'Severity_ep_mean': 'None', 'Severity_ep_sd': 'None', 'Severity_ep_n': 'None', 'Severity_scale': 'None', 'dropout': 'None', 'SE_mean': 'None', 'SE_sd': 'None', 'SE_n': 'None', 'TST_mean': 'None', 'TST_sd': 'None', 'TST_n': 'None', 'SOL_mean': 'None', 'SOL_sd': 'None', 'SOL_n': 'None', 'WASO_mean': 'None', 'WASO_sd': 'None', 'WASO_n': 'None', 'Sleep_diary_weeks': 'None', 'r_long': 'None', 'r_long_scale_used': 'None', 'Severity_mean_long': 'None', 'Severity_sd_long': 'None', 'Severity_n_long': 'None', 'Severity_ch_mean_long': 'None', 'Severity_ch_sd_long': 'None', 'Severity_ch_n_long': 'None', 'r_weeks_long': 'None'}
# 🍩 https://wandb.ai/srws-psg/optimizing_description_integrate/r/call/0c745998-6476-47e4-a81d-8592d80aed27
# {'n': 14, 'remission': -1, 'def_remission_response': '-1', 'scale_used': 'ISI', 'Severity_bl_mean': 15.4, 'Severity_bl_sd': 2.9, 'Severity_bl_n': 14, 'Severity_ch_mean': -1, 'Severity_ch_sd': -1, 'Severity_ch_n': -1, 'Severity_ep_mean': 12.2, 'Severity_ep_sd': 5.1, 'Severity_ep_n': 14, 'Severity_scale': 'ISI', 'dropout': 1, 'SE_mean': -1, 'SE_sd': -1, 'SE_n': -1, 'TST_mean': -1, 'TST_sd': -1, 'TST_n': -1, 'SOL_mean': -1, 'SOL_sd': -1, 'SOL_n': -1, 'WASO_mean': -1, 'WASO_sd': -1, 'WASO_n': -1, 'Sleep_diary_weeks': -1, 'r_long': -1, 'r_long_scale_used': '-1', 'Severity_mean_long': -1, 'Severity_sd_long': -1, 'Severity_n_long': -1, 'Severity_ch_mean_long': -1, 'Severity_ch_sd_long': -1, 'Severity_ch_n_long': -1, 'r_weeks_long': -1}
# {'Year': 2017, 'ind_clu': 'individual', 'ICC_for_cRCT': 0.05, 'Country': 'USA', 'Single_multi': 'single', 'Age_mean': 64.7, 'Age_sd': 9.5, 'Age_n': 14, 'F_n': 9, 'Hyp_n': 14, 'Insomnia_diagnosis': '2. informal_ISI', 'Primary_insomnia_n': 0, 'Comorbidities': '2. psy_mixed', 'se': 1, 'sd': 0, 'cr': 0, 'cw': 0, 'sr': 0, 'sc': 0, 're': 0, 'pi': 0, 'w': 0, 'dt': 0, 'ns': 0, 'he': 1, 'tg': 0, 'ind': 0, 'gp': 0, 'ff': 0, 'ae': 0, 'n': 14, 'remission': -1, 'def_remission_response': '-1', 'scale_used': 'ISI', 'Severity_bl_mean': 15.4, 'Severity_bl_sd': 2.9, 'Severity_bl_n': 14, 'Severity_ch_mean': -1, 'Severity_ch_sd': -1, 'Severity_ch_n': -1, 'Severity_ep_mean': 12.2, 'Severity_ep_sd': 5.1, 'Severity_ep_n': 14, 'Severity_scale': 'ISI', 'dropout': 1, 'SE_mean': -1, 'SE_sd': -1, 'SE_n': -1, 'TST_mean': -1, 'TST_sd': -1, 'TST_n': -1, 'SOL_mean': -1, 'SOL_sd': -1, 'SOL_n': -1, 'WASO_mean': -1, 'WASO_sd': -1, 'WASO_n': -1, 'Sleep_diary_weeks': -1, 'r_long': -1, 'r_long_scale_used': '-1', 'Severity_mean_long': -1, 'Severity_sd_long': -1, 'Severity_n_long': -1, 'Severity_ch_mean_long': -1, 'Severity_ch_sd_long': -1, 'Severity_ch_n_long': -1, 'r_weeks_long': -1}
# 1 0
# 🍩 https://wandb.ai/srws-psg/optimizing_description_integrate/r/call/50b4de70-6dec-4abb-981a-a38cbea69ca5
# ChatCompletion(id='chatcmpl-9TBlMBgHrbvkGP1tzxWJU2zBwzYCS', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='', role='assistant', function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_Hz9vJJhsUq4tbzVVv7HPYbkm', function=Function(arguments='{"Year": "Publication year of the primary report. If only the results from a registry are available, use the date when the results are posted instead. For example, if a study was published in 2017, the Year would be 2017.","ind_clu": "Study design: Choose \'individual\' if individually randomized, choose \'cluster\' if it is a cluster RCT. For example, if a study randomly assigns individual participants to different groups, select \'individual\'. If it assigns groups or clusters of participants, select \'cluster\'.","ICC_for_cRCT": "Intra-cluster Correlation Coefficient for cluster RCTs. If it is not clearly stated, use \'0.05\'. For example, if a study mentions an ICC of 0.03, use that value. If not mentioned, default to 0.05.","Country": "Countries where the trial took place. For example, if a study was conducted in the USA and Canada, list \'USA, Canada\'.","Single_multi": "Whether the recruitment took place at a single or multiple centers. Choose from the options [single, multi]. For example, if a study recruited participants from only one hospital, select \'single\'. If it recruited from several hospitals, select \'multi\'.","Age_mean": "Mean age of the patients in the arm. For example, if the average age of participants in a study arm is 45.6 years, the Age_mean would be 45.6.","Age_sd": "Standard deviation of the mean age. SD can be calculated using SE or CI if not directly provided. For example, if the standard deviation of the mean age is 5.2 years, the Age_sd would be 5.2.","Age_n": "The number of patients used for calculating Age_mean. For example, if the mean age was calculated from 100 patients, the Age_n would be 100.","F_n": "Number of female patients in the arm. For example, if there are 30 female patients in a study arm, the F_n would be 30.","Hyp_n": "Number of patients using hypnotics. If the drug treatment is part of the protocol treatment, \'Hyp_n\' should be equal to \'n\'. If not, use the number at baseline. For example, if 20 patients were using hypnotics at baseline, the Hyp_n would be 20.","Insomnia_diagnosis": "Formal or informal diagnostic criteria used for insomnia. Prioritize DSM, ICSD, ICD, and other formal criteria over informal scales. Choose from the options [1. formal_DSM, 1. formal_ICSD, 1. formal_ICD, 1. formal_Edinger2004, 2. informal_ISI, 2. informal_SCI, 2. informal_PSQI, 2. informal_AIS, 2. informal_other_self_reported_scales, 3. others]. For example, if a study used the Insomnia Severity Index (ISI) for diagnosis, select \'2. informal_ISI\'.","Primary_insomnia_n": "The number of primary insomnia patients (insomnia without comorbidities) in the arm. If focused on primary insomnia, it should be the same as \'n\'. For example, if a study arm has 50 patients with primary insomnia, the Primary_insomnia_n would be 50.","Comorbidities": "Comorbid conditions present in the study population. Use predefined categories such as primary_insomnia, psy_MDD, phy_heart_failure, etc. Choose from the options [0. primary_insomnia, 1. primary_secondary_mixed, 2. psy_MDD, 2. psy_anxiety, 2. psy_PTSD, 2. psy_schizophrenia_or_psychosis, 2. psy_bipolar, 2. psy_substance_dependence, 2. psy_others, 2. psy_mixed, 3. phy_dialysis, 3. phy_heart_failure, 3. phy_diabetes, 3. phy_fibromyalgia, 3. phy_cancer, 3. phy_steroid, 3. phy_pregnancy_perinatal, 3. phy_menopause, 3. phy_others, 3. phy_mixed, 4. psy_phy_mixed]. For example, if a study population includes patients with diabetes, select \'3. phy_diabetes\'.","se": "Sleep hygiene education component: 1 if included, 0 if not. For example, if a study includes sleep hygiene education as part of the intervention, the se would be 1.","sd": "Sleep diary component: 1 if ...
# 1 0
# 🍩 https://wandb.ai/srws-psg/optimizing_description_integrate/r/call/0d5ec572-1790-4369-8179-48cd3a89965c
# ChatCompletion(id='chatcmpl-9TBmMRC4FovUpC6VI13vfcGj9TgbR', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='', role='assistant', function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_mIsyyTdI2K7ZlBdpCApWtlrh', function=Function(arguments='{"n":14,"remission":-1,"def_remission_response":"Copy & paste the definition of remission and response stated by the author. If multiple definitions are stated for different measures, copy & paste them all. Example: \'Remission was defined as a score of 7 or less on the Insomnia Severity Index (ISI). Response was defined as a reduction of 8 points or more on the ISI.\'","scale_used":"The scale used for the definition of remission. Prioritize; ISI > SCI > FOSQ > ESS > PSQI > AIS > other_self_reported_scales > WASO_SOL > WASO > SOL. Use the definition stated by the author. You have to choose from the options [ISI, SCI, FOSQ, ESS, PSQI, AIS, other_self_reported_scales, WASO_SOL, WASO, SOL]","Severity_bl_mean":15.7,"Severity_bl_sd":3,"Severity_bl_n":14,"Severity_ch_mean":-1,"Severity_ch_sd":-1,"Severity_ch_n":-1,"Severity_ep_mean":11.2,"Severity_ep_sd":5.6,"Severity_ep_n":14,"Severity_scale":"The scale used for measuring the sleep-related severity. Prioritize; ISI > SCI > FOSQ > ESS > PSQI > AIS > other_self_reported_scales > WASO_SOL > WASO > SOL. Use the definition stated by the author. You have to choose from the options [ISI, SCI, FOSQ, ESS, PSQI, AIS, other_self_reported_scales, WASO_SOL, WASO, SOL]","dropout":6,"SE_mean":-1,"SE_sd":-1,"SE_n":-1,"TST_mean":-1,"TST_sd":-1,"TST_n":-1,"SOL_mean":-1,"SOL_sd":-1,"SOL_n":-1,"WASO_mean":-1,"WASO_sd":-1,"WASO_n":-1,"Sleep_diary_weeks":-1,"r_long":-1,"r_long_scale_used":"Scales that were used for counting remission at long-term. You have to choose from the options [ISI, SCI, FOSQ, ESS, PSQI, AIS, other_self_reported_scales, WASO_SOL, WASO, SOL]","Severity_mean_long":-1,"Severity_sd_long":-1,"Severity_n_long":-1,"Severity_ch_mean_long":-1,"Severity_ch_sd_long":-1,"Severity_ch_n_long":-1,"r_weeks_long":-1}', name='optimize_descriptions_of_study_features'), type='function')]), content_filter_results={})], created=1716743818, model='gpt-4o-2024-05-13', object='chat.completion', system_fingerprint='fp_5f4bad809a', usage=CompletionUsage(completion_tokens=552, prompt_tokens=22459, total_tokens=23011), prompt_filter_results=[{'prompt_index': 0, 'content_filter_result': {'jailbreak': {'filtered': False, 'detected': False}, 'custom_blocklists': {'filtered': False, 'details': []}}}, {'prompt_index': 9, 'content_filter_result': {'custom_blocklists': {'filtered': False, 'details': []}}}, {'prompt_index': 6, 'content_filter_result': {'custom_blocklists': {'filtered': False, 'details': []}}}, {'prompt_index': 7, 'content_filter_result': {'custom_blocklists': {'filtered': False, 'details': []}}}, {'prompt_index': 11, 'content_filter_result': {'custom_blocklists': {'filtered': False, 'details': []}}}, {'prompt_index': 5, 'content_filter_result': {'custom_blocklists': {'filtered': False, 'details': []}}}, {'prompt_index': 10, 'content_filter_result': {'custom_blocklists': {'filtered': False, 'details': []}}}, {'prompt_index': 4, 'content_filter_result': {'custom_blocklists': {'filtered': False, 'details': []}}}, {'prompt_index': 3, 'content_filter_result': {'custom_blocklists': {'filtered': False, 'details': []}}}, {'prompt_index': 2, 'content_filter_result': {'custom_blocklists': {'filtered': False, 'details': []}}}])
# Patel2017:[{"name": "Year", "type": "number", "description": "Publication year of the primary report. If only the results from a registry are available, use the date when the results are posted instead. For example, if a study was published in 2017, the Year would be 2017."}, {"name": "ind_clu", "type": "string", "description": "Study design: Choose 'individual' if individually randomized, choose 'cluster' if it is a cluster RCT. For example, if a study randomly assigns individual participants to different groups, select 'individual'. If it assigns groups or clusters of participants, select 'cluster'."}, {"name": "ICC_for_cRCT", "type": "number", "description": "Intra-cluster Correlation Coefficient for cluster RCTs. If it is not clearly stated, use '0.05'. For example, if a study mentions an ICC of 0.03, use that value. If not mentioned, default to 0.05."}, {"name": "Country", "type": "string", "description": "Countries where the trial took place. For example, if a study was conducted in the USA and Canada, list 'USA, Canada'."}, {"name": "Single_multi", "type": "string", "description": "Whether the recruitment took place at a single or multiple centers. Choose from the options [single, multi]. For example, if a study recruited participants from only one hospital, select 'single'. If it recruited from several hospitals, select 'multi'."}, {"name": "Age_mean", "type": "number", "description": "Mean age of the patients in the arm. For example, if the average age of participants in a study arm is 45.6 years, the Age_mean would be 45.6."}, {"name": "Age_sd", "type": "number", "description": "Standard deviation of the mean age. SD can be calculated using SE or CI if not directly provided. For example, if the standard deviation of the mean age is 5.2 years, the Age_sd would be 5.2."}, {"name": "Age_n", "type": "number", "description": "The number of patients used for calculating Age_mean. For example, if the mean age was calculated from 100 patients, the Age_n would be 100."}, {"name": "F_n", "type": "number", "description": "Number of female patients in the arm. For example, if there are 30 female patients in a study arm, the F_n would be 30."}, {"name": "Hyp_n", "type": "number", "description": "Number of patients using hypnotics. If the drug treatment is part of the protocol treatment, 'Hyp_n' should be equal to 'n'. If not, use the number at baseline. For example, if 20 patients were using hypnotics at baseline, the Hyp_n would be 20."}, {"name": "Insomnia_diagnosis", "type": "string", "description": "Formal or informal diagnostic criteria used for insomnia. Prioritize DSM, ICSD, ICD, and other formal criteria over informal scales. Choose from the options [1. formal_DSM, 1. formal_ICSD, 1. formal_ICD, 1. formal_Edinger2004, 2. informal_ISI, 2. informal_SCI, 2. informal_PSQI, 2. informal_AIS, 2. informal_other_self_reported_scales, 3. others]. For example, if a study used the Insomnia Severity Index (ISI) for diagnosis, select '2. informal_ISI'."}, {"name": "Primary_insomnia_n", "type": "number", "description": "The number of primary insomnia patients (insomnia without comorbidities) in the arm. If focused on primary insomnia, it should be the same as 'n'. For example, if a study arm has 50 patients with primary insomnia, the Primary_insomnia_n would be 50."}, {"name": "Comorbidities", "type": "string", "description": "Comorbid conditions present in the study population. Use predefined categories such as primary_insomnia, psy_MDD, phy_heart_failure, etc. Choose from the options [0. primary_insomnia, 1. primary_secondary_mixed, 2. psy_MDD, 2. psy_anxiety, 2. psy_PTSD, 2. psy_schizophrenia_or_psychosis, 2. psy_bipolar, 2. psy_substance_dependence, 2. psy_others, 2. psy_mixed, 3. phy_dialysis, 3. phy_heart_failure, 3. phy_diabetes, 3. phy_fibromyalgia, 3. phy_cancer, 3. phy_steroid, 3. phy_pregnancy_perinatal, 3. phy_menopause, 3. phy_others, 3. phy_mixed, 4. psy_phy_mixed]. For example, if a study population includes patients with ...
# Log has been successfully written to 'log_description'
# data extraction
# n_index:  0
# fold_index:  2
# f_index:  0
# 🍩 https://wandb.ai/srws-psg/optimizing_description_integrate/r/call/578fdf93-8314-4b7a-bd01-2405bb9e39ce
# arms_num:  5
# arms_list:  ['Imagery training', 'Imagery training with muscle tension-release', 'Somatic focusing training', 'Progressive relaxation training', 'Waiting-list control']
# arm_num:  0
# 🍩 https://wandb.ai/srws-psg/optimizing_description_integrate/r/call/a96ef752-ea5e-4747-83c0-41954d666a36
# {'Year': 1983, 'ind_clu': 'individual', 'ICC_for_cRCT': 0.05, 'Country': 'USA', 'Single_multi': 'single', 'Age_mean': 45.2, 'Age_sd': 10.5, 'Age_n': 9, 'F_n': 5, 'Hyp_n': 9, 'Insomnia_diagnosis': '2. informal_other_self_reported_scales', 'Primary_insomnia_n': 9, 'Comorbidities': '0. primary_insomnia', 'se': 0, 'sd': 1, 'cr': 0, 'cw': 0, 'sr': 0, 'sc': 0, 're': 1, 'pi': 0, 'w': 0, 'dt': 0, 'ns': 0, 'he': 0, 'tg': 1, 'ind': 0, 'gp': 1, 'ff': 1, 'ae': 0}
# {'Year': 1983, 'ind_clu': 'individual', 'ICC_for_cRCT': 0.05, 'Country': 'USA', 'Single_multi': 'single', 'Age_mean': 45.2, 'Age_sd': 10.5, 'Age_n': 9, 'F_n': 5, 'Hyp_n': 9, 'Insomnia_diagnosis': '2. informal_other_self_reported_scales', 'Primary_insomnia_n': 9, 'Comorbidities': '0. primary_insomnia', 'se': 0, 'sd': 1, 'cr': 0, 'cw': 0, 'sr': 0, 'sc': 0, 're': 1, 'pi': 0, 'w': 0, 'dt': 0, 'ns': 0, 'he': 0, 'tg': 1, 'ind': 0, 'gp': 1, 'ff': 1, 'ae': 0, 'n': 'None', 'remission': 'None', 'def_remission_response': 'None', 'scale_used': 'None', 'Severity_bl_mean': 'None', 'Severity_bl_sd': 'None', 'Severity_bl_n': 'None', 'Severity_ch_mean': 'None', 'Severity_ch_sd': 'None', 'Severity_ch_n': 'None', 'Severity_ep_mean': 'None', 'Severity_ep_sd': 'None', 'Severity_ep_n': 'None', 'Severity_scale': 'None', 'dropout': 'None', 'SE_mean': 'None', 'SE_sd': 'None', 'SE_n': 'None', 'TST_mean': 'None', 'TST_sd': 'None', 'TST_n': 'None', 'SOL_mean': 'None', 'SOL_sd': 'None', 'SOL_n': 'None', 'WASO_mean': 'None', 'WASO_sd': 'None', 'WASO_n': 'None', 'Sleep_diary_weeks': 'None', 'r_long': 'None', 'r_long_scale_used': 'None', 'Severity_mean_long': 'None', 'Severity_sd_long': 'None', 'Severity_n_long': 'None', 'Severity_ch_mean_long': 'None', 'Severity_ch_sd_long': 'None', 'Severity_ch_n_long': 'None', 'r_weeks_long': 'None'}
# 🍩 https://wandb.ai/srws-psg/optimizing_description_integrate/r/call/e01408d9-cfa9-42fa-967b-f345828bc64c
# {'n': 9, 'remission': -1, 'def_remission_response': '-1', 'scale_used': 'SOL', 'Severity_bl_mean': 108.01, 'Severity_bl_sd': 50.49, 'Severity_bl_n': 9, 'Severity_ch_mean': -1, 'Severity_ch_sd': -1, 'Severity_ch_n': -1, 'Severity_ep_mean': 35.46, 'Severity_ep_sd': 16.61, 'Severity_ep_n': 9, 'Severity_scale': 'SOL', 'dropout': -1, 'SE_mean': -1, 'SE_sd': -1, 'SE_n': -1, 'TST_mean': -1, 'TST_sd': -1, 'TST_n': -1, 'SOL_mean': -1, 'SOL_sd': -1, 'SOL_n': -1, 'WASO_mean': -1, 'WASO_sd': -1, 'WASO_n': -1, 'Sleep_diary_weeks': -1, 'r_long': -1, 'r_long_scale_used': '-1', 'Severity_mean_long': -1, 'Severity_sd_long': -1, 'Severity_n_long': -1, 'Severity_ch_mean_long': -1, 'Severity_ch_sd_long': -1, 'Severity_ch_n_long': -1, 'r_weeks_long': -1}
# {'Year': 1983, 'ind_clu': 'individual', 'ICC_for_cRCT': 0.05, 'Country': 'USA', 'Single_multi': 'single', 'Age_mean': 45.2, 'Age_sd': 10.5, 'Age_n': 9, 'F_n': 5, 'Hyp_n': 9, 'Insomnia_diagnosis': '2. informal_other_self_reported_scales', 'Primary_insomnia_n': 9, 'Comorbidities': '0. primary_insomnia', 'se': 0, 'sd': 1, 'cr': 0, 'cw': 0, 'sr': 0, 'sc': 0, 're': 1, 'pi': 0, 'w': 0, 'dt': 0, 'ns': 0, 'he': 0, 'tg': 1, 'ind': 0, 'gp': 1, 'ff': 1, 'ae': 0, 'n': 9, 'remission': -1, 'def_remission_response': '-1', 'scale_used': 'SOL', 'Severity_bl_mean': 108.01, 'Severity_bl_sd': 50.49, 'Severity_bl_n': 9, 'Severity_ch_mean': -1, 'Severity_ch_sd': -1, 'Severity_ch_n': -1, 'Severity_ep_mean': 35.46, 'Severity_ep_sd': 16.61, 'Severity_ep_n': 9, 'Severity_scale': 'SOL', 'dropout': -1, 'SE_mean': -1, 'SE_sd': -1, 'SE_n': -1, 'TST_mean': -1, 'TST_sd': -1, 'TST_n': -1, 'SOL_mean': -1, 'SOL_sd': -1, 'SOL_n': -1, 'WASO_mean': -1, 'WASO_sd': -1, 'WASO_n': -1, 'Sleep_diary_weeks': -1, 'r_long': -1, 'r_long_scale_used': '-1', 'Severity_mean_long': -1, 'Severity_sd_long': -1, 'Severity_n_long': -1, 'Severity_ch_mean_long': -1, 'Severity_ch_sd_long': -1, 'Severity_ch_n_long': -1, 'r_weeks_long': -1}
# arm_num:  1
# 🍩 https://wandb.ai/srws-psg/optimizing_description_integrate/r/call/d24aa67b-37b1-4793-9845-5eaff0633467
# {'Year': 1983, 'ind_clu': 'individual', 'ICC_for_cRCT': 0.05, 'Country': 'USA', 'Single_multi': 'single', 'Age_mean': None, 'Age_sd': None, 'Age_n': 9, 'F_n': None, 'Hyp_n': 9, 'Insomnia_diagnosis': '3. others', 'Primary_insomnia_n': 9, 'Comorbidities': '0. primary_insomnia', 'se': 0, 'sd': 1, 'cr': 0, 'cw': 0, 'sr': 0, 'sc': 0, 're': 1, 'pi': 0, 'w': 0, 'dt': 0, 'ns': 0, 'he': 0, 'tg': 1, 'ind': 0, 'gp': 1, 'ff': 1, 'ae': 0}
# {'Year': 1983, 'ind_clu': 'individual', 'ICC_for_cRCT': 0.05, 'Country': 'USA', 'Single_multi': 'single', 'Age_mean': None, 'Age_sd': None, 'Age_n': 9, 'F_n': None, 'Hyp_n': 9, 'Insomnia_diagnosis': '3. others', 'Primary_insomnia_n': 9, 'Comorbidities': '0. primary_insomnia', 'se': 0, 'sd': 1, 'cr': 0, 'cw': 0, 'sr': 0, 'sc': 0, 're': 1, 'pi': 0, 'w': 0, 'dt': 0, 'ns': 0, 'he': 0, 'tg': 1, 'ind': 0, 'gp': 1, 'ff': 1, 'ae': 0, 'n': 'None', 'remission': 'None', 'def_remission_response': 'None', 'scale_used': 'None', 'Severity_bl_mean': 'None', 'Severity_bl_sd': 'None', 'Severity_bl_n': 'None', 'Severity_ch_mean': 'None', 'Severity_ch_sd': 'None', 'Severity_ch_n': 'None', 'Severity_ep_mean': 'None', 'Severity_ep_sd': 'None', 'Severity_ep_n': 'None', 'Severity_scale': 'None', 'dropout': 'None', 'SE_mean': 'None', 'SE_sd': 'None', 'SE_n': 'None', 'TST_mean': 'None', 'TST_sd': 'None', 'TST_n': 'None', 'SOL_mean': 'None', 'SOL_sd': 'None', 'SOL_n': 'None', 'WASO_mean': 'None', 'WASO_sd': 'None', 'WASO_n': 'None', 'Sleep_diary_weeks': 'None', 'r_long': 'None', 'r_long_scale_used': 'None', 'Severity_mean_long': 'None', 'Severity_sd_long': 'None', 'Severity_n_long': 'None', 'Severity_ch_mean_long': 'None', 'Severity_ch_sd_long': 'None', 'Severity_ch_n_long': 'None', 'r_weeks_long': 'None'}
# 🍩 https://wandb.ai/srws-psg/optimizing_description_integrate/r/call/60388739-442e-47cb-8bd2-8fb3701cc390
# {'n': 9, 'remission': -1, 'def_remission_response': '-1', 'scale_used': 'SOL', 'Severity_bl_mean': 100.95, 'Severity_bl_sd': 38.74, 'Severity_bl_n': 9, 'Severity_ch_mean': -1, 'Severity_ch_sd': -1, 'Severity_ch_n': -1, 'Severity_ep_mean': 50.98, 'Severity_ep_sd': 38.42, 'Severity_ep_n': 9, 'Severity_scale': 'SOL', 'dropout': -1, 'SE_mean': -1, 'SE_sd': -1, 'SE_n': -1, 'TST_mean': -1, 'TST_sd': -1, 'TST_n': -1, 'SOL_mean': -1, 'SOL_sd': -1, 'SOL_n': -1, 'WASO_mean': -1, 'WASO_sd': -1, 'WASO_n': -1, 'Sleep_diary_weeks': -1, 'r_long': -1, 'r_long_scale_used': '-1', 'Severity_mean_long': 34.76, 'Severity_sd_long': 16.18, 'Severity_n_long': 9, 'Severity_ch_mean_long': -1, 'Severity_ch_sd_long': -1, 'Severity_ch_n_long': -1, 'r_weeks_long': 24}
# {'Year': 1983, 'ind_clu': 'individual', 'ICC_for_cRCT': 0.05, 'Country': 'USA', 'Single_multi': 'single', 'Age_mean': None, 'Age_sd': None, 'Age_n': 9, 'F_n': None, 'Hyp_n': 9, 'Insomnia_diagnosis': '3. others', 'Primary_insomnia_n': 9, 'Comorbidities': '0. primary_insomnia', 'se': 0, 'sd': 1, 'cr': 0, 'cw': 0, 'sr': 0, 'sc': 0, 're': 1, 'pi': 0, 'w': 0, 'dt': 0, 'ns': 0, 'he': 0, 'tg': 1, 'ind': 0, 'gp': 1, 'ff': 1, 'ae': 0, 'n': 9, 'remission': -1, 'def_remission_response': '-1', 'scale_used': 'SOL', 'Severity_bl_mean': 100.95, 'Severity_bl_sd': 38.74, 'Severity_bl_n': 9, 'Severity_ch_mean': -1, 'Severity_ch_sd': -1, 'Severity_ch_n': -1, 'Severity_ep_mean': 50.98, 'Severity_ep_sd': 38.42, 'Severity_ep_n': 9, 'Severity_scale': 'SOL', 'dropout': -1, 'SE_mean': -1, 'SE_sd': -1, 'SE_n': -1, 'TST_mean': -1, 'TST_sd': -1, 'TST_n': -1, 'SOL_mean': -1, 'SOL_sd': -1, 'SOL_n': -1, 'WASO_mean': -1, 'WASO_sd': -1, 'WASO_n': -1, 'Sleep_diary_weeks': -1, 'r_long': -1, 'r_long_scale_used': '-1', 'Severity_mean_long': 34.76, 'Severity_sd_long': 16.18, 'Severity_n_long': 9, 'Severity_ch_mean_long': -1, 'Severity_ch_sd_long': -1, 'Severity_ch_n_long': -1, 'r_weeks_long': 24}
# arm_num:  2
# 🍩 https://wandb.ai/srws-psg/optimizing_description_integrate/r/call/94b26132-7e89-4de7-8965-90a33fe14e15
# {'Year': 1983, 'ind_clu': 'individual', 'ICC_for_cRCT': 0.05, 'Country': 'USA', 'Single_multi': 'single', 'Age_mean': -1, 'Age_sd': -1, 'Age_n': 8, 'F_n': -1, 'Hyp_n': -1, 'Insomnia_diagnosis': '3. others', 'Primary_insomnia_n': 8, 'Comorbidities': '0. primary_insomnia', 'se': 0, 'sd': 1, 'cr': 0, 'cw': 0, 'sr': 0, 'sc': 0, 're': 1, 'pi': 0, 'w': 0, 'dt': 0, 'ns': 0, 'he': 0, 'tg': 1, 'ind': 0, 'gp': 1, 'ff': 1, 'ae': 0}
# {'Year': 1983, 'ind_clu': 'individual', 'ICC_for_cRCT': 0.05, 'Country': 'USA', 'Single_multi': 'single', 'Age_mean': -1, 'Age_sd': -1, 'Age_n': 8, 'F_n': -1, 'Hyp_n': -1, 'Insomnia_diagnosis': '3. others', 'Primary_insomnia_n': 8, 'Comorbidities': '0. primary_insomnia', 'se': 0, 'sd': 1, 'cr': 0, 'cw': 0, 'sr': 0, 'sc': 0, 're': 1, 'pi': 0, 'w': 0, 'dt': 0, 'ns': 0, 'he': 0, 'tg': 1, 'ind': 0, 'gp': 1, 'ff': 1, 'ae': 0, 'n': 'None', 'remission': 'None', 'def_remission_response': 'None', 'scale_used': 'None', 'Severity_bl_mean': 'None', 'Severity_bl_sd': 'None', 'Severity_bl_n': 'None', 'Severity_ch_mean': 'None', 'Severity_ch_sd': 'None', 'Severity_ch_n': 'None', 'Severity_ep_mean': 'None', 'Severity_ep_sd': 'None', 'Severity_ep_n': 'None', 'Severity_scale': 'None', 'dropout': 'None', 'SE_mean': 'None', 'SE_sd': 'None', 'SE_n': 'None', 'TST_mean': 'None', 'TST_sd': 'None', 'TST_n': 'None', 'SOL_mean': 'None', 'SOL_sd': 'None', 'SOL_n': 'None', 'WASO_mean': 'None', 'WASO_sd': 'None', 'WASO_n': 'None', 'Sleep_diary_weeks': 'None', 'r_long': 'None', 'r_long_scale_used': 'None', 'Severity_mean_long': 'None', 'Severity_sd_long': 'None', 'Severity_n_long': 'None', 'Severity_ch_mean_long': 'None', 'Severity_ch_sd_long': 'None', 'Severity_ch_n_long': 'None', 'r_weeks_long': 'None'}
# 🍩 https://wandb.ai/srws-psg/optimizing_description_integrate/r/call/ff08de7b-42ff-4700-a957-28ff0b035555
# {'n': 8, 'remission': -1, 'def_remission_response': '-1', 'scale_used': 'SOL', 'Severity_bl_mean': 104.04, 'Severity_bl_sd': 57.88, 'Severity_bl_n': 8, 'Severity_ch_mean': -1, 'Severity_ch_sd': -1, 'Severity_ch_n': -1, 'Severity_ep_mean': 67.29, 'Severity_ep_sd': 59.11, 'Severity_ep_n': 8, 'Severity_scale': 'SOL', 'dropout': -1, 'SE_mean': -1, 'SE_sd': -1, 'SE_n': -1, 'TST_mean': -1, 'TST_sd': -1, 'TST_n': -1, 'SOL_mean': -1, 'SOL_sd': -1, 'SOL_n': -1, 'WASO_mean': -1, 'WASO_sd': -1, 'WASO_n': -1, 'Sleep_diary_weeks': 4, 'r_long': -1, 'r_long_scale_used': '-1', 'Severity_mean_long': 84.2, 'Severity_sd_long': 60.2, 'Severity_n_long': 8, 'Severity_ch_mean_long': -1, 'Severity_ch_sd_long': -1, 'Severity_ch_n_long': -1, 'r_weeks_long': 30}
# ...
# 🍩 https://wandb.ai/srws-psg/optimizing_description_integrate/r/call/5d42e7ef-421d-4ba8-98d4-fe04a7e70f9c
# {'n': 61, 'remission': -1, 'def_remission_response': '-1', 'scale_used': '-1', 'Severity_bl_mean': -1, 'Severity_bl_sd': -1, 'Severity_bl_n': -1, 'Severity_ch_mean': -1, 'Severity_ch_sd': -1, 'Severity_ch_n': -1, 'Severity_ep_mean': -1, 'Severity_ep_sd': -1, 'Severity_ep_n': -1, 'Severity_scale': '-1', 'dropout': -1, 'SE_mean': 93.7, 'SE_sd': 2.8, 'SE_n': 61, 'TST_mean': -1, 'TST_sd': -1, 'TST_n': -1, 'SOL_mean': 11.3, 'SOL_sd': 5.4, 'SOL_n': 61, 'WASO_mean': 6.2, 'WASO_sd': 6.1, 'WASO_n': 61, 'Sleep_diary_weeks': -1, 'r_long': -1, 'r_long_scale_used': '-1', 'Severity_mean_long': -1, 'Severity_sd_long': -1, 'Severity_n_long': -1, 'Severity_ch_mean_long': -1, 'Severity_ch_sd_long': -1, 'Severity_ch_n_long': -1, 'r_weeks_long': -1}
# {'Year': 2000, 'ind_clu': 'individual', 'ICC_for_cRCT': 0.05, 'Country': 'USA', 'Single_multi': 'single', 'Age_mean': 21.7, 'Age_sd': 5.6, 'Age_n': 61, 'F_n': 46, 'Hyp_n': 0, 'Insomnia_diagnosis': '1. formal_ICSD', 'Primary_insomnia_n': 0, 'Comorbidities': '0. primary_insomnia', 'se': 0, 'sd': 0, 'cr': 0, 'cw': 0, 'sr': 0, 'sc': 0, 're': 0, 'pi': 0, 'w': 0, 'dt': 0, 'ns': 0, 'he': 0, 'tg': 0, 'ind': 0, 'gp': 0, 'ff': 0, 'ae': 0, 'n': 61, 'remission': -1, 'def_remission_response': '-1', 'scale_used': '-1', 'Severity_bl_mean': -1, 'Severity_bl_sd': -1, 'Severity_bl_n': -1, 'Severity_ch_mean': -1, 'Severity_ch_sd': -1, 'Severity_ch_n': -1, 'Severity_ep_mean': -1, 'Severity_ep_sd': -1, 'Severity_ep_n': -1, 'Severity_scale': '-1', 'dropout': -1, 'SE_mean': 93.7, 'SE_sd': 2.8, 'SE_n': 61, 'TST_mean': -1, 'TST_sd': -1, 'TST_n': -1, 'SOL_mean': 11.3, 'SOL_sd': 5.4, 'SOL_n': 61, 'WASO_mean': 6.2, 'WASO_sd': 6.1, 'WASO_n': 61, 'Sleep_diary_weeks': -1, 'r_long': -1, 'r_long_scale_used': '-1', 'Severity_mean_long': -1, 'Severity_sd_long': -1, 'Severity_n_long': -1, 'Severity_ch_mean_long': -1, 'Severity_ch_sd_long': -1, 'Severity_ch_n_long': -1, 'r_weeks_long': -1}
# n_index:  4
# fold_index:  9
# f_index:  4
# 🍩 https://wandb.ai/srws-psg/optimizing_description_integrate/r/call/d15a3524-ffda-4c1c-8905-7b6c22544f9d
# arms_num:  2
# arms_list:  ['cognitive behavioral therapy for insomnia', 'control intervention']
# arm_num:  0
# 🍩 https://wandb.ai/srws-psg/optimizing_description_integrate/r/call/7a8e2ad6-702f-4775-b899-442d9341580f
# {'Year': 2019, 'ind_clu': 'individual', 'ICC_for_cRCT': 0.05, 'Country': 'USA', 'Single_multi': 'multi', 'Age_mean': 33.4, 'Age_sd': 5.2, 'Age_n': 89, 'F_n': 44, 'Hyp_n': 89, 'Insomnia_diagnosis': '1. formal_DSM', 'Primary_insomnia_n': 89, 'Comorbidities': '3. phy_pregnancy_perinatal', 'se': 1, 'sd': 1, 'cr': 1, 'cw': 1, 'sr': 1, 'sc': 1, 're': 1, 'pi': 0, 'w': 0, 'dt': 0, 'ns': 0, 'he': 0, 'tg': 1, 'ind': 1, 'gp': 0, 'ff': 1, 'ae': 0}
# {'Year': 2019, 'ind_clu': 'individual', 'ICC_for_cRCT': 0.05, 'Country': 'USA', 'Single_multi': 'multi', 'Age_mean': 33.4, 'Age_sd': 5.2, 'Age_n': 89, 'F_n': 44, 'Hyp_n': 89, 'Insomnia_diagnosis': '1. formal_DSM', 'Primary_insomnia_n': 89, 'Comorbidities': '3. phy_pregnancy_perinatal', 'se': 1, 'sd': 1, 'cr': 1, 'cw': 1, 'sr': 1, 'sc': 1, 're': 1, 'pi': 0, 'w': 0, 'dt': 0, 'ns': 0, 'he': 0, 'tg': 1, 'ind': 1, 'gp': 0, 'ff': 1, 'ae': 0, 'n': 'None', 'remission': 'None', 'def_remission_response': 'None', 'scale_used': 'None', 'Severity_bl_mean': 'None', 'Severity_bl_sd': 'None', 'Severity_bl_n': 'None', 'Severity_ch_mean': 'None', 'Severity_ch_sd': 'None', 'Severity_ch_n': 'None', 'Severity_ep_mean': 'None', 'Severity_ep_sd': 'None', 'Severity_ep_n': 'None', 'Severity_scale': 'None', 'dropout': 'None', 'SE_mean': 'None', 'SE_sd': 'None', 'SE_n': 'None', 'TST_mean': 'None', 'TST_sd': 'None', 'TST_n': 'None', 'SOL_mean': 'None', 'SOL_sd': 'None', 'SOL_n': 'None', 'WASO_mean': 'None', 'WASO_sd': 'None', 'WASO_n': 'None', 'Sleep_diary_weeks': 'None', 'r_long': 'None', 'r_long_scale_used': 'None', 'Severity_mean_long': 'None', 'Severity_sd_long': 'None', 'Severity_n_long': 'None', 'Severity_ch_mean_long': 'None', 'Severity_ch_sd_long': 'None', 'Severity_ch_n_long': 'None', 'r_weeks_long': 'None'}
# 🍩 https://wandb.ai/srws-psg/optimizing_description_integrate/r/call/7ee4b911-ba3b-4ffd-ad2c-2ac42d8cd1a3
# {'n': 89, 'remission': 57, 'def_remission_response': 'Remission of insomnia (to an Insomnia Severity Index score less than 8) disorder was attained by 64% of women in the cognitive behavioral therapy for insomnia group.', 'scale_used': 'ISI', 'Severity_bl_mean': 15.4, 'Severity_bl_sd': 4.3, 'Severity_bl_n': 89, 'Severity_ch_mean': -7.4, 'Severity_ch_sd': 6.7, 'Severity_ch_n': 89, 'Severity_ep_mean': 8.0, 'Severity_ep_sd': 5.2, 'Severity_ep_n': 89, 'Severity_scale': 'ISI', 'dropout': 18, 'SE_mean': -1, 'SE_sd': -1, 'SE_n': -1, 'TST_mean': -1, 'TST_sd': -1, 'TST_n': -1, 'SOL_mean': -1, 'SOL_sd': -1, 'SOL_n': -1, 'WASO_mean': -1, 'WASO_sd': -1, 'WASO_n': -1, 'Sleep_diary_weeks': -1, 'r_long': -1, 'r_long_scale_used': '-1', 'Severity_mean_long': -1, 'Severity_sd_long': -1, 'Severity_n_long': -1, 'Severity_ch_mean_long': -1, 'Severity_ch_sd_long': -1, 'Severity_ch_n_long': -1, 'r_weeks_long': -1}
# {'Year': 2019, 'ind_clu': 'individual', 'ICC_for_cRCT': 0.05, 'Country': 'USA', 'Single_multi': 'multi', 'Age_mean': 33.4, 'Age_sd': 5.2, 'Age_n': 89, 'F_n': 44, 'Hyp_n': 89, 'Insomnia_diagnosis': '1. formal_DSM', 'Primary_insomnia_n': 89, 'Comorbidities': '3. phy_pregnancy_perinatal', 'se': 1, 'sd': 1, 'cr': 1, 'cw': 1, 'sr': 1, 'sc': 1, 're': 1, 'pi': 0, 'w': 0, 'dt': 0, 'ns': 0, 'he': 0, 'tg': 1, 'ind': 1, 'gp': 0, 'ff': 1, 'ae': 0, 'n': 89, 'remission': 57, 'def_remission_response': 'Remission of insomnia (to an Insomnia Severity Index score less than 8) disorder was attained by 64% of women in the cognitive behavioral therapy for insomnia group.', 'scale_used': 'ISI', 'Severity_bl_mean': 15.4, 'Severity_bl_sd': 4.3, 'Severity_bl_n': 89, 'Severity_ch_mean': -7.4, 'Severity_ch_sd': 6.7, 'Severity_ch_n': 89, 'Severity_ep_mean': 8.0, 'Severity_ep_sd': 5.2, 'Severity_ep_n': 89, 'Severity_scale': 'ISI', 'dropout': 18, 'SE_mean': -1, 'SE_sd': -1, 'SE_n': -1, 'TST_mean': -1, 'TST_sd': -1, 'TST_n': -1, 'SOL_mean': -1, 'SOL_sd': -1, 'SOL_n': -1, 'WASO_mean': -1, 'WASO_sd': -1, 'WASO_n': -1, 'Sleep_diary_weeks': -1, 'r_long': -1, 'r_long_scale_used': '-1', 'Severity_mean_long': -1, 'Severity_sd_long': -1, 'Severity_n_long': -1, 'Severity_ch_mean_long': -1, 'Severity_ch_sd_long': -1, 'Severity_ch_n_long': -1, 'r_weeks_long': -1}
# arm_num:  1
# 🍩 https://wandb.ai/srws-psg/optimizing_description_integrate/r/call/dd3948c4-a2c1-4696-a46d-bd1b2809eb82
# {'Year': 2019, 'ind_clu': 'individual', 'ICC_for_cRCT': 0.05, 'Country': 'USA', 'Single_multi': 'multi', 'Age_mean': 32.6, 'Age_sd': 4.9, 'Age_n': 90, 'F_n': 90, 'Hyp_n': 90, 'Insomnia_diagnosis': '1. formal_DSM', 'Primary_insomnia_n': 90, 'Comorbidities': '3. phy_pregnancy_perinatal', 'se': 1, 'sd': 0, 'cr': 0, 'cw': 0, 'sr': 0, 'sc': 0, 're': 1, 'pi': 0, 'w': 0, 'dt': 0, 'ns': 1, 'he': 1, 'tg': 1, 'ind': 1, 'gp': 0, 'ff': 1, 'ae': 0}
# {'Year': 2019, 'ind_clu': 'individual', 'ICC_for_cRCT': 0.05, 'Country': 'USA', 'Single_multi': 'multi', 'Age_mean': 32.6, 'Age_sd': 4.9, 'Age_n': 90, 'F_n': 90, 'Hyp_n': 90, 'Insomnia_diagnosis': '1. formal_DSM', 'Primary_insomnia_n': 90, 'Comorbidities': '3. phy_pregnancy_perinatal', 'se': 1, 'sd': 0, 'cr': 0, 'cw': 0, 'sr': 0, 'sc': 0, 're': 1, 'pi': 0, 'w': 0, 'dt': 0, 'ns': 1, 'he': 1, 'tg': 1, 'ind': 1, 'gp': 0, 'ff': 1, 'ae': 0, 'n': 'None', 'remission': 'None', 'def_remission_response': 'None', 'scale_used': 'None', 'Severity_bl_mean': 'None', 'Severity_bl_sd': 'None', 'Severity_bl_n': 'None', 'Severity_ch_mean': 'None', 'Severity_ch_sd': 'None', 'Severity_ch_n': 'None', 'Severity_ep_mean': 'None', 'Severity_ep_sd': 'None', 'Severity_ep_n': 'None', 'Severity_scale': 'None', 'dropout': 'None', 'SE_mean': 'None', 'SE_sd': 'None', 'SE_n': 'None', 'TST_mean': 'None', 'TST_sd': 'None', 'TST_n': 'None', 'SOL_mean': 'None', 'SOL_sd': 'None', 'SOL_n': 'None', 'WASO_mean': 'None', 'WASO_sd': 'None', 'WASO_n': 'None', 'Sleep_diary_weeks': 'None', 'r_long': 'None', 'r_long_scale_used': 'None', 'Severity_mean_long': 'None', 'Severity_sd_long': 'None', 'Severity_n_long': 'None', 'Severity_ch_mean_long': 'None', 'Severity_ch_sd_long': 'None', 'Severity_ch_n_long': 'None', 'r_weeks_long': 'None'}
# 🍩 https://wandb.ai/srws-psg/optimizing_description_integrate/r/call/496e56bd-d38e-44c9-a8f9-ad0a9b54b095
# {'n': 90, 'remission': 47, 'def_remission_response': 'Remission of insomnia (to an Insomnia Severity Index score less than 8) disorder was attained by 64% of women in the cognitive behavioral therapy for insomnia group vs 52% in the control group.', 'scale_used': 'ISI', 'Severity_bl_mean': 15.9, 'Severity_bl_sd': 4.4, 'Severity_bl_n': 90, 'Severity_ch_mean': -1.3, 'Severity_ch_sd': 4.9, 'Severity_ch_n': 90, 'Severity_ep_mean': 11.2, 'Severity_ep_sd': 4.9, 'Severity_ep_n': 90, 'Severity_scale': 'ISI', 'dropout': 27, 'SE_mean': -1, 'SE_sd': -1, 'SE_n': -1, 'TST_mean': -1, 'TST_sd': -1, 'TST_n': -1, 'SOL_mean': -1, 'SOL_sd': -1, 'SOL_n': -1, 'WASO_mean': -1, 'WASO_sd': -1, 'WASO_n': -1, 'Sleep_diary_weeks': -1, 'r_long': -1, 'r_long_scale_used': '-1', 'Severity_mean_long': -1, 'Severity_sd_long': -1, 'Severity_n_long': -1, 'Severity_ch_mean_long': -1, 'Severity_ch_sd_long': -1, 'Severity_ch_n_long': -1, 'r_weeks_long': -1}
# {'Year': 2019, 'ind_clu': 'individual', 'ICC_for_cRCT': 0.05, 'Country': 'USA', 'Single_multi': 'multi', 'Age_mean': 32.6, 'Age_sd': 4.9, 'Age_n': 90, 'F_n': 90, 'Hyp_n': 90, 'Insomnia_diagnosis': '1. formal_DSM', 'Primary_insomnia_n': 90, 'Comorbidities': '3. phy_pregnancy_perinatal', 'se': 1, 'sd': 0, 'cr': 0, 'cw': 0, 'sr': 0, 'sc': 0, 're': 1, 'pi': 0, 'w': 0, 'dt': 0, 'ns': 1, 'he': 1, 'tg': 1, 'ind': 1, 'gp': 0, 'ff': 1, 'ae': 0, 'n': 90, 'remission': 47, 'def_remission_response': 'Remission of insomnia (to an Insomnia Severity Index score less than 8) disorder was attained by 64% of women in the cognitive behavioral therapy for insomnia group vs 52% in the control group.', 'scale_used': 'ISI', 'Severity_bl_mean': 15.9, 'Severity_bl_sd': 4.4, 'Severity_bl_n': 90, 'Severity_ch_mean': -1.3, 'Severity_ch_sd': 4.9, 'Severity_ch_n': 90, 'Severity_ep_mean': 11.2, 'Severity_ep_sd': 4.9, 'Severity_ep_n': 90, 'Severity_scale': 'ISI', 'dropout': 27, 'SE_mean': -1, 'SE_sd': -1, 'SE_n': -1, 'TST_mean': -1, 'TST_sd': -1, 'TST_n': -1, 'SOL_mean': -1, 'SOL_sd': -1, 'SOL_n': -1, 'WASO_mean': -1, 'WASO_sd': -1, 'WASO_n': -1, 'Sleep_diary_weeks': -1, 'r_long': -1, 'r_long_scale_used': '-1', 'Severity_mean_long': -1, 'Severity_sd_long': -1, 'Severity_n_long': -1, 'Severity_ch_mean_long': -1, 'Severity_ch_sd_long': -1, 'Severity_ch_n_long': -1, 'r_weeks_long': -1}
# 9 0
# 9 1
# 9 2
# 9 3
# 9 4
# 🍩 https://wandb.ai/srws-psg/optimizing_description_integrate/r/call/746c6d32-3d59-486c-ac7e-f69f001fbcd5
# error occured:  Error code: 400 - {'error': {'message': "This model's maximum context length is 128000 tokens. However, your messages resulted in 128615 tokens (127226 in the messages, 1389 in the functions). Please reduce the length of the messages or functions.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# 9 0
# 9 1
# 9 2
# 9 3
# 9 4
# 🍩 https://wandb.ai/srws-psg/optimizing_description_integrate/r/call/8c418c19-56d2-47fc-96d9-346348b2efc7
# error occured:  Error code: 400 - {'error': {'message': "This model's maximum context length is 128000 tokens. However, your messages resulted in 129594 tokens (127789 in the messages, 1805 in the functions). Please reduce the length of the messages or functions.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Manber2019:[{"name": "Year", "type": "number", "description": "Publication year of the primary report. If only the results from registry are available, use the date when the results are posted instead."}, {"name": "ind_clu", "type": "string", "description": "Study design: Choose 'individual' if individually randomized, choose 'cluster' if it is a cluster RCT. You have to choose from the options [individual, cluster]."}, {"name": "ICC_for_cRCT", "type": "number", "description": "Intra-cluster Correlation Coefficient for cluster RCTs. If it is not clearly stated, use '0.05'."}, {"name": "Country", "type": "string", "description": "Countries where the trial took place."}, {"name": "Single_multi", "type": "string", "description": "Whether the recruitment took place at a single or multi centers. You have to choose from the options [single, multi]."}, {"name": "Age_mean", "type": "number", "description": "Mean age of the patients in the arm."}, {"name": "Age_sd", "type": "number", "description": "Standard deviation of the mean age. SD can be calculated using SE or CI if not directly provided."}, {"name": "Age_n", "type": "number", "description": "The number of patients used for calculating Age_mean."}, {"name": "F_n", "type": "number", "description": "Number of female patients in the arm."}, {"name": "Hyp_n", "type": "number", "description": "Number of patients using hypnotics. If the drug treatment is part of the protocol treatment, 'Hyp_n' should be equal to 'n'. If not, use the number at baseline."}, {"name": "Insomnia_diagnosis", "type": "string", "description": "Formal or informal diagnostic criteria used for insomnia. Prioritize DSM, ICSD, ICD, and other formal criteria over informal scales. You have to choose from the options [1. formal_DSM, 1. formal_ICSD, 1. formal_ICD, 1. formal_Edinger2004, 2. informal_ISI, 2. informal_SCI, 2. informal_PSQI, 2. informal_AIS, 2. informal_other_self_reported_scales, 3. others]."}, {"name": "Primary_insomnia_n", "type": "number", "description": "The number of primary insomnia patients (insomnia without comorbidities) in the arm. If focused on primary insomnia, it should be same as 'n'."}, {"name": "Comorbidities", "type": "string", "description": "Comorbid conditions present in the study population. Use predefined categories such as primary_insomnia, psy_MDD, phy_heart_failure, etc. You have to choose from the options [0. primary_insomnia, 1. primary_secondary_mixed, 2. psy_MDD, 2. psy_anxiety, 2. psy_PTSD, 2. psy_schizophrenia_or_psychosis, 2. psy_bipolar, 2. psy_substance_dependence, 2. psy_others, 2. psy_mixed, 3. phy_dialysis, 3. phy_heart_failure, 3. phy_diabetes, 3. phy_fibromyalgia, 3. phy_cancer, 3. phy_steroid, 3. phy_pregnancy_perinatal, 3. phy_menopause, 3. phy_others, 3. phy_mixed, 4. psy_phy_mixed]"}, {"name": "se", "type": "number", "description": "Sleep hygiene education component: 1 if included, 0 if not."}, {"name": "sd", "type": "number", "description": "Sleep diary component: 1 if included, 0 if not."}, {"name": "cr", "type": "number", "description": "Cognitive restructuring component: 1 if included, 0 if not."}, {"name": "cw", "type": "number", "description": "Constructive worry component: 1 if included, 0 if not."}, {"name": "sr", "type": "number", "description": "Sleep restriction component: 1 if included, 0 if not."}, {"name": "sc", "type": "number", "description": "Stimulus control component: 1 if included, 0 if not."}, {"name": "re", "type": "number", "description": "Relaxation component: 1 if included, 0 if not."}, {"name": "pi", "type": "number", "description": "Paradoxical intention component: 1 if included, 0 if not."}, {"name": "w", "type": "number", "description": "Waiting component: 1 if included, 0 if not."}, {"name": "dt", "type": "number", "description": "Conventional drug treatment component: 1 if included, 0 if not."}, {"name": "ns", "type": "number", "description": "Non-specific treatment effect component: 1 if included, 0 if not."}, {"name": "he", "type ...
# Log has been successfully written to 'log_description'
